# %% [markdown]
# <a href="https://colab.research.google.com/github/deltorobarba/maths/blob/main/maths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="blue">**Mathematics**

# %% [markdown]
# ![science](https://raw.githubusercontent.com/deltorobarba/maths/main/science.PNG)

# %% [markdown]
# ##### <font color="blue">*Heisenberg-Weyl*

# %% [markdown]
# <font color="blue">**Heisenberg-Weyl Algebra (mit Exponentiation und Konjugation)**
#
# Heisenberg-Weyl Algebra: (anti-symmetric (symplectic) bilinear form)
#
# ![Quantum Harmonic Oscillator](https://upload.wikimedia.org/wikipedia/commons/thumb/9/9e/HarmOsziFunktionen.png/330px-HarmOsziFunktionen.png)
#
# 1. Hamiltonian:
#
# $$\hat{H} \propto \hat{P}^2 + \hat{Q}^2 = \hbar \omega \left(\hat{a}^\dagger \hat{a} + \frac{1}{2}\right) = \hbar \omega (\hat{n} + \frac{1}{2})$$
#
# * $\hat{H}$ generator of basis state rotations in phase space ($Q / P$)
#
#   * Ladder Operator Form: $\hat{H}=\hbar \omega\left(a^{\dagger} a+\frac{1}{2}\right)$. $\hat{a}$ and $\hat{a}^\dagger$ (Ladder Operators):  jump Up and Down the energy ladder.  Operators $\hat{Q}$ and $\hat{P}$ linear combinations of $\hat{a}, \hat{a}^\dagger$. Their sum of squares ($\hat{Q}^2 + \hat{P}^2$) gives Number Operator $\hat{n}$ for total energy.
#   * Position/Momentum Form $\hat{H}=\frac{p^2}{2 m}+\frac{1}{2} m \omega^2 x^2$. [Quantum Harmonic Oscillation](https://en.wikipedia.org/wiki/Quantum_harmonic_oscillator) describes physical swap Kinetic $\leftrightarrow$ Potential = Time Evolution. Eg $t=0$: state in Position $Q$. Time evolution by $t=\frac{\pi}{2\omega}$ rotated $90^\circ$ to Momentum $P$ $\rightarrow$ is QFT!
#   * Everything in quantum physics can be mapped onto a ['Phase Space'](https://en.wikipedia.org/wiki/Phase_space) of position $Q$ and momentum $P$ ([Formulation](https://en.wikipedia.org/wiki/Phase-space_formulation))
#   * Mathematically, in QM Time is an Angle. In the expression $e^{-i\theta}$, $\theta$ must be a dimensionless number (an angle in radians). When we write the time-evolution operator as $\hat{U}(t) = e^{-i \hat{H} t / \hbar}$, the quantity $(\hat{H} t / \hbar)$ plays the role of that angle. In QM, states don't move along a trajectory like a baseball but its complex phase rotates. **If a system is in an energy eigenstate (Stationary State) with energy $E$, it stays in that state, but its phase "spins" at a frequency of $\omega = E/\hbar$.**
#
# 2. Unit Circle (Why Complex Numbers?)
#   * [Harmonic oscillator](https://en.wikipedia.org/wiki/Simple_harmonic_motion) moves back and forth: $x(t) = \cos(\omega t)$, described by real numbers: Position ($x$) and Velocity ($v$). Can combined to complex amplitude: $\alpha = x + i p$. Rotation keeps structure (unitary), rotates without changing magnitude (length).
#   * Annihilation operator $\hat{a}$ combines Position and Momentum into single complex number: $\hat{a} \propto \hat{Q} + i\hat{P}$. This is $x + iy$ (Euler) $\rightarrow$ Real Axis (Position) $\cos(\omega t)$. Imaginary Axis (Momentum) $i\sin(\omega t)$. Rotation (Time) $e^{i\omega t}$ = Oscillation between $Q$ and $P$
#   * Multiplying $\hat{a}$ by $e^{-i\omega t}$ rotates the vector in the complex plane. When the vector is horizontal (Real), the particle has maximum Position $Q$. When the vector is vertical (Imaginary), the particle has maximum Momentum $P$. **90° switch from X to Z = QFT.**
#
# 3. Exponentiation: Raise $e$ to power of position and momentum with $e^{-i \hat{G} \theta}$ to get from QHO to Quantum Operators
#   * $\hat{U} = e^{-i \hat{G} \theta}$ unitary is general form that describes movement of state in terms of fundamental operators $\hat{Q}$ and $\hat{P}$.
#     * $e^{i \theta}$ represents point on unit circle and keeps it unitary ($U^{\dagger}U=I$).
#     * $-i$ ensures transformation is rotation in Hilbert space that preserves length (norm) of state vector.
#     * $\hat{G}$ is a transformation. Parameter $\theta$ scales transformation.
#   * **Exponentiation** allows us to describe different transformations (gates). We just construct generator $\hat{G}$ with linear or non-linear combinations of fundamental operators $\hat{Q}$ + $\hat{P}$ (or $\hat{a}$ and $\hat{a}^\dagger$) or $\hat{X}$ and $\hat{Z}$ (modulo 𝑑) for qudit/qubit from Heisenberg-Weyl group. Exponentiation of unitary $\hat{U} = e^{-i \hat{H} t / \hbar}$ is defined and computed upon $[\hat{x}, \hat{p}] = i\hbar$ (CCR).
#     * If $\hat{G}$ is energy $\hat{H}$ (Hamiltonian), then $\hat{U} = e^{-i \hat{H} t / \hbar}$ where $\theta$ is duration of time $\frac{t}{\hbar}$ because because $\hat{H}$ is Time Evolution
#   * **Linear Transformations**: Generated by linear or quadratic functions ($\le 2^{\text{nd}}$ degree) of fundamental operators $\hat{Q}, \hat{P}$, or $\hat{X}$ and $\hat{Z}$ (modulo 𝑑). Not orthogonal and form overcomplete basis. Eigenstates of annihilation operator $\hat{a}$.
#   * **Non-Linear Transformations**: Generated by cubic or higher functions ($\ge 3^{\text{rd}}$ degree) of fundamental operators $\hat{Q}, \hat{P}$, or $\hat{X}$ and $\hat{Z}$ (modulo 𝑑). Break symmetry. Form orthonormal basis. Eigenstates of number operator $\hat{n} = \hat{a}^\dagger \hat{a}$.
#
# 4. Conjugate relation: An operator is a Generator of its conjugate variable's translation: This allows basis change $X$ <> $P$
#   * **Clock Z** *represents* Position (Potential) but *generates* Momentum Translation (Kick) - $D_{0,p} \sim Z^p$ applied (moves faster)
#   * **Shift X** *represents* Momentum (Kinetic) but *generates* Position Translation (Slide) - $D_{q,0} \sim X^q$ applied (new position)
#   * Connected via **Fourier Transform**. Used in $D_{q,p} = \tau^{qp} X^q Z^p$.  Based on commutation relation: $[x̂, p̂] = i ħ$ (for continuous), $ZX = \omega XZ$ (Weyl relation). For example in: Characteristic ($\chi(\xi)$) <> Wigner function.
#
# 5. Kinetic Energy $\hat{P}^2$ $\rightarrow$ Momentum $\hat{P} = \frac{i}{\sqrt{2}}(\hat{a}^\dagger - \hat{a})$ $\rightarrow$ Shift operator $X = e^{-i \hat{P} \delta}$ $\rightarrow$ Bit Flip/Pauli $X$. Generator linear in $\hat{P}$
#   * **Kinetic Energy $\hat{P}^2$** corresponds to hopping term/Laplacian $\approx (X + X^\dagger)$. (Real/Symmetric) > used in Google's OTOC.
#   * **Gaussian: Momentum** $\hat{P} = \frac{i}{\sqrt{2}}(\hat{a}^\dagger - \hat{a})$ $\rightarrow$ corresponds to derivative $\approx i(X^\dagger - X)$. (Complex/Imaginary, anti-symmetric)
#   * **Clifford (Qudit): Shift**  $\hat{X}^a |j\rangle = |j+1\rangle \pmod d\rangle$. |0⟩→|1⟩→|2⟩→|d−1⟩→|0⟩. Eigenvalues of $X$ are powers of $\omega$ (via Fourier). Because:  In "Momentum Basis", Shift operator is diagonal! Looks like Clock matrix. Because $X = \text{DFT}^\dagger \cdot Z \cdot \text{DFT}$.
#   * **Clifford (Qubit): Pauli X**: $\sigma_x |j\rangle = |j+1 \pmod 2\rangle$. Swaps 0<>1. $ZX = -XZ$. Phase is ω = $e^{i 2\pi/2}$ = -1, Eigenvalues 1, -1.
#   * **Conjugation relation: Shift $X$ *represents* Momentum (Kinetic) but *generates* Position Shift** - $D_{q,0} \sim X^q$ applied (new position). Matrix $X$ is Real and Off-Diagonal (Permutation matrix of 0s and 1s). Shift is exponentiated momentum $X \approx e^{-i \hat{P} \delta_x}$
#
# 6. Potential Energy $\hat{Q}^2$ $\rightarrow$ Position $\hat{Q} = \frac{1}{\sqrt{2}}(\hat{a} + \hat{a}^\dagger)$ $\rightarrow$ Clock operator $Z = e^{i \hat{Q} \delta}$ $\rightarrow$ Phase Flip/Pauli-$Z$. Generator linear in $\hat{Q}$
#   * **Gaussian: Position** $\hat{Q} = \frac{1}{\sqrt{2}}(\hat{a} + \hat{a}^\dagger)$ is observable. Position ($\hat{Q}$) observable has Real eigenvalues (location index $k$).
#   * **Clifford (Qudit): Clock** $\hat{Z}^b$ acts as $|k\rangle \rightarrow \omega^k |k\rangle$ where $\omega=e^{2\pi i/d}$ phase gradient + primitive $d$-th root unity (=Eigenvalues). $e^{ix}$ is clock phase gate $Z$ with complex eigenvalues on unit circle (phases $\omega^k$ on unit circle). Raised to $d$-th power ($\omega^0, \omega^1, \dots, \omega^{d-1}$) to generate $d$ solutions to tag each basis state k. For $d=3$, $\omega = e^{i 2\pi/3}$  (unitary but not Hermitian).
#   * **Clifford (Qubit): Phase Flip/Pauli $Z$**. $d=2$ primitive root of unity: $\omega_2 = e^{2\pi i / 2} = e^{i\pi} = -1$ $→$  $\sigma_z |j\rangle = (-1)^j |j\rangle = \omega^j |j\rangle$. This is mod 2 version: $ZX = -XZ (ω = -1)$. Adds a $-1$ phase to $\sigma_z |1\rangle = -|1\rangle$, but leaves $\sigma_z |0\rangle = |0\rangle$. = Pauli $Z$ matrix is both Unitary (preserves probabilities) and Hermitian (is its own conjugate). We can observe it directly.
#   * **Conjugation relation: Clock $Z$ *represents* Position (Potential) but *generates* Momentum (Kick)** - $D_{0,p} \sim Z^p$ applied (move faster). Matrix $Z$ complex Eigenvalues (phases on unit circle) and diagonal. Operator $\hat{Q}$ has real eigenvalues (location)
#
# 7. [Hamiltonian Operator](https://en.wikipedia.org/wiki/Hamiltonian_(quantum_mechanics)#Schr%C3%B6dinger_equation) generates [Time Evolution](https://en.wikipedia.org/wiki/Time_evolution) / Rotation / Basis Change. Generator is Quadratic $H = \hat{P}^2 + \hat{Q}^2$
#   * **Gaussian: Phase Shifter** $R(θ)=e^{-i \theta \hat{n}}$ rotates state by angle $θ$. For $θ=π/2$ (quarter turn), 90° = Fourier Transform. Generating operator is number operator $\hat{n}$ with Hamiltonian $H \propto \hat{Q}^2 + \hat{P}^2$ with rotation operator $R(θ)=e^{-i \theta (Q^2 + P^2)}$. $\hat{Q}$-$\hat{P}$ swap represents how potential and kinetic energy switch back and forth forever = basis change (rotation)
#   * **Clifford (Qudit): Quantum Fourier Transform (QFT)** is exactly Quarter period $\theta = \pi/2$ to rotate $Z$-eigenbasis (Position) into $X$-eigenbasis (Momentum) due to conjugate relation. Basis change by action on computational states $\text{QFT}*d |j \rangle$ =  ${0}^{d-1}  \omega^{jk} |k \rangle$. Basis change: maps single, localized basis state $|j\rangle$ into uniform superposition of all basis states tagged with phase $\omega^{jk}$. $W X W^\dagger = Z$. QFT turns Shift into Clock $\rightarrow$ QFT diagonalizes Shift $X$ operator. $W Z W^\dagger = X^\dagger$. Inverse QFT turns Clock into inverse Shift $\rightarrow$ Qudit $Z$ operator applies phase $\omega^j = e^{2\pi i j / d}$ based on *single* qudit index $j$.
#   * **Clifford (Qubit): Hadamard ($\hat{H}$)**. Conjugate relation allows basis change $Z$<>$X$  via equal superposition $H|0\rangle = |+\rangle$.
#   * Quadratic Generators $\hat{Q}^2 + \hat{P}^2$ geometrically generate rotations around origin of phase space. If you let a state evolve under this generator for a specific "time" or "angle," it's Quantum Fourier Transform. And angle is time in this setting!
#
# 8. [Displacement Operator](https://en.wikipedia.org/wiki/Displacement_operator) generates displacements in Phase Space. Generator is linear $G = q\hat{P} - p\hat{Q}$
#   * **Gaussian: Displacement** $\hat{D}(q, p) = e^{( -\frac{i}{\hbar} (q\hat{P} - p\hat{Q})}$ with generator $H  \propto (q\hat{P} - p\hat{Q})$. Where $H \propto \hat{P} \rightarrow$ generates shift in $Q$. And $H \propto \hat{Q} \rightarrow$ generates shift in $P$. Here called: position / momentum.
#   * **Clifford (Qudit): Displacement** $D_{q,p} = e^{i\pi qp/d} X^q Z^p$. Via Heisenberg-Weyl with of all combinations of shifts and clock/ phases ($X^q Z^p$). Phase factor $e^{i\pi qp/d}$ required because $X$ and $Z$ do not commute (Aharonov-Bohm effect in phase space).
#   * Linear Generators $q\hat{P} - p\hat{Q}$  geometrically don't rotate state around origin but slide to new location (q,p) in phase space
#
# 9. Special Quantum Operators
# * <font color="blue">*Special: Gaussian: Pauli-Y*</font>
#   * is just a product, not independent operator! In qubit $\sigma_y = i \sigma_x \sigma_z$ is just combination of bit and phase flip. For qudits: family of Generalized Pauli Operators defined by product of shifts and clocks: $P_{q,p} = X^q Z^p$.
#   * **For $d=2$ (Qubits):** $X^1 Z^0 = X$ and $X^0 Z^1 = Z$ and $X^1 Z^1 \propto Y$ ($Y$ is just $(1,1)$ point on the grid).
#   * **For $d=3$ (Qutrits):** $X Z$, $X Z^2$, $X^2 Z$, etc. None of these is uniquely called "$Y$". "Pauli $Y$" doesn't vanish; it just becomes one of the many $D_{q,p}$ displacement operators ($q \neq 0, p \neq 0$)
# * <font color="blue">*Special: Shear/Phase Gate*</font>
#   * Gaussian: **Quadratic Phase (Shear)**: Generator $H \propto \hat{Q}^2$. Hamiltonian $H \propto \hat{Q}^2$ (a "Kerr" nonlinearity or a Shear) preserves Position $Q$ but shears Momentum $P \to P + Q$.
#   * Clifford (Qubit): **Phase Gate ($\hat{S}$ or $\hat{P}$)**. $Z \to Z$, $X \to Y \sim XZ$. Phase gate is diagonal. $S = \text{diag}(1, i, \dots)$. It adds a quadratic phase $k^2$ to the wavefunction.
# * <font color="blue">*Special: Entanglement*</font>
#   * **Gaussian: Squeezer + Beam Splitter = Entanglement** $\approx$ CNOT.  Squeeze state to ellipse, then rotate ellipse 45° via Beam Splitter $\rightarrow$ noise becomes correlated between two axes = this is Entanglement. **Squeezer** is $\hat{S}(r) = e^{\left( -\frac{i r}{2\hbar} (\hat{Q}^2 - \hat{P}^2)\right)}$ with generator $H \propto (\hat{Q}^2 - \hat{P}^2)$ $= \hat{Q}\hat{P} + \hat{P}\hat{Q}$. Scales axes: stretches $Q$ and shrinks $P$ (or vice versa). Multiplies position by $e^{-r}$ and momentum by $e^r$. **Beam Splitter** $\hat{B}(\theta) = e^{-i \theta (\hat{Q}_1 \hat{P}_2 - \hat{Q}_2 \hat{P}_1)}$ with generator $H \propto \hat{Q}_1\hat{P}_2 - \hat{Q}_2\hat{P}_1$. This is the angular momentum operator in phase space. It performs passive rotation between two modes.If $\theta = \pi/4$ (50:50 Beam Splitter), it mixes the two inputs equally:$\hat{a}_1 \to \frac{\hat{a}_1 + \hat{a}_2}{\sqrt{2}}$ and $\hat{a}_2 \to \frac{\hat{a}_1 - \hat{a}_2}{\sqrt{2}}$.
#   * **Clifford (Qudit): C-SUM ($CX$)** $|c\rangle|t\rangle \to |c\rangle|t \oplus c\rangle  \pmod d\rangle$.  Adds control bit to target bit modulo d. $\hat{C}_{\text{SUM}} = e^{-i \hat{Q}_1 \hat{P}_2}$ with generator $\hat{Q}_1 \hat{P}_2$. Couples Position particle 1 to Momentum (shift) particle 2. C-SUM gate built via: Beam Splitter + Squeezing + Inverse Beam Splitter
#   * **Clifford (Qubit): CNOT**. $|c\rangle|t\rangle \to |c\rangle|t \oplus c\rangle  \pmod 2\rangle$. Adds control bit to target bit modulo 2.
# * <font color="blue">*Special: Cubic Phase $\rightarrow$ here begins non-simulatable magic states*</font>
#   * **Non-Gaussian: Cubic Phase** $\hat{U} = e^{i\gamma \hat{Q}^3}$ with generator $H \propto \hat{Q}^3$.  Cubic Phase gate $V(\gamma) = e^{i \gamma \hat{Q}^3}$ distorts phase space. A circle (coherent state) becomes a "banana" shape with negative Wigner function regions—the signature of non-classicality.
#   * **Non-Clifford (Qudit): Discrete Cubic Phase ($\hat{T}_d$)** (mod d). Generalized Magic Gates, often diagonal phases like $e^{i \frac{2\pi}{d^3} k^3}$. Corresponds to degree-3 polynomial phases: $T_d |k\rangle = \omega^{k^3} |k\rangle$. Exactly analogous to the cubic phase gate: $V(\gamma) = e^{i\gamma \hat{x}^3}$.
#   * **Non-Clifford (QUBIT): $\hat{T}$-gate** (magic gate) degree-3 (or $\pi/8$ gate): $\hat{T} = e^{-i \pi/8 \hat{Z}}$ - is cubic phase in discrete phase space (mod 2) : $\pi/8$ phase. The Clifford group maps Pauli operators to Pauli operators (Level 2).
# * <font color="blue">*Special: Other Operators*</font>
#   * **Non-Gaussian: Kerr** $\hat{U} = e^{i\chi \hat{n}^2}$ where $\hat{n} = \hat{a}^\dagger \hat{a}$. Generator $\propto (\hat{Q}^2 + \hat{P}^2)^2$ (quartic). Since $\hat{n} \sim Q^2 + P^2$, then $\hat{n}^2 \sim (Q^2 + P^2)^2 \sim Q^4 + \dots$This is a Quartic (4th order) potential. This represents a medium where the refractive index changes based on intensity. In computation, it is often used to build "Cat States" (macroscopic superpositions), which are excellent candidates for error-corrected logical qubits (Bosonic Codes).
#   * **Non-Clifford (Qudit): General high-order phase gates**
#   * **Non-Clifford (QUBIT): Toffoli Gate** (also Non-Clifford and Universal with $\hat{H}$ and $\hat{T}$)

# %% [markdown]
# <font color="blue">**Unity Root and Cycle Tracing**
#
# **Unity Root**
#
# Einheitswurzeln heißen so, weil sie eine Wurzel (also eine Lösung einer Gleichung) der Zahl 1 (der „Einheit“) sind. Wenn man eine solche Zahl n-mal mit sich selbst malnimmt (n-te Potenz), kommt genau die Zahl 1 heraus.
#
# Bedeutung der Wörter
# * Einheit: In der Mathematik wird die Zahl 1 oft als „Einheit“ bezeichnet (wie das lateinische Wort unitas für Eins).
# * Wurzel: Das ist die Zahl, die gesucht wird, wenn man eine Potenz rückgängig machen möchte (so wie die normale Quadratwurzel aus 9 die Zahl 3 macht, weil 3² = 9).
#
# Kurze Erklärung am Beispiel
# * Gesucht sind Zahlen $z$, für die gilt: $z^n = 1$ (also z hoch n gleich 1).
# * Die normale Zahl 1 ist immer eine Lösung (1² = 1, 1³ = 1, etc.).
# * Bei komplexen Zahlen gibt es aber noch mehr Lösungen, zum Beispiel bei der 4. Einheitswurzel (z⁴ = 1) auch die Zahl i oder -1 und -i, weil diese Werte hoch 4 ebenfalls den Wert 1 ergeben.
# * Geometrisch liegen all diese Zahlen wie ein sauberer Kreis auf dem Einheitskreis in der Ebene.
#
# Möchtest du wissen, wie man diese Zahlen im Kreis einzeichnet oder brauchst du ein Beispiel für eine bestimmte Potenz (wie die 3. oder 4. Einheitswurzel)?
#
# **Was bedeutet das dann: e^(2πi/d) ist speziell die primitive Wurzel: die, deren Potenzen alle anderen erzeugen.**
#
# Das bedeutet, dass dieser spezielle Wert wie ein „Generatorschlüssel“ funktioniert. Wenn du diese eine Zahl immer wieder mit sich selbst multiplizierst (sie potenzierst), erzeugst du nacheinander alle anderen Einheitswurzeln für diese Zahl $d$.
# Das Wort „primitiv“ kommt hier vom lateinischen primitivus („zuerst entstanden“ oder „ursprünglich“), weil aus ihr alle anderen Wurzeln geboren werden.
#
# *So funktioniert das Erzeugen*
#
# Wenn wir die Zahl $\zeta = e^{\frac{2\pi i}{d}}$ nennen, entstehen die anderen Wurzeln durch ihre Potenzen:
#
# * 1. Potenz: $\zeta^1 = e^{\frac{2\pi i}{d}}$ (Die erste Wurzel, ein Schritt auf dem Kreis)
# * 2. Potenz: $\zeta^2 = e^{\frac{4\pi i}{d}}$ (Die zweite Wurzel, zwei Schritte)
# * 3. Potenz: $\zeta^3 = e^{\frac{6\pi i}{d}}$ (Die dritte Wurzel, drei Schritte)
# * Letzte Potenz: $\zeta^d = e^{2\pi i} = 1$ (Nach $d$ Schritten bist du einmal komplett um den Kreis herum und landest wieder bei der 1)
#
# Weil du auf diesem Weg jede einzelne der $d$ Lösungen genau einmal triffst, nennt man diese Ausgangszahl die primitive Wurzel.
#
#
# *Das Bild im Kopf: Ein Kuchen mit $d$ Stücken*
#
# * Der Ausdruck $2\pi$ steht in der Mathematik für einen kompletten Kreis ($360^\circ$).
# * Der Nenner $d$ teilt diesen Kreis in $d$ gleich große Tortenstücke.
# * Das $i$ im Exponenten sorgt dafür, dass wir uns auf diesem Kreis bewegen.
# * Die Zahl $e^{\frac{2\pi i}{d}}$ ist exakt die erste Ecke des allerersten Tortenstücks (wenn man bei der 1 startet und gegen den Uhrzeigersinn geht).
# * Nimmst du diese Ecke hoch 2, springst du zur zweiten Ecke. Nimmst du sie hoch 3, zur dritten. Du „erzeugst“ Schritt für Schritt das ganze Muster.
#
# Möchtest du sehen, wie das konkret für ein festes $d$ (z. B. $d = 4$ oder $d = 3$) aussieht, oder interessiert dich, warum manche andere Wurzeln nicht primitiv sind?

# %% [markdown]
# <font color="blue">**Heisenberg–Weyl-Algebra in Quantum Computing — von der Tensoralgebra bis zu Magic States**
#
# > **Die ganze QC-Geschichte ist *eine* Bühne (der HW-/Phasenraum) plus *ein* Knopf (der Polynomgrad des Generators). Qubits, Qudits, der harmonische Oszillator, Simulierbarkeit, Magic States — alles spielt auf dieser einen symplektischen Bühne.**
#
# <font color="blue">*A. Herkunft — woher die HW-Algebra kommt*
#
# 1. Die Wurzel: die Tensoralgebra $T(V)$. Nimm einen Vektorraum $V$. Die **Tensoralgebra**
#
# $$T(V)=\mathbb C\oplus V\oplus(V\otimes V)\oplus\cdots$$
#
# ist die „freie" Algebra: man schreibt Vektoren einfach nebeneinander ($v\otimes w$), und es gilt *keine* Regel außer Assoziativität. Der wilde Urzustand — noch keine Geometrie, keine Physik. (→ Abschnitt *Tensor Algebra*.)
#
# 2. Der eine Schritt: eine Regel aufzwingen (Quotient).
#
# * Struktur entsteht, indem man **eine** Rechenregel erzwingt — technisch: Quotient nach einem Ideal („ab jetzt sei dieser Ausdruck null"). Die Regel kommt von einer **Bilinearform** auf $V$. Je nach **Parität der Form** gabelt sich der Stammbaum in genau zwei Welten:
#
# $$\underbrace{\mathrm{Cl}(V,Q)=T(V)\big/\langle\,v\otimes v-Q(v)\mathbf 1\,\rangle}_{\text{symmetrisch }Q\ \to\ \textbf{GA, der andere Ast}}\qquad \underbrace{\mathcal W(V,\omega)=T(V)\big/\langle\,v\otimes w-w\otimes v-\omega(v,w)\mathbf 1\,\rangle}_{\text{antisymmetrisch }\omega\ \to\ \textbf{HW, unser Fokus}}$$
#
# Die HW-Regel $v\otimes w-w\otimes v=\omega(v,w)\mathbf 1$ besagt: *die Reihenfolge zweier Vektoren unterscheidet sich um eine Zahl* — den orientierten Flächeninhalt $\omega(v,w)$ des aufgespannten Parallelogramms im Phasenraum. Das ist die Geometrie von **Ort und Impuls**. (Der linke Ast — symmetrische Form, Längen, Rotoren — ist die Geometrische Algebra; siehe eigene Sektion. Ab hier nur noch rechts.)
#
# 3. Welche Richtung ist welche. Der elegante Punkt: deformierende Form und entstehendes Grundobjekt haben *entgegengesetzte* Parität.
#
# | | deformiert mit | ⟶ Vertauschungsregel | „freies" <br>Grundobjekt | lineare Gruppe | Teilchen |
# |---|---|---|---|---|---|
# | Clifford/GA *(am Rand)* | **symmetrischer** Form $Q$ | $vw+wv=2B(v,w)$ <br>— antikommutativ (CAR) | $\Lambda(V)$ | $O(V)$, $\mathrm{Spin}$ — orthogonal | Fermionen |
# | **Heisenberg–Weyl** | **antisymmetrischer** Form $\omega$ | $vw-wv=\omega(v,w)$ <br>— kommutativ (CCR) | $\mathrm{Sym}(V)$ | $Sp(V)$ — **symplektisch** | **Bosonen** |
#
# Zwei Lesehilfen: **(i)** „CCR" (Kommutator-Relation) heißt *nicht*, dass Bosonen vertauschen — sie heißt nur, die Struktur ist *kommutator*-basiert, im Gegensatz zum *Anti*kommutator (CAR) der Fermionen. **(ii)** $\mathcal W(V,\omega)$ ist konkret die universelle Einhüllende der **Heisenberg-Lie-Algebra** $\mathfrak h=\langle q,p,z\rangle$, $[q,p]=z$, $z$ zentral, modulo $z=\mathbf 1$ — daraus wird gleich $[\hat Q,\hat P]=i\hbar$.
#
# <font color="blue">*B. Die diskrete HW-Welt — Qubits und Qudits*
#
# 4. Clock & Shift, die Weyl-Relation.
#
# * Für Quantencomputer nimmt man die *endliche* HW-Welt über $\mathbb Z_d$: zwei unitäre Operatoren,
#
# $$\text{Shift } X\lvert j\rangle=\lvert j{+}1\bmod d\rangle,\qquad \text{Clock } Z\lvert j\rangle=\omega^j\lvert j\rangle,\qquad \omega=e^{2\pi i/d}.$$
#
# Ihre **eine** definierende Regel ist das diskrete Gegenstück zu $vw-wv=\omega(v,w)$:
#
# $$\boxed{\;ZX=\omega\,XZ\;}$$
#
# > **Rechenbeispiel — Qutrit ($d=3$), $\omega=e^{2\pi i/3}$.**
# > $$X=\begin{pmatrix}0&0&1\\1&0&0\\0&1&0\end{pmatrix},\qquad Z=\begin{pmatrix}1&0&0\\0&\omega&0\\0&0&\omega^{2}\end{pmatrix}.$$
# > Probe: $ZX\lvert j\rangle=Z\lvert j{+}1\rangle=\omega^{j+1}\lvert j{+}1\rangle$, aber $XZ\lvert j\rangle=\omega^{j}\lvert j{+}1\rangle$, also $ZX=\omega XZ\ \checkmark$. Für $d=2$ ist $\omega=-1$, und $X,Z$ werden zu $\sigma_x,\sigma_z$ mit $ZX=-XZ$.
#
# 5. Die Pauli-Gruppe trägt die symplektische Form.
#
# * Die von allen $X_i,Z_i$ erzeugte **Pauli-Gruppe** $\mathcal P_n$ ist eine *zentrale Erweiterung* — eine Gruppe, die aus „Labels" $(\mathbf a,\mathbf b)\in\mathbb Z_d^{2n}$ plus einer Phase besteht:
#
# $$1\longrightarrow \underbrace{\mathbb Z_d}_{\text{Phasen}}\longrightarrow \mathcal P_n \longrightarrow \underbrace{\mathbb Z_d^{2n}}_{\text{Labels}}\longrightarrow 1.$$
#
# Der Witz: schreibt man Pauli-Operatoren als $D(\mathbf a,\mathbf b)=\prod_i X_i^{a_i}Z_i^{b_i}$, ist die **Phase beim Vertauschen genau die symplektische Form** auf den Labels:
#
# $$D(\mathbf a,\mathbf b)\,D(\mathbf a',\mathbf b')=\omega^{\,\langle(\mathbf a,\mathbf b),(\mathbf a',\mathbf b')\rangle}\,D(\mathbf a',\mathbf b')\,D(\mathbf a,\mathbf b),\qquad \langle\cdot,\cdot\rangle=\mathbf a\!\cdot\!\mathbf b'-\mathbf a'\!\cdot\!\mathbf b.$$
#
# Man rechnet also nicht mehr mit Matrizen, sondern nur noch mit *Vektoren über $\mathbb Z_d$* und ihrer symplektischen Paarung. **Fazit: Qudits sitzen für jedes $d$ auf der symplektischen HW-Seite — auch Qubits ($d=2$).** Das ist der Hebel für alles Folgende.
#
# <font color="blue">*C. Die Symmetrien der Bühne — die Clifford-Gruppe*
#
# 6. Die Quanten-Clifford-Gruppe $=$ Normalisator von $\mathcal P_n$.
#
# * Die natürlichste Frage: welche Gatter $U$ bilden die Pauli-Gruppe *auf sich selbst* ab? Antwort — die **Clifford-Gruppe**:
#
# $$\mathcal C_n=N_{U(d^n)}(\mathcal P_n)=\bigl\{\,U:\ U\,\mathcal P_n\,U^{\dagger}=\mathcal P_n\,\bigr\}.$$
#
# Weil $U$ die Struktur $ZX=\omega XZ$ erhält, ist seine ganze Wirkung durch eine $2n\times2n$-Matrix über $\mathbb Z_d$ beschrieben — eine *lineare* Symmetrie der symplektischen Labels (für primes $d$):
#
# $$\boxed{\;\mathcal C_n\big/\bigl(\mathcal P_n\cdot U(1)\bigr)\;\cong\;Sp(2n,\mathbb Z_d)\;}$$
#
# **Wichtige Klarstellung (GA am Rand):** *Clifford*-Gruppe heißt sie aus historisch-strukturellen Gründen (dieselbe „Normalisator einer Erzeugermenge"-Figur wie bei der echten Clifford-Algebra), **nicht** weil eine Clifford-Algebra im Spiel wäre. Ihre Strukturgruppe ist **symplektisch** ($Sp$), nicht orthogonal ($\mathrm{Spin}$). Die echte orthogonale Clifford-Welt sitzt anderswo (Fermionen/Matchgates; eigene Sektion). Bei $d=2$ verschmelzen beide *akzidentell* über $\mathbb F_2$ — verschwindet für $d>2$.
#
# > **Rechenbeispiel — Clifford-Gatter als symplektische Matrizen ($d=2$).** Schreibe einen Pauli als $(x\,|\,z)^{\mathsf T}$: $X=(1|0)$, $Z=(0|1)$, $Y\sim(1|1)$. Dann
# > $$H:\ \begin{cases}X\mapsto Z\\ Z\mapsto X\end{cases}\Rightarrow M_H=\begin{pmatrix}0&1\\1&0\end{pmatrix},\qquad S:\ \begin{cases}X\mapsto Y\\ Z\mapsto Z\end{cases}\Rightarrow M_S=\begin{pmatrix}1&0\\1&1\end{pmatrix}.$$
# > Beide $\in Sp(2,\mathbb F_2)$. Das **$T$-Gate** dagegen schickt $X\mapsto\tfrac1{\sqrt2}(X+Y)$ — eine *Summe* von Paulis, **keine** lineare Permutation mehr; es fällt aus $\mathcal C_n$ heraus.
#
# 7. Die Clifford-Hierarchie (Gottesman–Chuang).
#
# * Sie ordnet *alle* Gatter rekursiv nach „wie weit weg von Pauli":
#
# $$\mathcal C^{(1)}=\mathcal P_n,\qquad \mathcal C^{(k)}=\bigl\{\,U:\ U\,\mathcal P_n\,U^{\dagger}\subseteq \mathcal C^{(k-1)}\,\bigr\}.$$
#
# $\mathcal C^{(2)}=\mathcal C_n$ ist die Clifford-Gruppe — die **letzte Stufe, die noch eine Gruppe ist**. Das $T$-Gate (Qubits) und das Qudit-Cubic-Phase-Gate liegen in $\mathcal C^{(3)}$: sie bilden Paulis auf *Cliffords* ab, aber nicht mehr auf Paulis. Diese Stufe-3-Gatter sind genau die „magischen" — siehe Teil E.
#
# <font color="blue">*D. Die Grenze der klassischen Simulierbarkeit*
#
# 8. Gottesman–Knill-Theorem.
#
# * Schaltkreise aus *nur* Clifford-Gattern (mit Standardbasis-Präparation und -Messung) sind **klassisch effizient simulierbar**. Grund: Statt den $d^{\,n}$-dimensionalen Zustandsvektor zu verfolgen, trackt man im Heisenberg-Bild nur, *wie sich die Pauli-Erzeuger transformieren* — ein **symplektisches Tableau-Update** über $\mathbb Z_d$, also eine $O(n^2)$-Matrixoperation. Das ist das formale Herzstück: $\mathcal C_n/\mathcal P_n\cong Sp(2n,\mathbb Z_d)$, und symplektische Matrizen aktualisiert man trivial. Ein Quantencomputer aus reinen Clifford-Gattern bietet also **keinen** Speedup.
#
# 9. Wigner-Negativität als Ressource.
#
# * Warum reicht Clifford nicht? Die Wigner-Funktion $W(q,p)$ ist eine „Wahrscheinlichkeitsverteilung" im Phasenraum — solange sie überall $\ge 0$ bleibt, verhält sich der Zustand klassisch.
#
# * **Kontinuierlich — Hudsons Theorem (1974):** Ein reiner Zustand hat *überall* $W\ge 0$ **genau dann**, wenn er **Gaußsch** ist.
# * **Diskret — Gross' Wigner-Funktion (ungerades $d$):** $W\ge 0\Rightarrow$ effizient simulierbar (Veitch–Ferrie–Gross–Emerson; Mari–Eisert; Howard et al.). **Wigner-Negativität ist eine *notwendige* Ressource** für jeden Quantenvorteil.
#
# Clifford-Operationen *erhalten* $W\ge 0$ (sie permutieren den Phasenraum nur starr); erst ein Stufe-3-Gatter erzeugt negative Regionen — **Magic States** — und schaltet die Universalität frei (*Magic State Distillation*).
#
# | | erhält $W\ge 0$? | simulierbar? | Gruppe |
# |---|---|---|---|
# | Pauli $\mathcal C^{(1)}$ | ✓ | ✓ | $\mathbb Z_d^{2n}$ (Translationen) |
# | Clifford $\mathcal C^{(2)}$ | ✓ | ✓ (Gottesman–Knill) | $Sp(2n,\mathbb Z_d)$ |
# | $T$ / Cubic-Phase $\mathcal C^{(3)}$ | ✗ | ✗ | **keine Gruppe** |
#
# <font color="blue">*E. Der kontinuierliche Limes und der Gradfilter — bis zu den Magic States*
#
# 10. Der Limes $d\to\infty$.
#
# * Macht man das diskrete Qudit-„Zifferblatt" unendlich fein, wird aus dem zyklischen Gitter die flache Phasenraum-Ebene: Shift $X\to$ Impuls $\hat P$ (Translation), Clock $Z\to$ Ort $\hat Q$. Die endliche Weyl-Relation geht in die **kontinuierliche CCR** über:
#
# $$ZX=\omega XZ\quad\xrightarrow{\;d\to\infty\;}\quad [\hat Q,\hat P]=i\hbar\,\mathbf 1.$$
#
# Diskrete Qudits und der kontinuierliche harmonische Oszillator sind also *dieselbe* HW-Bühne, nur in feinerer Auflösung. (→ Abschnitt *Exponentiation … HW Algebra*.)
#
# 11. Der entscheidende Filter — Polynomgrad des Generators.
#
# * Jedes Gatter $U=e^{-i\hat H t}$ kommt von einem Hamiltonian $\hat H$. Die Trennlinie zwischen „zahm/simulierbar" und „magisch/universell" verläuft exakt beim **Polynomgrad von $\hat H$** in $(\hat Q,\hat P)$ — das ist *der eine Knopf*, diskret wie kontinuierlich:
#
# | Grad von $\hat H$ | erzeugt (CV) | Gruppe (CV) | diskretes Pendant | Wigner | simulierbar? |
# |---|---|---|---|---|---|
# | $\le 1$ | Displacement | (Translationen) | Pauli $\mathcal P_n$ | $\ge 0$ | ✓ |
# | $2$ | Rotation / Squeeze / Fourier | $Sp(2n,\mathbb R)$ → metaplektisch $\mathrm{Mp}$ (**Gauß**) | Clifford $\mathcal C_n$ | $\ge 0$ | ✓ |
# | $\ge 3$ | Cubic Phase, Kerr | **nicht-Gauß** | $T$ / Qudit-Cubic $\in\mathcal C^{(3)}$ | $<0$ möglich | ✗ |
#
# > **Die zentrale Analogie:** *Quanten-Clifford-Gatter (diskrete Qudits)* $\;\longleftrightarrow\;$ *Gaußsche Operationen (Squeezer, Beam Splitter; lineare Optik)*. Beide sind die **quadratische/symplektische Stufe** — diskret $Sp(2n,\mathbb Z_d)$, kontinuierlich $Sp(2n,\mathbb R)$.
#
# 12. Der Ausbruch in die Nicht-Linearität — Magic States.
#
# * Das **Cubic Phase Gate** $\hat U=e^{i\gamma\hat Q^{3}}$ ist der kanonische Grad-3-Generator. Es *schert* den Phasenraum quadratisch:
#
# $$\hat U^{\dagger}\,\hat Q\,\hat U=\hat Q,\qquad \hat U^{\dagger}\,\hat P\,\hat U=\hat P+3\gamma\hbar\,\hat Q^{2}.$$
#
# > **Rechnung (BCH).** Mit $A=i\gamma\hat Q^3$ und $[\hat Q^3,\hat P]=3i\hbar\hat Q^2$:
# > $$e^{-A}\hat P\,e^{A}=\hat P+[-A,\hat P]+\tfrac12[-A,[-A,\hat P]]+\cdots=\hat P-i\gamma(3i\hbar\hat Q^2)+0=\hat P+3\gamma\hbar\hat Q^2.$$
# > Ein *quadratisches* $\hat Q^2$ verschöbe $\hat P$ nur *linear* ($\hat P\mapsto\hat P+c\hat Q$, symplektisch); das *kubische* Gate schert *nicht-linear* — der runde Wigner-Fleck wird zur „Banane", in deren Innenbiegung $W < 0$ kippt. Genau das ist die Ressource.
#
# * **Diskretes Pendant.** Das exakte Qudit-Analogon zu $\hat Q^3$ ist $\operatorname{diag}(\omega^{j^{3}})$; für Qubits ist es (bis auf Cliffords) das **$T$-Gate**. *Präzise:* Das $T$-Gate **ist** nicht buchstäblich das Cubic-Phase-Gate, sondern sein **Analogon** als Stufe-3-Generator — beide liefern „Magie"/Wigner-Negativität.
# * **Kerr-Effekt (Grad 4).** $\hat n^{2}=(\hat a^{\dagger}\hat a)^{2}\approx(\hat Q^2+\hat P^2)^2$ ist quartisch; er schmiert den Phasenraum ringförmig und erzeugt **Schrödinger-Katzen-Zustände** (Cat-Qubits, bosonische Codes).
#
# > **Die feine, aber zentrale Unterscheidung — Raum vs. Gruppe.** Ab Grad 3 verlässt du die symplektische **Gruppe** $Sp$ (die Clifford-/Gauß-Symmetrien) — *deshalb* Magie und Universalität. Du verlässt aber **nie** den symplektischen **Raum** (die HW-Bühne selbst): das $T$-Gate ist immer noch ein Operator auf demselben Pauli/HW-Hilbertraum, nur eben keine *lineare* Symmetrie davon mehr. *Bild:* Der Phasenraum ist das Blatt Papier (HW, immer da); $Sp$ sind die starren Bewegungen des Blatts; das $T$-Gate ist ein Stift, der eine *gekrümmte* Linie aufs selbe Blatt zeichnet. **Genau deshalb bleibt HW der Großmeister — auch die magischen Gates leben auf seiner Bühne.**
#
# <font color="blue">*Quick Reference — Heisenberg–Weyl in QC*
#
# * $T(V)$ — Tensoralgebra, freie „Mutter"; HW $=$ Quotient mit antisymmetrischer Form $\omega$.
# * $\mathcal W(V,\omega)=T(V)/\langle vw-wv-\omega\,\mathbf 1\rangle=U(\mathfrak h)/(z{=}1)$; $\mathrm{gr}\,\mathcal W\cong\mathrm{Sym}(V)$.
# * CCR $[\hat Q,\hat P]=i\hbar\mathbf 1$, $[\hat a,\hat a^\dagger]=\mathbf 1$ — kontinuierlich; $d\to\infty$-Limes der Qudits.
# * $Z,X$ mit $ZX=\omega XZ$, $\omega=e^{2\pi i/d}$ — diskrete HW-Erzeuger (Clock/Shift).
# * $\mathcal P_n$ — Pauli-Gruppe; zentrale Erweiterung von $\mathbb Z_d^{2n}$, Kommutator $=$ symplektische Form.
# * $\mathcal C_n=N_{U(d^n)}(\mathcal P_n)$, $\;\mathcal C_n/(\mathcal P_n U(1))\cong Sp(2n,\mathbb Z_d)$ — symplektisch, *nicht* orthogonal.
# * $\mathcal C^{(k)}$ — Clifford-Hierarchie; $\mathcal C^{(2)}$ letzte Gruppe, $T\in\mathcal C^{(3)}$.
# * Gottesman–Knill — Clifford simulierbar via symplektisches Tableau ($O(n^2)$).
# * $W(q,p)$ — Wigner-Funktion; Negativität $=$ notwendige Ressource (Hudson CV; Gross diskret).
# * Gradfilter — $\le 1$ Displacement · $2$ Gauß/Clifford ($Sp$, $W\ge0$, simulierbar) · $\ge 3$ Cubic/$T$/Kerr (nicht-Gauß, $W < 0$, universell).
#
# **Drei Merksätze.**
# 1. **HW ist die Bühne** für *alles* in QC: Qubits, Qudits, harmonischer Oszillator, Stabilisatoren, Magic States — eine symplektische Welt, Quotient von $T(V)$ mit antisymmetrischer Form. (GA $=$ der andere, orthogonale Ast; in QC nur bei Einzel-Qubit-Rotoren und Fermionen sichtbar.)
# 2. **Die „Clifford-Gruppe" der QI ist symplektisch** ($Sp(2n,\mathbb Z_d)$), trotz des Namens — die linearen Symmetrien der HW-Bühne, Grad-$\le 2$.
# 3. **Der eine Knopf ist der Polynomgrad:** $\le 2$ = Gauß/Clifford = simulierbar = $W\ge0$; $\ge 3$ ($T$-Gate, Cubic Phase, Kerr) verlässt die *Gruppe* $Sp$ (nicht den *Raum* HW), erzeugt $W<0$ und schaltet den echten Quantencomputer frei.

# %% [markdown]
# ##### <font color="blue">*Quantum Dynamics*

# %% [markdown]
# <font color="blue">**Schrödinger Equation  $|\psi(t)\rangle = e^{-iHt} |\psi(0)\rangle$**
#
# Quantum systems in chemistry and physics can be described and computed with either classical and quantum methods:
#
# * **Model**: Classical (Newton Mechanics) vs Quantum (Schrödinger equation)
# * **Type**: Static (State) vs Dynamical (Evolution)
# * **Computing**: Classical Computing vs Quantum Computing
#
# <font color="blue">*1. Classical (Newtonian) Mechanics (**Static and Dynamic**): $F = m \cdot a$*
# * Ignores electrons and consider atoms as spheres connected by springs (force fields)
# * **Classical - Dynamic**: Molecular dynamics (MD). How proteins enfold and move? GROMACS, NAMD, AMBER.
# * **Classical - Static**: Molecular Docking / Energy Minimization. Geometrically: Does medication fit to enzyme? AutoDock, Rosetta.
# * **Quantum computing methods:** Future: Navier Stokes (fluid dynamics) with HHL to solve linear systems and differential equations exponentially faster than classical computers. For weather and climate: simulate weather with a much finer grid (e.g. 100m)
#
# <font color="blue">*2. Quantum Mechanics (**Static**): Time-independent Schrödinger Equation $\hat{H}|\psi\rangle = E|\psi\rangle$*
# * Includes electrons. **Approximates Ground State via optimization** with variation $\delta \langle H \rangle = 0$ to find global optimum in energy landscape. Stationary state important for calculating binding energies: If $\psi$ is an eigenstate of $\hat{H}$, then time evolution is trivial: $\Psi(t) = \psi e^{-iEt/\hbar}$. Probability density $|\Psi(t)|^2$ remains constant over time = states are stationary.
# * **Classical computing:** Hartree-Fock (mean field of $\psi$) but ignore correlation energies, DFT (electron density $\rho$) approximates correlation energies with functionals (but require correct functional assumed), Post-HF (Coupled cluster, configuration interaction) calculate correlation energies but only small systems since their complexity grows exponentially
# * **Quantum computing** (**NISQ**): Variational Quantum Eigensolver. Quantum Advantage: finds correlation energy with entanglement.
#   * In classical quantum chemistry, correlation energies are either ignored (HF), approximated (DFT), or, while theoretically calculable exactly, are only feasible for small quantum systems (post-Hartree-Fock methods like coupled cluster or configuration interaction).
#   * For classical computers, complexity grows exponentially, this is why quantum computers will play a significant role in analyzing larger, more complex systems.
#
# <font color="blue">*3. Quantum Mechanics (**Dynamic**): Time-dependent Schrödinger Equation $i\hbar \frac{\partial}{\partial t} \Psi(\mathbf{r}, t) = \hat{H} \Psi(\mathbf{r}, t)$*
# * **Simulate Time Evolution** $e^{-i\hat{H}t}$ of Quantum State $|\Psi(t)\rangle = e^{-i\hat{H}t/\hbar} |\Psi(0)\rangle$ via Unitary Transformation. For Quantum Chaos, OTOC, Scrambling (Black Holes) reaction dynamics (observe how bonds break and reform during a collision). No forward theorem!
# * **Classical computing**: Time-Dependent DFT (TD-DFT) used to classically calculate excitations (fluorescence, spectra). However only for short times and small systems. To solve the time-dependent equation $i\hbar \frac{\partial}{\partial t} \Psi = \hat{H} \Psi$ classically at scale, you have to apply operator $e^{-i\hat{H}t/\hbar}$ to wavefunction. In system with $N$ particles, complexity grows exponentially with $N$.
# * **Quantum computing** (**Fault-Tolerant**): Central challenge in quantum dynamics (Simulating Quantum Time Evolution):
#   * Molecule evolves under all its forces (Kinetic + Potential) simultaneously, but QC can only do one. But unitary propagator $U(t) = e^{-i\hat{H}t}$ is implemented on quantum hardware that only supports a discrete set of elementary gates at once.
#   * Three approaches: LCU, Trotterization, Qubitization (with Quantum Walks and Block Encoding). And with the OTOC metric to measure information scrambling during quantum evolution (https://research.google/blog/a-verifiable-quantum-advantage/)
#
#
# <font color="blue">*Appendix: Why we can solve the Schrödinger equation analytically only for very small systems (Quantum Chemistry)*
# * **Analytical** solution for Schrödinger in Hydrogen atom. But a second electron add electron-electron repulsion = three-body problem.
# * **Approximate** Schrödinger with DFT and HF on classical computers via **optimization (variation)** for larger systems than Hydrogen
# * **Simulate** time evolution for even larger systems = Quantum computer doesn't store information anymore - **it is the Hilbert space!**
# * Weil die Schrödinger Gleichung nicht exakt lösbar für größere Systeme: Rayleigh Ritz Verfahren aus Variationsanalyse und Born-Oppenheimer Aporoximation (Nukleus fixed, Elektronen für Energy Potential). Modelle und Verfahren:
#   * Valenzbindungstheorie (Hybridisierung, lokale Bindungen)
#   * Molekülorbitaltheorie (Delokalisierung, Konjugation, Homo/Lumo, LCAO-Methode)
#   * Hartee-Fock, Post-Hartree Fock (correlation energies), DFT
#   * Quantum Numbers (Besonderheit: Spinquantenzahl. Normale“ Schrödinger-Gleichung liefert nur $n$, $l$ und $m_l$. Spin ($m_s$=± 1/2) quanten- mechanische Eigenschaft. Erscheint wenn Quantenmechanik + Speziellen RT kombiniert (1928 Dirac-Gleichung).

# %%
# @title Qubitization: Quantum Walk, Block Encoding, LCU
# ==========================================
# OTOC (Quantum Implementation)
# ==========================================
from IPython.display import display, Markdown

print(40*"=")
print("Qubitization (Quantum Walk, Block Encoding, LCU)")
print(40*"=")

display(Markdown(r"* Qubitization is an algebraic trick. It transforms the problem of walking through time into a problem of walking through the eigenvalues of an operator."))
display(Markdown(r"* **LCU Decomposition:** Approximate operator by decomposing propagator $e^{-iHt}$ via Taylor series in weightes sum of unitaries $H = \sum_{l=0}^{L-1} \alpha_l U_l$. (non-unitary, represents energy). Then **Normalization:** $\lambda = \sum |\alpha_k|$ $\rightarrow$ $H/\lambda$. If $H=$ Dirac $\mathcal{D}$ = as benchmark, its algebraic structure (sum of Paulis) efficient."))
display(Markdown(r"* **LCU Oracles**: 1. ***PREPARE Oracle*** ($P$): encodes coefficients $\alpha_j$ into amplitudes of ancilla. Output is state where probability of measuring state $j$ is proportional to $\alpha_j$: $P|0\rangle = \frac{1}{\sqrt{\|\alpha\|_1}} \sum_{j=0}^{m-1} \sqrt{\alpha_j} |j\rangle$. ***2. SELECT Oracle*** ($S$) apply unitaries $U_l$ to target register state, conditioned on state of ancilla (entangles). If ancilla is state $|j\rangle$, it applies $U_j$ to target state $|\psi\rangle$. $S = \sum_{j=0}^{m-1} |j\rangle\langle j| \otimes U_j$ ***3. Un-prepare***: Apply inverse $P^\dagger$ to ancilla. ***4. Measure***: ancilla."))
display(Markdown(r"* **Block Encoding $U_H$:** LCU embeds $\hat{H}/\lambda$ in top-left corner of quantum walk $U_H = \begin{pmatrix} \hat{H}/\lambda & \dots \\ \dots & \dots \end{pmatrix}$. If Ancilla is $|0\rangle$, we apply $H$. If Ancilla is $|1\rangle$, apply junk."))
display(Markdown(r"* **Quantum Walk** $Q$: add reflections to $U$ turns it into walk that moves through energy spectrum. By reflecting junk back into system ($Q = R \cdot U$), a rotation is created. Eigenvalues of $Q$ are linked to eigenvalues $E$ of $H$ via $\mu = e^{\pm i \arccos(E/\lambda)}$ (energy mapping). Physics is in angle (Isomorphism): $E_k = \lambda \cos(\theta_k)$. QW transforms *energy information* (scalar magnitude) into *phase information* (how fast rotates). High Energy $\rightarrow$ Small Angle. Zero Energy $\rightarrow$ $\cos(90^\circ)=0$."))

print(40*"=")
print("Simulation: Qubitization for OTOC")
print(40*"=")

display(Markdown(r"* Example: OTOC (scrambling of black hole or complex molecule). Time Reversal in Qubitization: invert Reflection and Oracles. **Shows that TIME in Qubitization is actually an ANGLE in Hilbert space**."))
display(Markdown(r"* Scrambling: Even with 1 system qubit, measurement changes if Forward and Backward walks don't perfectly cancel out because of the $X$ gate (butterfly). Code is gate-based with no god-mode access to $e^{-iHt}$."))
print("\n")

# --- 1. Define the Oracles (Same as before) ---

class PrepareOracle(cirq.Gate):
    def __init__(self, coeffs):
        super(PrepareOracle, self).__init__()
        self.coeffs = coeffs
        self.l1 = sum(coeffs)
        self.theta = 2 * np.arccos(np.sqrt(coeffs[0] / self.l1))
    def _num_qubits_(self): return 1
    def _decompose_(self, qubits):
        yield cirq.ry(self.theta).on(qubits[0])

class SelectOracle(cirq.Gate):
    def _num_qubits_(self): return 2
    def _decompose_(self, qubits):
        anc, sys = qubits
        yield cirq.X(sys).controlled_by(anc, control_values=[0])
        yield cirq.Z(sys).controlled_by(anc, control_values=[1])

# --- 2. Define the Qubitization Walk Step (The Engine) ---

class QubitizationWalkStep(cirq.Gate):
    """A single step of the Quantum Walk Q."""
    def __init__(self, coeffs):
        super(QubitizationWalkStep, self).__init__()
        self.prep = PrepareOracle(coeffs)
        self.sel = SelectOracle()

    def _num_qubits_(self): return 2

    def _decompose_(self, qubits):
        anc, sys = qubits
        # Q = Reflection * LCU_Operator
        # Part 1: LCU Operator (Block Encoding)
        yield self.prep.on(anc)
        yield self.sel.on(anc, sys)
        yield cirq.inverse(self.prep).on(anc)
        # Part 2: Reflection on Ancilla
        yield cirq.Z(anc)

# --- 3. The OTOC Experiment as example use case for qubitization ---

def run_qubitization_otoc(steps=2):
    q_anc = cirq.NamedQubit("Ancilla")
    q_sys = cirq.NamedQubit("System")
    circuit = cirq.Circuit()

    walk_step = QubitizationWalkStep(coeffs=[0.6, 0.8])

    # STEP A: Forward Evolution (Forward Walk)
    for _ in range(steps):
        circuit.append(walk_step.on(q_anc, q_sys))

    # STEP B: The Butterfly Perturbation (V)
    # We apply X to the system
    circuit.append(cirq.X(q_sys))

    # STEP C: Backward Evolution (Inverse Walk)
    # This is the 'Time Reversal' unique to OTOCs
    for _ in range(steps):
        circuit.append(cirq.inverse(walk_step).on(q_anc, q_sys))

    # STEP D: Measurement (W)
    circuit.append(cirq.measure(q_sys, key='otoc_result'))

    print(f"--- Qubitization OTOC Circuit ({steps} steps) ---")
    print(circuit)

    simulator = cirq.Simulator()
    result = simulator.run(circuit, repetitions=1000)
    print("\nResults (Histogram):")
    print(result.histogram(key='otoc_result'))

run_qubitization_otoc(steps=4)
# Out:
# ...
# Qubitization (Quantum Walk, Block Encoding, LCU)
# ...
# * Qubitization is an algebraic trick. It transforms the problem of walking through time into a problem of walking through the eigenvalues of an operator.
# * **LCU Decomposition:** Approximate operator by decomposing propagator $e^{-iHt}$ via Taylor series in weightes sum of unitaries $H = \sum_{l=0}^{L-1} \alpha_l U_l$. (non-unitary, represents energy). Then **Normalization:** $\lambda = \sum |\alpha_k|$ $\rightarrow$ $H/\lambda$. If $H=$ Dirac $\mathcal{D}$ = as benchmark, its algebraic structure (sum of Paulis) efficient.
# ...

# %%
# @title RCS: Porter-Thomas check → Is circuit design good? (Rotation vs. Interaction - Balancing Local Scrambling + Global Entanglement)
import cirq
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Markdown


#print(40*"=")
print("RCS: Experiment zur Zeitentwicklung unter der zeitabhängigen Schrödinger-Gleichung mit zufälligem Hamiltonian")
#print(40*"=")

display(Markdown(r"* **Rotation (Local Scrambling):** Kinetic energy (internal energy of qubits). SU(2) Lie (rotate individual Bloch vectors but cannot create entanglement). **Ideal**: $X^{0.5}, Y^{0.5}, T$. **Real**: `cirq.PhasedXZGate(x_exponent=0.5, axis_phase_exponent=a, z_exponent=0) for a in exponents` which can become any of them by changing phase of axis: $T$ (Phase Gate) is rotation around Z-axis (z_exponent), $Y^{0.5}$ is 90° rotation around y-axis (axis_phase_exponent=0.5), $X^{0.5}$ (Square root of NOT) is 90° rotation around X-axis (axis_phase_exponent=0). On QPU microwave pulse is always same shape ($X^0.5$), but computer changes phase of microwave relative to qubit's clock to make it look like Y or T-gate. **Trotterization** (Ising): use specific X-rotation ($e^{-iθX}$) = one direction, represents Transverse Field trying to flip spins. **RCS**: no specific field but max uncertainty = random rotations in XY plane."))
display(Markdown(r"* **Exchange Interaction (Global Scrambling)**: Potential energy. SU(4).  Real: `cirq.FSimGate(theta=np.pi/2, phi=np.pi/6)` = **θ iSwap** angle (with calibration drift / coherent error because iSwap rarely exactly 90 degrees (exponent 0.5), θ=π/2 is full iSwap) followed by **ϕ CPHASE** angle `cirq.PhasedXZGate` (ZZ-style phase shift during swap). Ideal: `cirq.CZ` = special case of FSim (swap (θ) = 0, phase (ϕ) = π). Google QC is opposite: θ large (natural energy exchange) and ϕ small (accidental phase shift). **Trotterization**: use ZZ interactions ($e^{-iθZZ}$) = Phase-Phase interaction. Qubits don't swap energy; they just change each other's clocks (phases) based on their state. **RCS**: use Exchange interactions like iSwap. There is a physical exchange of the excitation (the 1 state) between qubits. This leads to much faster scrambling."))
display(Markdown(r"* Google OTOC²: no Qubitization, but cycles of random single-qubit gates+fixed two-qubit gates (iSWAP-like, followed by CPHASE, like from RCS."))
display(Markdown(r"* **From Trotterization: $X$-Rotation (Transverse Field $X$:** flip spins (Dynamics) Term $e^{-i X \theta}$ corresponds exactly to an RX gate. **$ZZ$-Interaction $Z_0 Z_1$:** align/anti-align spins (Entanglement). $e^{-i Z \otimes Z \theta}$ operator not natively on QC. Constructed  with sequence: CNOT $\rightarrow$ RZ $\rightarrow$ CNOT."))

def generate_rcs_circuit(qubits, depth):
    circuit = cirq.Circuit()
    gate_set = [cirq.X**0.5, cirq.Y**0.5, cirq.T]

    for d in range(depth):
        # 1. Random single-qubit gates
        for q in qubits:
            gate = np.random.choice(gate_set)
            circuit.append(gate(q))

        # 2. Alternating entangling gates (Brickwork pattern)
        offset = d % 2
        for i in range(offset, len(qubits) - 1, 2):
            circuit.append(cirq.CZ(qubits[i], qubits[i+1]))

    return circuit

print("\n------ Circuit Structure (4 qubits, 4 layers) ------ \n")
n_qubits = 4
qubits = [cirq.LineQubit(i) for i in range(n_qubits)]
depth = 4
circuit = generate_rcs_circuit(qubits, depth)
print(circuit)


# Setup: 12 qubits
n_qubits = 12
qubits = [cirq.LineQubit(i) for i in range(n_qubits)]
depth = 50

# Create and simulate
circuit = generate_rcs_circuit(qubits, depth)
simulator = cirq.Simulator()
result = simulator.simulate(circuit)

# Get the probabilities |psi|^2
probs = np.abs(result.final_state_vector)**2

# --- XEB Fidelity Calculation ---
N = 2**n_qubits
xeb_fidelity = N * np.sum(probs**2) - 1
#print(f"Linear XEB Fidelity: {xeb_fidelity:.4f} ({n_qubits} qubits, {depth} layers) \n")

print(f"\n------ Simulation ({n_qubits} qubits, {depth} layers), Linear XEB Fidelity: {xeb_fidelity:.4f} ------ \n")


# --- Side-by-Side Plotting ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))
small_size = 7

# Left Plot: Speckle Pattern
ax1.bar(range(2**n_qubits), probs, width=1.0, color='teal', alpha=0.7)
ax1.set_title(f"RCS Speckle Pattern ({n_qubits} Qubits)", fontsize=small_size + 2)
ax1.set_xlabel("Basis State (Decimal)", fontsize=small_size)
ax1.set_ylabel("Probability", fontsize=small_size)
ax1.tick_params(axis='both', labelsize=small_size)

# Right Plot: Porter-Thomas Histogram
ax2.hist(N * probs, bins=50, density=True, alpha=0.6, color='purple', label='Circuit Data')
x = np.linspace(0, 10, 100)
ax2.plot(x, np.exp(-x), 'r--', label='Porter-Thomas (Theoretical)')
ax2.set_yscale('log')
ax2.set_title("Distribution of Bitstring Probabilities", fontsize=small_size + 2)
ax2.set_xlabel("N * p (Normalized Probability)", fontsize=small_size)
ax2.set_ylabel("Density (Log Scale)", fontsize=small_size)
ax2.tick_params(axis='both', labelsize=small_size)
ax2.legend(fontsize=small_size - 1)

plt.tight_layout()
plt.show()

display(Markdown(r"**Thomas-Porter Distribution**: $P(p)=(N-1)(1-p)^{N-2} \approx N e^{-N p}$, where $N=2^n$. $e^{-Np}$ curve = quantum chaos (global scrambling). Reaching $y = e^{-x}$ on log-scale (red dashed line) in histogram, shows successful simulation of global scrambling. **Lieb-Robinson bound**: theoretical limit at which information is scrambled with RCS.  Similar to how OTOCs quantify rate of scrambling (Lyapunov exponent). RCS is designed to exploit the Lieb-Robinson bound to spread information at the maximum possible speed. **Page Scrambling**: RCS is designed to be maximally chaotic (meanwhile Trotterization of physical system can be long time to explore entire Hilbert space. **RCS Speckle pattern**: noise on real hardware leads to flattened speckle = every bitstring equally likely ($1/2^n$). RCS: prove bars still spiky enough for theory. **Scrambling time** $t_S$: for 1D chain architecture in code, to reach Porter-Thomas: need depth that scales linearly with number of qubits ($d∼n$) = light cone from first qubit has reached the last qubit. 2D grid (like Google's Sycamore), depth only needs to scale as $d∼\sqrt{}n$.*"))
# Out:
# RCS: Experiment zur Zeitentwicklung unter der zeitabhängigen Schrödinger-Gleichung mit zufälligem Hamiltonian
# ...

# %%
# @title RCS: XEB vs depth/noise → How does noise corrupt it?
import cirq
import numpy as np
import matplotlib.pyplot as plt
import random
from IPython.display import display, Markdown

# Based on 'Phase transitions in random circuit sampling' https://www.nature.com/articles/s41586-024-07998-6

# --- setup ---
n_rows, n_cols = 3, 3
qubits = [cirq.GridQubit(i, j) for i in range(n_rows) for j in range(n_cols)]
n_qubits = len(qubits)
dim = 2 ** n_qubits

SYC_GATE = cirq.FSimGate(theta=np.pi / 2, phi=np.pi / 6)
p_values = [-1, -0.75, -0.5, -0.25, 0, 0.25, 0.5, 0.75]


def get_2q_layer():
    edges = []
    for i in range(n_rows):
        for j in range(n_cols):
            if i < n_rows - 1:
                edges.append((cirq.GridQubit(i, j), cirq.GridQubit(i + 1, j)))
            if j < n_cols - 1:
                edges.append((cirq.GridQubit(i, j), cirq.GridQubit(i, j + 1)))
    random.shuffle(edges)
    layer, used = [], set()
    for q1, q2 in edges:
        if q1 not in used and q2 not in used:
            layer.append(SYC_GATE.on(q1, q2))
            used.update([q1, q2])
    return layer


def build_circuits_2024(depth, noise_1q, noise_2q):
    """2024 gate set: PhasedXPowGate as a single primitive
    (Z^p X^{1/2} Z^{-p}, with virtual Z done in software)."""
    ideal = cirq.Circuit()
    noisy = cirq.Circuit()
    for _ in range(depth):
        ones = {q: cirq.PhasedXPowGate(phase_exponent=random.choice(p_values),
                                       exponent=0.5)
                for q in qubits}
        layer_1q = cirq.Moment(ones[q].on(q) for q in qubits)
        ideal.append(layer_1q)
        noisy.append(layer_1q)
        if noise_1q > 0:
            noisy.append(cirq.Moment(
                cirq.depolarize(noise_1q).on(q) for q in qubits
            ))

        twoq = get_2q_layer()
        ideal.append(cirq.Moment(twoq))
        noisy.append(cirq.Moment(twoq))
        if noise_2q > 0:
            noise_ops = []
            for op in twoq:
                for q in op.qubits:
                    noise_ops.append(cirq.depolarize(noise_2q).on(q))
            noisy.append(cirq.Moment(noise_ops))
    return ideal, noisy


ideal_sim = cirq.Simulator()
noisy_sim = cirq.DensityMatrixSimulator()
trials = 3

# ======================================================================
# Experiment 1: XEB decay vs depth at fixed hardware quality
# ======================================================================
depths_decay   = [2, 4, 6, 8, 10, 12, 14, 16]
noise_1q_2024  = 0.0008
noise_2q_fixed = 0.005

xeb_2024 = np.zeros(len(depths_decay))

#print("✅ Experiment 1: XEB vs depth...")
for idx, d in enumerate(depths_decay):
    x24 = 0.0
    for _ in range(trials):
        c_i, c_n = build_circuits_2024(d, noise_1q_2024, noise_2q_fixed)
        sv  = ideal_sim.simulate(c_i).final_state_vector
        rho = noisy_sim.simulate(c_n).final_density_matrix
        x24 += dim * np.sum(np.abs(sv) ** 2 * np.real(np.diag(rho))) - 1
    xeb_2024[idx] = x24 / trials
    #print(f"  Depth {d} done.")

# ======================================================================
# Experiment 2: XEB vs noise strength at fixed depths
# ======================================================================
base_1q = 0.0008
base_2q = 0.005
scales = np.linspace(0.25, 12.0, 7)
depths_sweep = [10, 14, 18]

#  the noise sweep at depth 18 is the heaviest single chunk.
# If you want a faster smoke test, drop trials to 2 and shorten scales to np.linspace(0.25, 12.0, 7).

results = {d: np.zeros(len(scales)) for d in depths_sweep}

#print("✅ Experiment 2: noise sweep...")
for d in depths_sweep:
    for j, s in enumerate(scales):
        p_1q = base_1q * s
        p_2q = base_2q * s
        x = 0.0
        for _ in range(trials):
            c_ideal, c_noisy = build_circuits_2024(d, p_1q, p_2q)
            sv  = ideal_sim.simulate(c_ideal).final_state_vector
            rho = noisy_sim.simulate(c_noisy).final_density_matrix
            x += dim * np.sum(np.abs(sv) ** 2 * np.real(np.diag(rho))) - 1
        results[d][j] = x / trials
    #print(f"  Depth {d} done.")

errors_per_cycle = scales * (9 * base_1q + 6 * base_2q)

# ======================================================================
# Side-by-side plot
# ======================================================================

# --- Side-by-Side Plotting ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
small_size = 7

# Left: XEB vs depth
ax1.plot(depths_decay, xeb_2024, marker='s',
         label=fr'2024 Gates $\{{Z^p X^{{1/2}} Z^{{-p}}\}}$ '
               fr'($p_{{1q}}={noise_1q_2024}$)',
         color='#d62728', linewidth=2)
ax1.axhline(0, color='black', linestyle='--',
            label='Uniform (complete decoherence)')
ax1.set_title(f'Linear XEB Decay vs Depth\n'
              f'($p_{{2q}}={noise_2q_fixed}$, 2024 gate set)', fontsize=small_size + 2)
ax1.set_xlabel('Circuit Depth (Cycles)', fontsize=small_size)
ax1.set_ylabel('Linear XEB Fidelity', fontsize=small_size)
ax1.tick_params(axis='both', labelsize=small_size)
ax1.legend(fontsize=small_size - 1)
ax1.grid(True, alpha=0.4)

# Right: XEB vs noise strength
colors = ['#d62728', '#2ca02c', '#1f77b4']
for d, color in zip(depths_sweep, colors):
    y = results[d]
    mask = y > 0  # only positive values on log axis
    ax2.semilogy(errors_per_cycle[mask], y[mask],
                 marker='o', label=f'depth = {d}', color=color, linewidth=2)

ax2.set_xlabel(r'Error per cycle ($\epsilon \times n$)', fontsize=small_size)
ax2.set_ylabel('Linear XEB Fidelity (log scale)', fontsize=small_size)
ax2.set_title('XEB vs Noise Strength\n(3x3 Sycamore Grid, 2024 gate set)', fontsize=small_size + 2)
ax2.tick_params(axis='both', labelsize=small_size)
ax2.legend(fontsize=small_size - 1)
ax2.grid(True, alpha=0.4, which='both')

plt.tight_layout()
plt.show()

from IPython.display import display, Markdown
display(Markdown(r"* 'build_circuits_2024' returns two circuits from same random gate sequence: ideal and noisy simulation"))
display(Markdown(r"* Ideal circuit is simulated with Simulator() → just gates, no noise channels, gives pure state vector sv (what perfect quantum computer would produce)"))
display(Markdown(r"* Noisy circuit is simulated with DensityMatrixSimulator() → same gates, but with cirq.depolarize(...), gives density matrix rho (what real, noisy QC produces)"))
display(Markdown(r"* XEB computed by comparing them: ' xeb = dim * sum(|sv|² · diag(rho)) - 1'. Masures how much the noisy output correlates with the ideal output probabilities."))
#display(Markdown(r"* Plot (XEB vs depth) and plot (XEB vs noise strength) show same metric, just sweep different axes. Every dot on both plots required running both simulations."))

print("\n------ Print deepest circuit at highest noise ------ \n")
# that's the regime where XEB has collapsed, and you can see why (lots of depolarize channels piling up):
d = max(depths_sweep)        # 18
s = scales[-1]               # 12.0, the strongest noise
p_1q = base_1q * s
p_2q = base_2q * s
ideal, noisy = build_circuits_2024(d, p_1q, p_2q)
print(noisy)

#from cirq.contrib.svg import SVGCircuit
#SVGCircuit(noisy)
# Out:
# * 'build_circuits_2024' returns two circuits from same random gate sequence: ideal and noisy simulation
# * Ideal circuit is simulated with Simulator() → just gates, no noise channels, gives pure state vector sv (what perfect quantum computer would produce)
# * Noisy circuit is simulated with DensityMatrixSimulator() → same gates, but with cirq.depolarize(...), gives density matrix rho (what real, noisy QC produces)
# * XEB computed by comparing them: ' xeb = dim * sum(|sv|² · diag(rho)) - 1'. Masures how much the noisy output correlates with the ideal output probabilities.
# ------ Print deepest circuit at highest noise ------
#
# ...

# %%
# @title OTOC: On Chaotic Hamiltonian (Mixed-field Ising model)

# OTOC (Quantum Dynamics, Quantum Chaos and Scrambling)
# ==========================================
# OTOC (Linear Algebra Implementation)
# ==========================================

from scipy.linalg import norm
from IPython.display import display, Markdown

print(40*"=")
print("OTOC (Quantum Dynamics, Quantum Chaos and Scrambling)")
print(40*"=")

display(Markdown(r"* Simple chaotic Hamiltonian is mixed-field Ising: $H = \sum Z_i Z_{i+1} + h_x \sum X_i + h_z \sum Z_i$. Longitudinal field $h_z$ breaks integrability and turns it chaotic."))
display(Markdown(r"* **OTOC** messen das Scrambling von Information. Wenn du einen Operator W(t) zu einer Zeit t hast und einen Operator V(0) zum Zeitpunkt 0, misst der OTOC $ \langle W^\dagger(t) V^\dagger(0) W(t) V(0) \rangle $, **wie stark diese Operatoren nach der Zeit t nicht mehr kommutieren**. QM Äquivalent zum Schmetterlingseffekt."))
display(Markdown(r"* **OTOC** $C(t) = \langle [\hat{W}(t), \hat{V}(0)]^\dagger [\hat{W}(t), \hat{V}(0)] \rangle$ is metric to quantify quantum chaos and rate of scrambling (quantum Lyapunov exponent). **Operator Spreading:** local operator $\hat{V}$ (Pauli gate) evolves under chaotic Hamiltonian into non-local operator $\hat{V}(t) = e^{iHt}\hat{V}e^{-iHt}$ (Eigenstate Thermalization)"))
display(Markdown(r"* OTOC is calculated via sequence: ***Forward Evolution***: Apply Qubitization Walk $n$ times (simulating time $+t$). ***Perturbation***: Apply Butterfly operator $\hat{V}$ ($X$ gate). ***Backward Evolution***: Apply inverse Qubitization Walk $n$ times (simulating time $-t$). ***Measurement***: Apply probe operator $\hat{W}$ and check correlation."))
display(Markdown(r"* **Four-Point Function:** evolve forward and backward in time: $W(t) = e^{iHt} W(0) e^{-iHt}$. Schrödinger (moving states) $\rightarrow$ Heisenberg (moving operators)"))
display(Markdown(r"* **Time-Dependent Schrödinger** $|\Psi(t)\rangle = e^{-iHt} |\Psi(0)\rangle$ tells how state moves. OTOC describes if chaotic or ordered. Time-Dependent part hidden in $\hat{W}(t)$."))
display(Markdown(r"* **Heisenberg Evolution** $\hat{W}(t) = e^{iHt} \hat{W}(0) e^{-iHt}$ to calculate $\hat{W}(t)$, where $e^{-iHt}$ is solution to Schrödinger. Without Schrödinger, no $\hat{W}(t)$ and no OTOC."))
display(Markdown(r"* **Loschmidt Echo**: measure OTOC on QC: 1. Evolve forward ($e^{-iHt}$) 2. Perturbation ($\hat{V}$) 3. Evolve backward ($e^{+iHt}$ - time reversal) 4. Measure overlap"))
display(Markdown(r"*An OTOC is defined as $C(t) = \langle [\hat{W}(t), \hat{V}(0)]^\dagger [\hat{W}(t), \hat{V}(0)] \rangle$. The core concept here is Operator Spreading. We want to see how a local operator $\hat{W}$ at time $0$ evolves into a complex, non-local operator $\hat{W}(t) = \hat{U}^\dagger(t) \hat{W}(0) \hat{U}(t)$ at time $t$. We are asking: How much does the future measurement of $W$ depend on a past perturbation $V$? - If the system is chaotic, $\hat{W}(t)$ spreads across the system and eventually fails to commute with $\hat{V}(0)$, causing the OTOC to grow.*"))
display(Markdown(r"* **Quantum Chaos** (Right). Information scrambles (thermalizes). By t=20, system is perfect model for how information is hidden in Black Hole."))
display(Markdown(r"* **Interaction strength $J$** increase makes slope steeper (information moves faster) and quantum chaos $h_z$ grows faster. Light Cone of Information Scrambling:"))

def get_unitary_from_circuit(qubits, t, h_x, h_z, steps=25):
    """
    Creates the Unitary Matrix U(t) for a specific Hamiltonian setup.
    H = Sum(Zi Zj) + h_x * Sum(Xi) + h_z * Sum(Zi)
    """
    circuit = cirq.Circuit()
    dt = t / steps
    n = len(qubits)

    for _ in range(steps):
        # 1. Interaction (ZZ) - The "Scrambler"
        for i in range(n - 1):
            circuit.append(cirq.CNOT(qubits[i], qubits[i+1]))
            circuit.append(cirq.rz(rads=2 * dt).on(qubits[i+1]))
            circuit.append(cirq.CNOT(qubits[i], qubits[i+1]))

        # 2. Transverse Field (X) - The "Driver"
        if h_x != 0:
            for i in range(n):
                circuit.append(cirq.rx(rads=2 * h_x * dt).on(qubits[i]))

        # 3. Longitudinal Field (Z) - The "Chaos Generator"
        # Adding this term breaks integrability and causes chaos.
        if h_z != 0:
            for i in range(n):
                circuit.append(cirq.rz(rads=2 * h_z * dt).on(qubits[i]))

    # Extract the full unitary matrix (2^N x 2^N)
    return cirq.unitary(circuit)

def calculate_otoc_curve(num_qubits, h_x, h_z, time_points):
    """
    Calculates the OTOC C(t) = || [W(t), V] ||^2
    V = X on Qubit 0 (The Perturbation)
    W = Z on Qubit N-1 (The Probe)
    """
    qubits = cirq.LineQubit.range(num_qubits)
    otoc_values = []

    # Define Operators V (at t=0) and W (at t=0)
    # We build them as full matrices (2^N x 2^N)

    # V = X_0 (Tensor product: X I I I...)
    op_list_V = [np.eye(2)] * num_qubits
    op_list_V[0] = np.array([[0, 1], [1, 0]]) # X
    V = op_list_V[0]
    for i in range(1, num_qubits):
        V = np.kron(V, op_list_V[i])

    # W = Z_last (Tensor product: ...I I I Z)
    op_list_W = [np.eye(2)] * num_qubits
    op_list_W[-1] = np.array([[1, 0], [0, -1]]) # Z
    W = op_list_W[-1]
    for i in range(num_qubits-2, -1, -1):
        W = np.kron(op_list_W[i], W)

    #print(f"Simulating: h_x={h_x}, h_z={h_z}...")

    for t in time_points:
        if t == 0:
            otoc_values.append(0)
            continue

        # 1. Get Time Evolution Operator U(t)
        U = get_unitary_from_circuit(qubits, t, h_x, h_z)
        U_dag = U.conj().T

        # 2. Evolve W forward in time (Heisenberg Picture)
        # W(t) = U^dagger * W * U
        W_t = U_dag @ W @ U

        # 3. Calculate Commutator C = [W(t), V] = W(t)V - VW(t)
        commutator = W_t @ V - V @ W_t

        # 4. Measure "Size" of commutator (Frobenius Norm)
        # This tells us how non-commutative they have become
        c_val = np.linalg.norm(commutator) ** 2
        otoc_values.append(c_val)

    return otoc_values

# --- Simulation Setup ---
# A simple chaotic Hamiltonian is the mixed-field Ising model:

n_qubits = 5  # Small enough for matrix multiplication
times = np.linspace(0, 15.0, 30)

# Scenario 1: Ordered / Integrable (Ising Model)
# No longitudinal field (h_z = 0)
otoc_ordered = calculate_otoc_curve(n_qubits, h_x=1.0, h_z=0.0, time_points=times)

# Scenario 2: Chaotic (Non-Integrable)
# We add a longitudinal field (h_z = 0.5) to break symmetry
otoc_chaotic = calculate_otoc_curve(n_qubits, h_x=1.0, h_z=0.5, time_points=times)

# --- Plotting ---
plt.figure(figsize=(6, 3))
small_size = 8 # font size
plt.plot(times, otoc_ordered, label='Ordered (h_z=0)', color='blue', linestyle='--')
plt.plot(times, otoc_chaotic, label='Chaotic (h_z=0.5)', color='red', linewidth=2)
plt.title(f'Quantum Scrambling (with Qubitization): OTOC Growth (N={n_qubits} Qubits)', fontsize=small_size + 1)
plt.xlabel('Time (t)', fontsize=small_size)
plt.ylabel('OTOC Commutator Magnitude', fontsize=small_size)
plt.legend(fontsize=small_size - 1) # fint size on legend slightly smaller
plt.tick_params(axis='both', labelsize=small_size)

plt.grid(True, alpha=0.3)
plt.tight_layout() # Ensures labels don't get cut off at smaller sizes
plt.show()
# Out:
# ...
# OTOC (Quantum Dynamics, Quantum Chaos and Scrambling)
# ...
# * Simple chaotic Hamiltonian is mixed-field Ising: $H = \sum Z_i Z_{i+1} + h_x \sum X_i + h_z \sum Z_i$. Longitudinal field $h_z$ breaks integrability and turns it chaotic.
# * **OTOC** messen das Scrambling von Information. Wenn du einen Operator W(t) zu einer Zeit t hast und einen Operator V(0) zum Zeitpunkt 0, misst der OTOC $ \langle W^\dagger(t) V^\dagger(0) W(t) V(0) \rangle $, **wie stark diese Operatoren nach der Zeit t nicht mehr kommutieren**. QM Äquivalent zum Schmetterlingseffekt.
# * **OTOC** $C(t) = \langle [\hat{W}(t), \hat{V}(0)]^\dagger [\hat{W}(t), \hat{V}(0)] \rangle$ is metric to quantify quantum chaos and rate of scrambling (quantum Lyapunov exponent). **Operator Spreading:** local operator $\hat{V}$ (Pauli gate) evolves under chaotic Hamiltonian into non-local operator $\hat{V}(t) = e^{iHt}\hat{V}e^{-iHt}$ (Eigenstate Thermalization)
# ...

# %%
# @title OTOC: Light Cone of Scrambling (OTOC for all qubits over time. Ordered vs Chaotic)

display(Markdown(r"* **MSS bound (Maldacena-Shenker-Stanford Schranke)**: $\lambda_L \leq 2\pi/\beta$. Vermutung, dass Schwarze Löcher die schnellsten Scrambler der Natur sind. Ties scrambling to thermodynamics and black holes (saturate bound). Connects OTOCs to JT gravity, SYK, + Hayden-Preskill protocol."))
display(Markdown(r"* **Quantum Butterfly Effect**: Calculates OTOC between first qubit and other qubits. Proof how information spreads physically (light cone of scrambling in real)."))
display(Markdown(r"* **Lieb-Robinson Light Cone (Bound)** (diagonal V-shape): information has speed limit **Butterfly Velocity** $v_B$ (slope of diagonal line) as it travels down chain"))
display(Markdown(r"* **Lieb-Robinson velocity** sets the universal speed limit on how fast information can propagate in a local quantum system. The speed limit shows up in three places: it's the slope of the OTOC light cone (the butterfly velocity), it's why RCS depth scales linearly with $n$ in 1D and as $\sqrt{n}$ in 2D, and it's the operator-spreading velocity in random unitary circuits."))
display(Markdown(r"* **Porter-Thomas distribution** $P(p) \approx N e^{-Np}$ (with $N = 2^n$) is the bitstring probabilities histogram in RCS. It is the fingerprint of a **Haar-random unitary**. The depth needed to **reach Porter-Thomas — the scrambling time** — is set by the circuit geometry: $d \sim n$ for a 1D chain, $d \sim \sqrt{n}$ for a 2D grid like Sycamore. This is the light cone from the **Lieb-Robinson bound** reaching across the device."))
display(Markdown(r"* **Page scrambling time** is when a system has thermalized so thoroughly that most qubits need to be measured to recover any local information. RCS is designed to push system to Page scrambling as fast as possible → is why it uses Haar-random gates rather than evolution under a specific Hamiltonian."))
display(Markdown(r"* **Poincare Recurrence** (Left) with Ballistic Echoes. Information remains particle-like and bounces back coherently to original state."))
display(Markdown(r"* **Quantum Chaos** (Right). Information scrambles (thermalizes). By t=20, system is perfect model for how information is hidden in Black Hole."))
display(Markdown(r"* **Interaction strength $J$** increase makes slope steeper (information moves faster) and quantum chaos $h_z$ grows faster. Light Cone of Information Scrambling:"))

def calculate_otoc_heatmap(num_qubits, h_x, h_z, t_max, t_steps):
    """
    Calculates OTOC for all qubits over time to visualize the Light Cone.
    """
    qubits = cirq.LineQubit.range(num_qubits)
    times = np.linspace(0, t_max, t_steps)
    # Matrix to store results: Rows = Qubits, Cols = Time
    heatmap_data = np.zeros((num_qubits, t_steps))

    # V is always X on the first qubit (The "Butterfly")
    op_list_V = [np.eye(2)] * num_qubits
    op_list_V[0] = np.array([[0, 1], [1, 0]]) # Pauli X
    V = op_list_V[0]
    for i in range(1, num_qubits):
        V = np.kron(V, op_list_V[i])

    #print(f"Generating Heatmap (h_z={h_z})...")

    for t_idx, t in enumerate(times):
        if t == 0: continue

        # Get the global Unitary for this time point
        U = get_unitary_from_circuit(qubits, t, h_x, h_z) # Using previous function
        U_dag = U.conj().T

        # Calculate OTOC for each qubit j as the "Probe"
        for j in range(num_qubits):
            # W is Z on qubit j
            op_list_W = [np.eye(2)] * num_qubits
            op_list_W[j] = np.array([[1, 0], [0, -1]]) # Pauli Z

            # Construct W matrix
            W = op_list_W[0]
            for k in range(1, num_qubits):
                W = np.kron(W, op_list_W[k])

            # Heisenberg evolution: W(t) = U^dag * W * U
            W_t = U_dag @ W @ U

            # Commutator magnitude
            commutator = W_t @ V - V @ W_t
            heatmap_data[j, t_idx] = np.linalg.norm(commutator) ** 2

    return times, heatmap_data

# --- Execution ---
n_qubits = 6 # Kept small for simulation speed
t_max = 20.0
t_steps = 25

# Generate data for Chaotic vs Ordered
_, data_ordered = calculate_otoc_heatmap(n_qubits, 1.0, 0.0, t_max, t_steps)
times, data_chaotic = calculate_otoc_heatmap(n_qubits, 1.0, 0.5, t_max, t_steps)

# --- Plotting ---

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 3))

# Define your desired font size
small_size = 7

# Plot 1
sns.heatmap(data_ordered, ax=ax1, cmap='magma', xticklabels=np.round(times, 1))
ax1.set_title("Ordered (h_z=0): Ballistic Spread", fontsize=small_size + 2)
ax1.set_xlabel("Time (t)", fontsize=small_size)
ax1.set_ylabel("Qubit Index", fontsize=small_size)
ax1.tick_params(axis='both', labelsize=small_size)

# Adjust Colorbar 1
cbar1 = ax1.collections[0].colorbar
cbar1.ax.tick_params(labelsize=small_size)

# Plot 2
sns.heatmap(data_chaotic, ax=ax2, cmap='magma', xticklabels=np.round(times, 1))
ax2.set_title("Chaotic (h_z=0.5): Scrambling / Diffusion", fontsize=small_size + 2)
ax2.set_xlabel("Time (t)", fontsize=small_size)
ax2.set_ylabel("Qubit Index", fontsize=small_size)
ax2.tick_params(axis='both', labelsize=small_size)

# Adjust Colorbar 2
cbar2 = ax2.collections[0].colorbar
cbar2.ax.tick_params(labelsize=small_size)

plt.tight_layout()
plt.show()

display(Markdown(r"*$C(t) = \langle [\hat{W}(t), \hat{V}(0)]^\dagger [\hat{W}(t), \hat{V}(0)] \rangle$ quantifies rate of scrambling. $\hat{V}(0)$: Butterfly (small local perturbation at start). $\hat{W}(t)$ measurement later in time. At $t=0$, $W$ and $V$ commute (are on different qubits). Commutator is 0. As time evolves, $\hat{W}(t)$ grows spatially (scrambling). Eventually, $\hat{W}(t)$ hits the qubit where $\hat{V}$ sits. They no longer commute. Commutator grows, and $C(t)$ deviates from zero. Result: rate at which OTOC grows is Lyapunov Exponent ($\lambda$), the speed limit of chaos.*"))
# Out:
# * **MSS bound (Maldacena-Shenker-Stanford Schranke)**: $\lambda_L \leq 2\pi/\beta$. Vermutung, dass Schwarze Löcher die schnellsten Scrambler der Natur sind. Ties scrambling to thermodynamics and black holes (saturate bound). Connects OTOCs to JT gravity, SYK, + Hayden-Preskill protocol.
# * **Quantum Butterfly Effect**: Calculates OTOC between first qubit and other qubits. Proof how information spreads physically (light cone of scrambling in real).
# * **Lieb-Robinson Light Cone (Bound)** (diagonal V-shape): information has speed limit **Butterfly Velocity** $v_B$ (slope of diagonal line) as it travels down chain
# ...

# %% [markdown]
# <font color="blue">**Quanten-Chaos-Konzepte**
#
# 1. Fast-Scrambling & Operator-Wachstum
#
# * **Scrambling-Zeit:** Logarithmisch in der Systemgröße — schwarze Löcher sind die schnellsten Scrambler des Universums.
# $$t_* \sim \frac{1}{\lambda_L}\ln N$$
#
# * **Operatorgröße $n(t)$:** Mittlere Anzahl nicht-trivialer Pauli-Faktoren in der Pauli-String-Zerlegung von $W(t)$; wächst exponentiell bis zur Sättigung.
# $$\frac{dn}{dt} = \lambda_L\, n(t) \implies n(t) \sim e^{\lambda_L t}$$
#
# * **Operator-Größen-Verteilung:** Wahrscheinlichkeit, dass $W(t)$ Größe $n$ hat; $C(t)$ ist ihr erstes Moment.
# $$P(n,t) = \!\!\sum_{I:\,n(I)=n}\!\! |c_I(t)|^2, \qquad C(t) \propto \frac{\langle n(t)\rangle}{N}$$
#
# * **Butterfly-Geschwindigkeit:** Räumliche Ausbreitungsrate der Operatorfront — gibt die Steigung des Lichtkegels im OTOC.
# $$C(t,x) \sim \frac{1}{N}\,e^{\lambda_L(t - x/v_B)}$$
#
# 2. Krylov-Komplexität & Lanczos
#
# * **Liouvillian:** Superoperator, der Heisenberg-Evolution erzeugt; seine Tridiagonalisierung definiert die Krylov-Basis.
# $$\mathcal{L} = [H,\cdot], \qquad O(t) = e^{i\mathcal{L}t}O$$
#
# * **Lanczos-Rekursion:** Tridiagonale Form von $\mathcal{L}$ auf der Krylov-Kette; $b_n$ = Hopping-Amplituden zwischen Krylov-Plätzen.
# $$\mathcal{L}|O_n) = b_{n+1}|O_{n+1}) + b_n|O_{n-1})$$
#
# * **Krylov-Komplexität:** Mittlere Position auf der Krylov-Kette; misst algebraische Tiefe der Operator-Evolution.
# $$K(t) = \sum_n n\,|\varphi_n(t)|^2$$
#
# * **Universal Operator Growth Hypothesis (UOGH):** Bei nicht-integrablen Systemen wachsen die $b_n$ linear, mit Steigung durch KMS-Analytizität beschränkt.
# $$b_n = \alpha\,n + \gamma + o(1), \qquad \alpha \leq \pi/\beta$$
#
# * **Wachstumsregimes:**
# $$b_n \to \text{const} \Rightarrow K \sim t \quad (\text{integrabel})$$
# $$b_n \sim \sqrt{n} \Rightarrow K \sim t^2 \quad (\text{frei})$$
# $$b_n \sim \alpha n \Rightarrow K \sim e^{2\alpha t} \quad (\text{chaotisch})$$
#
# 3. MSS-Schranke & KMS-Analytizität
#
# * **OTOC (quadrierter Kommutator):** Misst Operator-Spreading via Nicht-Kommutativität zur Zeit $t$.
# $$C(t) = \langle[W(t),V]^\dagger[W(t),V]\rangle_\beta \simeq \frac{2K}{N}e^{\lambda_L t}$$
#
# * **MSS-Schranke:** Universelle Obergrenze für die Quanten-Lyapunov-Rate; gesättigt von Schwarzen Löchern und SYK.
# $$\lambda_L \leq \frac{2\pi}{\beta} = \frac{2\pi k_B T}{\hbar}$$
#
# * **KMS-Bedingung:** Verknüpft thermische Korrelatoren mit imaginärer Zeit — Quelle der Analytizität im Streifen $0 \leq \mathrm{Im}(t) \leq \beta$.
# $$\langle A(t)B(0)\rangle_\beta = \langle B(0)A(t+i\beta)\rangle_\beta$$
#
# * **Regularisierter OTOC:** $\rho^{1/4}$ symmetrisch verteilt; der MSS-Beweis lebt auf dieser Funktion.
# $$F(t) = \mathrm{Tr}\!\left[\rho^{1/4}W(t)\rho^{1/4}V\rho^{1/4}W(t)\rho^{1/4}V\right]$$
#
# * **Stack:** Algebraisches Prinzip → algorithmische Schranken.
# $$\text{KMS-Analytizität} \Rightarrow \alpha \leq \pi/\beta \Rightarrow \lambda_L \leq 2\alpha \leq 2\pi/\beta$$
#
# 4. Eigenstate Thermalization Hypothesis (ETH)
#
# * **ETH-Ansatz (Srednicki):** Matrixelemente lokaler Operatoren in Energieeigenzuständen — diagonaler Teil thermisch, off-diagonal exponentiell unterdrückt.
# $$A_{mn} = \mathcal{A}(\bar E)\delta_{mn} + e^{-S(\bar E)/2}f_A(\bar E,\omega)R_{mn}$$
#
# * **Kerneinsicht:** Ein einzelner Energieeigenzustand verhält sich lokal bereits wie ein thermisches Ensemble; das System thermalisiert *lokal*, bleibt aber global rein.
#
# * **Klassifikation:**
# $$\text{Chaotisch: ETH erfüllt} \,|\, \text{Integrabel: GGE} \,|\, \text{MBL: keine Thermalisierung}$$
#
# * **Zeitliche Hierarchie:**
# $$t_{\text{therm}} \sim \mathcal{O}(1) \,<\, t_*^{\text{scrambling}} \sim \ln N \,<\, t_K^{\text{Krylov}} \sim e^S$$
#
# 5. Yoshida-Kitaev-Decoder
#
# * **Hayden-Preskill (2007):** Information, die in einen Scrambler fällt, kann aus früher emittierter Strahlung in Zeit $\mathcal{O}(\ln N)$ rekonstruiert werden — falls man die Dynamik kennt.
#
# * **YK-Decoder (2017):** Probabilistisches Protokoll mit zwei Kopien $U$ und $U^*$, das Scrambling als Teleportations-Kanal nutzt.
# $$\text{Fidelity} \propto \langle W(t)^\dagger V^\dagger W(t) V\rangle_\beta \quad (\text{= OTOC})$$
#
# * **Paradoxe Konsequenz:** Decoder funktioniert *gerade dann*, wenn das System maximal scrambelt (OTOC → 0); Chaos = Übertragungs-Ressource.
#
# 6. Random Unitary Circuits (RUCs)
#
# * **Definition:** Brickwork aus Haar-zufälligen 2-Qubit-Gates; kein Hamiltonian, maximal chaotisch by construction.
#
# * **Operator-Spreading (Nahum-Vijay-Haah 2018):** KPZ-Universalitätsklasse — ballistische Front mit diffusiver Verbreiterung.
# $$\langle x_{\text{front}}\rangle = v_B t, \qquad \sigma(t) \sim t^{1/3}$$
#
# * **Verschränkungs-Wachstum:** Linear in $t$ mit Geschwindigkeit $v_E \leq v_B$ (Mezei-Stanford-Schranke).
# $$S(t) = v_E\, t + \mathcal{O}(t^{1/3})$$
#
# * **Dual-Unitary:** Gates sowohl in Raum- als auch Zeitrichtung unitär; OTOC verschwindet *exakt* außerhalb des Lichtkegels — deterministisch lösbar, $v_B$ saturiert Lieb-Robinson.
#
# * **Messungs-induzierter Phasenübergang (MIPT):** Bei Mess-Rate $p$ pro Site: Volumengesetz für $p < p_c$, Flächengesetz für $p > p_c$.
# $$S(p) = \begin{cases} \propto L & p < p_c \\ \mathcal{O}(1) & p > p_c \end{cases}$$
#
# 7. Scrambling als algorithmische Schranke
#
# * **Lieb-Robinson:** Information-Geschwindigkeitslimit in lokalen Systemen; setzt Tiefe-Untergrenze für globale Entanglement-Erzeugung.
# $$\|[A(t),B]\| \leq C\,e^{-\mu(d - v_{LR}t)}$$
#
# * **Tiefe-Skalierung für globale Verschränkung:**
# $$d_{\min} \sim \begin{cases} n & \text{1D} \\ \sqrt{n} & \text{2D} \\ \log n & \text{all-to-all} \end{cases}$$
#
# * **Hamiltonian-Simulation:** Lieb-Robinson saturiert von Haah-Hastings-Kothari-Low 2018 — Gate-Komplexität ist *Scrambling-limitiert*.
# $$\text{Gates} = \mathcal{O}(nt\cdot\mathrm{polylog}(1/\epsilon))$$
#
# * **Barren Plateaus (McClean et al. 2018):** Volles Scrambling → exponentiell flache Optimierungs-Landschaft, VQAs untrainierbar.
# $$\mathrm{Var}[\partial_\theta E] \sim 2^{-n}$$
#
# * **Vikram-Shou-Galitski-Schranke:** Untere Schranke für Scrambling-Zeit aus Entropie.
# $$t_s \gtrsim \log S$$
#
# 8. Quick-Lookup-Tabelle
#
# | Größe | Symbol | Bound | Wo |
# |---|---|---|---|
# | Lyapunov | $\lambda_L$ | $\leq 2\pi/\beta$ | OTOC |
# | Lanczos-Steigung | $\alpha$ | $\leq \pi/\beta$ | Krylov |
# | Butterfly | $v_B$ | $\leq v_{LR}$ | RUC, OTOC |
# | Modulares Chaos | $\kappa$ | $\leq 2\pi$ | de Boer-Lamprou |
# | Scrambling-Zeit | $t_*$ | $\geq \frac{\beta}{2\pi}\ln N$ | Fast-Scrambling |
# | VQA-Gradient | $\mathrm{Var}[\partial E]$ | $\sim 2^{-n}$ | Barren Plateau |
#
# Operatoralgebra: Tomita-Takesaki (modular Fluss, KMS), Crossed Products, Modular Chaos und Lyapunov-Schranken. Cohomology: Hochschild- und zyklische Kohomologie, K-Theorie, Spektrale Tripel und Indextheorie, Charakteristische Klassen
#
# > Quantum Chaos Classification: Scrambling time of quantum system bounded by cohomology of its operator algebra (under modular flow)

# %% [markdown]
# ##### <font color="blue">*Quantum Computing*

# %%
# !pip install cirq openfermion -q
import cirq
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### <font color="blue">**IonQ Quantum Computing**

# %%
# IonQ libraries
# !pip install cirq-ionq -q
import cirq_ionq # https://docs.ionq.com/sdks/cirq
import cirq      # https://quantumai.google/cirq/hardware/ionq/circuits
import json
import pickle
import requests
import pandas as pd
import numpy as np
from datetime import datetime
from google.colab import files
from collections import Counter
import matplotlib.pyplot as plt
import cirq_ionq.ionq_exceptions as ionq_exceptions
from IPython.display import display, Markdown

# %%
# Connect to IonQ Service and Secret Manager for Token
from google.colab import userdata
api_token = userdata.get('ionq-quantum')
service = cirq_ionq.Service(api_key=api_token)
print("✅ Connection to IonQ successful")

# Check Available Backends (Simulators and QPUs)
print("\n✅ List of all backends (https://cloud.ionq.com/backends/qpus)")
headers = {"Authorization": f"apiKey {'ionq-quantum'}"}
r = requests.get("https://api.ionq.co/v0.3/backends", headers=headers)
if r.status_code == 200:
    available = [b for b in r.json() if b['status'].upper() == 'AVAILABLE']
    for i, b in enumerate(available, 1):
    #for i, b in enumerate(r.json(), 1): # to print all backends
        qt = b.get('average_queue_time', 0)
        print(f"\n{i}. {b['backend'].upper()}\n └── Type: {'QPU' if 'qpu' in b['backend'] else 'Simulator'}\n └── Status: {b['status'].upper()}\n └── Qubits: {b['qubits']}\n └── Average Queue Time: {f'{qt/3600:.1f} hours' if qt > 3600 else f'{qt/60:.1f} minutes' if qt > 60 else f'{qt} seconds'}" + (''.join([f"\n └── Available Noise Models: {', '.join(b['noise_models'])}" if 'noise_models' in b else "", f"\n └── Characterization: Available" if 'characterization_url' in b else "", f"\n └── DEGRADED SERVICE" if b.get('degraded', False) else ""])))
else: print(f"Backend check failed: {r.status_code}\nError details: {r.text}")


BACKEND = "qpu.forte-1" # forte-1, forte-enterprise-1, aria-1
print(f"\n✅ Selected backend: {BACKEND}")

# https://quantumai.google/cirq/hardware/ionq/calibrations - Error: Insufficient Scope
#calibration = service.get_current_calibration()
#print(calibration.fidelities())
#print(calibration.timings())
# Out:
# ✅ Connection to IonQ successful
#
# ✅ List of all backends (https://cloud.ionq.com/backends/qpus)
#
# 1. QPU.FORTE-1
#  └── Type: QPU
#  └── Status: AVAILABLE
#  └── Qubits: 36
#  └── Average Queue Time: 3222.9 hours
#  └── Characterization: Available
#
# 2. SIMULATOR
#  └── Type: Simulator
#  └── Status: AVAILABLE
#  └── Qubits: 29
#  └── Average Queue Time: 0 seconds
#  └── Available Noise Models: aria-1, forte-1, forte-enterprise-1, ideal
#
# 3. QPU.FORTE-ENTERPRISE-1
#  └── Type: QPU
#  └── Status: AVAILABLE
#  └── Qubits: 36
#  └── Average Queue Time: 1908.5 hours
#  └── Characterization: Available
#
# ✅ Selected backend: qpu.forte-1

# %% [markdown]
# **Use Case: Two-Qubit Entangled [Bell State](https://en.wikipedia.org/wiki/Bell_state) Preparation $|\Phi^+\rangle$**
#
# * Start with two qubits, $q_0$ and $q_1$, both initialized to the $|0\rangle$ state, creating the state **$|00\rangle$**.
#
# * Hadamard gate puts $q_0$ into a **superposition**, meaning it is equally likely to be measured as $|0\rangle$ or $|1\rangle$.
#   * Hadamard on the first qubit $q_0$:  $|00\rangle \xrightarrow{H \otimes I} \left(\frac{|0\rangle + |1\rangle}{\sqrt{2}}\right) \otimes |0\rangle = \frac{1}{\sqrt{2}}(|00\rangle + |10\rangle)$
#   * The state becomes $\frac{1}{\sqrt{2}}(|00\rangle + |10\rangle)$
#
# * CNOT gate for **Entanglement** (using $q_0$ as the control and $q_1$ as the target): CNOT flips $q_1$ only if $q_0$ is $|1\rangle$
#     * If $q_0$ is $|0\rangle$, $q_1$ stays $|0\rangle$ (path $|00\rangle \to |00\rangle$).
#     * If $q_0$ is $|1\rangle$, $q_1$ flips from $|0\rangle$ to $|1\rangle$ (path $|10\rangle \to |11\rangle$).
#     * $\frac{1}{\sqrt{2}}(|00\rangle + |10\rangle) \xrightarrow{\text{CNOT}} \frac{1}{\sqrt{2}}(|00\rangle + |11\rangle) = |\Phi^+\rangle$
#     * The state becomes $\frac{1}{\sqrt{2}}(|00\rangle + |11\rangle) = |\Phi^+\rangle$
#
# This final state, $|\Phi^+\rangle$, is a maximally *entangled Bell state* $\frac{1}{\sqrt{2}}(|00\rangle + |11\rangle)$ because measuring $q_0$ instantly determines $q_1$:with each outcome ('00' or '11') occurring with a $\mathbf{50\%}$ probability.
# * The amplitude for $|00\rangle$ is $1/\sqrt{2}$. The probability $P('00') = |1/\sqrt{2}|^2 = 0.5$
# * The amplitude for $|11\rangle$ is $1/\sqrt{2}$. The probability $P('11') = |1/\sqrt{2}|^2 = 0.5$

# %%
# IonQ Circuit and Transpilation

print("\n✅ Quantum Circuit and Transpilation")
display(Markdown(r"Two-Qubit maximally entangled [Bell State](https://en.wikipedia.org/wiki/Bell_state) preparation $|\Phi^+\rangle = \frac{1}{\sqrt{2}}(|00\rangle + |11\rangle)$ with each outcomes $|00\rangle$ and $|11\rangle$ at 50% probability."))
q0, q1 = cirq.LineQubit.range(2)
circuit = cirq.Circuit(
    cirq.H(q0),
    cirq.CNOT(q0, q1),
    cirq.measure(q0, q1, key='x'))
print(circuit)
# Out:
# ✅ Quantum Circuit and Transpilation
# Two-Qubit maximally entangled [Bell State](https://en.wikipedia.org/wiki/Bell_state) preparation $|\Phi^+\rangle = \frac{1}{\sqrt{2}}(|00\rangle + |11\rangle)$ with each outcomes $|00\rangle$ and $|11\rangle$ at 50% probability.
# 0: ───H───@───M('x')───
#           │   │
# 1: ───────X───M────────

# %%
# Local Simulation

print("\n✅ Local Simulation")
result = cirq.sample(
    circuit,
    repetitions=100)
print(result.histogram(key='x'))
print(result)
cirq.plot_state_histogram(result)
print(result.data)
# Out:
# ✅ Local Simulation
# Counter({0: 53, 3: 47})
# x=0001001000101100010001001100011001010000101011001001100110111010001001000111010011100111110101111101, 0001001000101100010001001100011001010000101011001001100110111010001001000111010011100111110101111101
#     x
# 0   0
# 1   0
# 2   0
# 3   3
# 4   0
# .. ..
# 95  3
# 96  3
# 97  3
# 98  0
# 99  3
#
# [100 rows x 1 columns]

# %%
# IonQ Simulation

print("\n✅ Noiseless simulation")
result = service.run(
    circuit=circuit,
    target="simulator",
    repetitions=100,
    name="Noiseless Cirq Simulation")
print(result.histogram(key='x'))
print(result)
with open('noiseless_result.pkl', 'wb') as f:
    pickle.dump(result, f)

print("\n✅ Noisy simulation")
# https://docs.ionq.com/guides/simulation-with-noise-models
result = service.run(
    circuit=circuit,
    target="simulator",
    repetitions=100,
    name="Noisy Cirq Simulation",
    extra_query_params={"noise": {"model": "forte-1"}})
print(result.histogram(key='x'))
print(result)
with open('noisy_result.pkl', 'wb') as f:
    pickle.dump(result, f)
# Out:
# ✅ Noiseless simulation
# Counter({3: 50, 0: 50})
# x=1101001000100111111101100111101010010001000000010100100001111000001001011101110111010001101110101101, 1101001000100111111101100111101010010001000000010100100001111000001001011101110111010001101110101101
#
# ✅ Noisy simulation
# Counter({0: 54, 3: 45, 1: 1})
# x=0000011111001010001000011101101010100110010111001010010011101101000010010110111001000001000110011100, 0000011111001010001000011101101010101110010111001010010011101101000010010110111001000001000110011100

# %%
# IonQ Quantum Computation ⚠️

print("\n✅ Quantum simulation")
# (https://docs.ionq.com/guides/qpu-submission-checklist)
job = service.create_job(
    circuit=circuit,
    target=BACKEND,
    repetitions=100,
    name="QPU Cirq Simulation")
print(job.job_id())
print(job.status())

# Retrieve a job
#job_id = "019a7d6c-a0fb-779b-9340-8795a9a2f1c0"
#job = service.get_job(job_id)

# Get the first result from the list -  https://cloud.ionq.com/jobs
results_list = job.results()
result = results_list[0].to_cirq_result()  # Access first element
print(result.histogram(key='x'))
# Save results into file
with open('quantum_result.pkl', 'wb') as f:
    pickle.dump(result, f)
# Out:
# ✅ Quantum simulation
# 019dcb89-89b9-775e-8af0-d4d49bab8474
# submitted
# Counter({3: 52, 0: 47, 1: 1})

# %%
# Plotting of results

print("\n✅ Comparison and Plotting of Results")
data = {}
for name in ['noiseless', 'noisy', 'quantum']:
    with open(f'{name}_result.pkl', 'rb') as f:
        result = pickle.load(f)
        data[name] = result.histogram(key='x')

# Create comparison DataFrame
states = range(4)
comparison_df = pd.DataFrame({
    'State': states,
    'Binary': [format(s, '02b') for s in states],
    'Noiseless': [data['noiseless'].get(s, 0) for s in states],
    'Noisy': [data['noisy'].get(s, 0) for s in states],
    'Quantum': [data['quantum'].get(s, 0) for s in states]
})

print(comparison_df.to_string(index=False))
print("="*50 + "\n")

# Plotting
fig = plt.figure(figsize=(24, 7))
fig.suptitle('Quantum Simulation Results Comparison', fontsize=20, fontweight='bold', y=0.98)

state_labels = ['|00⟩', '|01⟩', '|10⟩', '|11⟩']
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
plot_configs = [
    (1, 'Noiseless', 'Noiseless Simulation\n(100 shots)'),
    (2, 'Noisy', 'Noisy Simulation (forte-1)\n(100 shots)'),
    (3, 'Quantum', 'Quantum Result (forte-1)\n(100 shots)')
]

max_count = comparison_df[['Noiseless', 'Noisy', 'Quantum']].max().max()

# Individual plots
for idx, col, title in plot_configs:
    ax = plt.subplot(1, 3, idx)
    bars = ax.bar(state_labels, comparison_df[col], color=colors, alpha=0.8, edgecolor='black')
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.set_ylabel('Count', fontsize=12)
    ax.set_xlabel('Quantum State', fontsize=12)
    ax.set_ylim(0, max_count * 1.15)
    ax.grid(True, alpha=0.3)

    # Add count labels
    for bar, count in zip(bars, comparison_df[col]):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + max_count*0.01,
                f'{count}', ha='center', va='bottom', fontweight='bold', fontsize=10)

plt.subplots_adjust(left=0.05, bottom=0.1, right=0.98, top=0.85, wspace=0.2)
plt.show()
# Out:
# ✅ Comparison and Plotting of Results
#  State Binary  Noiseless  Noisy  Quantum
#      0     00         50     54       47
#      1     01          0      1        1
#      2     10          0      0        0
#      3     11         50     45       52
# ...

# %% [markdown]
# ###### <font color="blue">**IBM Quantum Computing**

# %%
# IBM libraries
# !pip install qiskit qiskit-ibm-runtime qiskit[visualization] -q
import matplotlib.pyplot as plt
import numpy as np
import qiskit
from google.colab import userdata
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit import QuantumCircuit
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler
from qiskit.visualization import plot_histogram
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from IPython.display import display, Markdown

# %%
# Connect to IBM backend
print("✅ Connect to IBM Quantum")
api_token = userdata.get('ibm-quantum')
service = QiskitRuntimeService(channel='ibm_quantum_platform', token=api_token)


print("\n✅ List of all backends")
available_backends = service.backends()
print("Available Quantum Backends:")
for b in available_backends:
    print(f"- {b.name} ({b.num_qubits} qubits)")

print("\n✅ Select quantum backend")
backend = service.backend('ibm_strasbourg')
# backend = service.least_busy(simulator=False, operational=True) # Choose automatically
print(f"Selected backend: {backend.name}")

#print("\n✅ Documentation")
#display(Markdown(r"Devices: https://eu-de.quantum.cloud.ibm.com/computers"))
#display(Markdown(r"Topology: https://eu-de.quantum.cloud.ibm.com/docs/de/guides/qpu-information"))
#display(Markdown(r"Jobs: https://eu-de.quantum.cloud.ibm.com/workloads"))
#display(Markdown(r"Cost: https://cloud.ibm.com/billing"))
#display(Markdown(r"Tutorials: https://eu-de.quantum.cloud.ibm.com/docs/de/tutorials"))
# Out:
# ✅ Connect to IBM Quantum
# qiskit_runtime_service._discover_account:WARNING:2026-04-26 20:49:58,662: Loading account with the given token. A saved account will not be used.
# qiskit_runtime_service.__init__:WARNING:2026-04-26 20:50:03,517: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (pay-as-you-go), the available account instances are: einstein. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# qiskit_runtime_service.backends:WARNING:2026-04-26 20:50:03,519: Loading instance: einstein, plan: pay-as-you-go
# ✅ List of all backends
# Available Quantum Backends:
# - ibm_strasbourg (127 qubits)
# - ibm_aachen (156 qubits)
# ...

# %% [markdown]
# **Use Case: Unequal Superposition Experiment**
#
# Creating non-uniform probability distributions by combining standard superposition gates with rotation gates.
#
# * **Circuit:**
#     1.  **Unequal Superposition:** $R_y(\pi/3)$ on $q_0 \rightarrow \frac{\sqrt{3}}{2}|0\rangle + \frac{1}{2}|1\rangle$.
#     2.  **Equal Superposition:** $H$ on $q_1 \rightarrow \frac{1}{\sqrt{2}}(|0\rangle + |1\rangle)$.
#     3.  **Bit-Flip:** $X$ on $q_3$ flips MSB $|0...\rangle \rightarrow |1...\rangle$.
#     4.  **Entanglement:** $CX_{0,2}$ flips $q_2$ if $q_0$ is $|1\rangle$.
# * **Final State:** $|\psi_{final}\rangle = \frac{\sqrt{3}}{2\sqrt{2}}|1000\rangle + \frac{\sqrt{3}}{2\sqrt{2}}|1010\rangle + \frac{1}{2\sqrt{2}}|1101\rangle + \frac{1}{2\sqrt{2}}|1111\rangle$
# * **Probabilities ($P = |\text{amplitude}|^2$):**
#     * $|1000\rangle, |1010\rangle$: $P = |\frac{\sqrt{3}}{2\sqrt{2}}|^2 = 3/8 = \textbf{37.5\%}$
#     * $|1101\rangle, |1111\rangle$: $P = |\frac{1}{2\sqrt{2}}|^2 = 1/8 = \textbf{12.5\%}$

# %%
# IBM Circuit Definition

# 4. Create the Quantum Circuit with Asymmetric State Evolution (with Unequal Superposition)
print("\n✅ Create unequal superposition (non-uniform probability distributions) with rotation gates Rᵧ(π3)")
display(Markdown(r"* Final State: $|\psi_{final}\rangle = \frac{\sqrt{3}}{2\sqrt{2}}|1000\rangle + \frac{\sqrt{3}}{2\sqrt{2}}|1010\rangle + \frac{1}{2\sqrt{2}}|1101\rangle + \frac{1}{2\sqrt{2}}|1111\rangle$"))
display(Markdown(r"* Probabilities ($P = |\text{amplitude}|^2$):: $|1000\rangle, |1010\rangle$: $P = |\frac{\sqrt{3}}{2\sqrt{2}}|^2 = 3/8 = \textbf{37.5\%}$ and $|1101\rangle, |1111\rangle$: $P = |\frac{1}{2\sqrt{2}}|^2 = 1/8 = \textbf{12.5\%}$"))

print("\n✅ Create the Quantum Circuit with Asymmetric State Evolution (with Unequal Superposition)")
qc = QuantumCircuit(4, 4)
qc.ry(np.pi / 3, 0) # Replace H(0) with Ry(pi/3, 0) to create a 75%/25% split
qc.h(1)             # Keep the H on q1 for a 50/50 split
qc.barrier()
qc.cx(0, 2)
qc.x(3)
qc.barrier()
qc.measure([0, 1, 2, 3], [0, 1, 2, 3])
#print("\nIdeal Circuit Diagram:")
display(qc.draw("mpl"))
# Out:
# ✅ Create unequal superposition (non-uniform probability distributions) with rotation gates Rᵧ(π3)
# * Final State: $|\psi_{final}\rangle = \frac{\sqrt{3}}{2\sqrt{2}}|1000\rangle + \frac{\sqrt{3}}{2\sqrt{2}}|1010\rangle + \frac{1}{2\sqrt{2}}|1101\rangle + \frac{1}{2\sqrt{2}}|1111\rangle$
# * Probabilities ($P = |\text{amplitude}|^2$):: $|1000\rangle, |1010\rangle$: $P = |\frac{\sqrt{3}}{2\sqrt{2}}|^2 = 3/8 = \textbf{37.5\%}$ and $|1101\rangle, |1111\rangle$: $P = |\frac{1}{2\sqrt{2}}|^2 = 1/8 = \textbf{12.5\%}$
# ✅ Create the Quantum Circuit with Asymmetric State Evolution (with Unequal Superposition)

# %%
# 5. Transpile circuit for backend (translates ideal circuit into one the hardware can run)
print(f"\n✅ Transpiled Circuit for Backend {backend.name} (translates ideal circuit into one the hardware can run)")
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(qc)
#print(f"\nTranspiled Circuit for {backend.name}:")
display(isa_circuit.draw("mpl"))
# Out:
# ✅ Transpiled Circuit for Backend ibm_strasbourg (translates ideal circuit into one the hardware can run)

# %%
# Apendix: Run local Simulation

# ----- Local Simulation ----
print("\n✅ Run local simulation")
from qiskit.primitives import StatevectorSampler as LocalSampler
from qiskit.visualization import plot_histogram

local_sampler = LocalSampler() # Create local sampler
local_shots = 1024
local_job = local_sampler.run(pubs=[(qc,)], shots=local_shots) # Run circuit
local_result = local_job.result()
local_counts = local_result[0].data.c.get_counts() # Extract counts from result
print(f"Local Simulation results (counts) with {local_shots} shots:")
print(local_counts)
print("\nProbabilities:")
for bitstring, count in sorted(local_counts.items()):
    probability = count / local_shots
    print(f"  |{bitstring}>: {probability:.3f} ({count}/{local_shots})")

display(plot_histogram(local_counts, title="Local Simulation Results"))
# Out:
# ✅ Run local simulation
# Local Simulation results (counts) with 1024 shots:
# {'1010': 389, '1000': 371, '1101': 130, '1111': 134}
#
# Probabilities:
#   |1000>: 0.362 (371/1024)
#   |1010>: 0.380 (389/1024)
#   |1101>: 0.127 (130/1024)
#   |1111>: 0.131 (134/1024)

# %%
# IBM Quantum Computation ⚠️

# 6. Run job on IBM quantum computer
print("\n✅ Run job on IBM quantum computer")
sampler = Sampler(mode=backend)
shots = 1024
print(f"\nSubmitting job to {backend.name}...")
job = sampler.run(pubs=[(isa_circuit,)], shots=shots) # Run transpiled 'isa_circuit', not original 'qc'
print(f"Job submitted successfully! Job ID: {job.job_id()}")

print("\n✅ Job Status")
print(f"{job.status()}")

print("\n✅ Job metrics")
print(f"{job.metrics()}")

print("\n✅ Job result")
print(f"{job.result()}")
# Out:
# ✅ Run job on IBM quantum computer
#
# Submitting job to ibm_strasbourg...
# /usr/local/lib/python3.12/dist-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:1003: UserWarning: The backend ibm_strasbourg currently has a status of maintenance.
#   warnings.warn(
# Job submitted successfully! Job ID: d7n7l86cfkrc73cssr90
#
# ✅ Job Status
# QUEUED
#
# ✅ Job metrics
# {'caller': 'qiskit_ibm_runtime~sampler.py', 'qiskit_version': 'qiskit_ibm_runtime-0.46.1,qiskit-2.4.1*', 'timestamps': {'created': '2026-04-26T20:50:40.520906Z', 'finished': None, 'running': None}, 'bss': {'seconds': 0}, 'usage': {'quantum_seconds': 0, 'seconds': 0}}
#
# ✅ Job result

# %%
# 7. Get and display results

print("\n✅ Get and display results")
result = job.result()
counts = result[0].data.c.get_counts()
print("\nMeasurement Results (Counts):")
print(counts)
plot_histogram(counts)

#display(plot_histogram(counts, title="Quantum Computation Results"))

# %% [markdown]
# Devices: https://eu-de.quantum.cloud.ibm.com/computers
#
# Topology: https://eu-de.quantum.cloud.ibm.com/docs/de/guides/qpu-information
#
# Jobs: https://eu-de.quantum.cloud.ibm.com/workloads
#
# Cost: https://cloud.ibm.com/billing
#
# Tutorials: https://eu-de.quantum.cloud.ibm.com/docs/de/tutorials

# %% [markdown]
# ###### <font color="blue">**Alice & Bob Quantum Computing**

# %%
# !pip install -U qiskit-alice-bob-provider -q
from google.colab import userdata
from qiskit_alice_bob_provider import AliceBobRemoteProvider
from qiskit import QuantumCircuit, transpile

# %%
# 1. Retrieve API key and connect to Alice & Bob
api_token = userdata.get('alicebob')
provider = AliceBobRemoteProvider(api_key=api_token)

# %%
# 2. List available backends
for backend in provider.backends():
    print(backend.name)
# Out:
# EMU:1Q:LESCANNE_2020
# QPU:1Q:BOSON_4A
# QPU:1Q:BOSON_4B
# QPU:1Q:BOSON_4C
# EMU:6Q:PHYSICAL_CATS
# EMU:40Q:PHYSICAL_CATS
# EMU:40Q:LOGICAL_TARGET
# EMU:40Q:LOGICAL_NOISELESS
# EMU:15Q:LOGICAL_EARLY

# %%
# 3. Select backend (QPU quantum or EMU emulator)
backend = provider.get_backend('EMU:6Q:PHYSICAL_CATS', average_nb_photons=10.0)
print(f"Selected backend: {backend.name}")
# Out:
# Selected backend: EMU:6Q:PHYSICAL_CATS

# %%
# 4. Define Quantum Circuit
# Use case: Measure bit-flip probability of a single qubit after a 1ms delay (Qiskit)
qc = QuantumCircuit(1, 1)
qc.initialize('1', 0)
qc.delay(duration=1, qarg=0, unit='ms')
qc.measure(0, 0) # Measures bit-flip probability of single qubit after a 1ms delay
print(qc.draw())
# Out:
#      ┌───────────────┐┌──────────────┐┌─┐
#   q: ┤ Initialize(1) ├┤ Delay(1[ms]) ├┤M├
#      └───────────────┘└──────────────┘└╥┘
# c: 1/══════════════════════════════════╩═
#                                        0

# %%
# 6. Transpile circuit to specific backend to ensure correct error-correction properties
transpiled = transpile(qc, backend)
print(transpiled.draw())
# Out:
#      ┌───────────────┐┌─────────────────┐┌─┐
#    q ┤ Initialize(1) ├┤ Delay(0.001[s]) ├┤M├
#      └───────────────┘└─────────────────┘└╥┘
# c: 1/═════════════════════════════════════╩═
#                                           0

# %%
# 7. Run circuit on Felis Cloud
job = backend.run(transpiled, shots=1000)

# %%
# 8. Get results
res = job.result()
print(f"Job Status: {job.status()}")
print(f'Total counts: {res.get_counts()}')
# Out:
# Job Status: JobStatus.DONE
# Total counts: {'1': 1000}

# %%
# Console: https://api-gcp.alice-bob.com/console
# Backend: https://felis.alice-bob.com/docs/backends/about_backends/
# Status:  https://felis.alice-bob.com/docs/felis_cloud/hardware_availability_schedule/
# Samples: https://github.com/Alice-Bob-SW/felis/tree/main/samples

# %% [markdown]
# ##### <font color="blue">*Tensor Algebra*

# %% [markdown]
# ###### Core

# %% [markdown]
# <font color="blue">*Bilinearformen und ihre Geometrien — von der Tensoralgebra zur Quantisierung*
#
# <font color="blue">**A. Titel und Einordnung**
#
# * **Klammer aller Themen:** Wähle eine Bilinearform auf $V$ — daraus folgen Algebra, Geometrie, Symmetriegruppe und Physik. Die Themen sind nicht sechs Gebiete, sondern ein Bauplan mit Schaltern (→ Notiz *Vier Schalter, ein Bauplan*).
# * **Verworfene Alternative:** „Algebraische Differentialgeometrie der modernen Physik" — kein etabliertes Fachgebiet, und deckt nur ~2/3 der Notizen:
#   * Der diskrete Phasenraum (Pauli-Gruppe über $\mathbb{Z}_d$, Gottesman-Knill, Magic States) ist *keine* Differentialgeometrie — keine Mannigfaltigkeiten, keine Glattheit, keine Ableitungen, sondern Darstellungstheorie und symplektische lineare Algebra über endlichen Ringen.
#   * Die zyklische Kohomologie sprengt den Rahmen bewusst — sie existiert genau dort, wo klassische Differentialgeometrie versagt (nichtkommutative Algebren).
# * **Etablierte Fachbegriffe dahinter:** Deformationsquantisierung bzw. PBW-Deformationen quadratischer Algebren.
#
# ---
#
# <font color="blue">**B. Rohmaterial: die Tensoralgebra**
#
# * Alles beginnt mit der freien, regellosen **Tensoralgebra** $T(V) = \bigoplus_{k=0}^{\infty} V^{\otimes k}$: assoziativ, nicht kommutativ, keine Relationen. Sie ist der wilde Urzustand, aus dem alles andere gebaut wird.
# * **Konstruktionsprinzip:** Struktur entsteht durch **Quotient nach einem Ideal** — bestimmte Elemente werden „per Dekret zu Null erklärt", wodurch dem Raum eine Rechenregel (und damit eine Geometrie) aufgezwungen wird. Mechanik im Detail (Ideal als „schwarzes Loch der Multiplikation", Herleitung der Antisymmetrie aus $v \otimes v = 0$): → Notiz *Quotient und Ideal der Tensor Algebra*.
#
# ---
#
# <font color="blue">**C. Die vier kanonischen Quotienten**
#
# *(Wichtig: vier, nicht drei — ohne $\mathrm{Sym}(V)$ fehlt der klassische Phasenraum, und PBW hätte kein Ziel.)*
#
# * **Äußere Algebra (Graßmann):** $\Lambda(V) = T(V)\,/\,\langle v \otimes v \rangle \;\Rightarrow\; v \wedge w = -\,w \wedge v$ — Basis für Differentialformen und Kohomologie.
# * **Symmetrische Algebra (Polynome):** $\mathrm{Sym}(V) = T(V)\,/\,\langle v \otimes w - w \otimes v \rangle \;\Rightarrow\; vw = wv$ — klassische Observablen, Funktionen auf dem Phasenraum (zugleich das Startobjekt der algebraischen Geometrie: Koordinatenring des affinen Raums).
# * **Clifford-Algebra** (deformiert $\Lambda$ mit *symmetrischer* Form $Q$): $\mathrm{Cl}(V,Q) = T(V)\,/\,\langle v \otimes v - Q(v)\mathbf{1}\rangle \;\Rightarrow\; vw + wv = 2Q(v,w)$ — Raum für Fermionen und Spinoren (CAR).
# * **Weyl-Algebra** (deformiert $\mathrm{Sym}$ mit *antisymmetrischer* Form $\omega$): $W(V,\omega) = T(V)\,/\,\langle v \otimes w - w \otimes v - \omega(v,w)\mathbf{1}\rangle \;\Rightarrow\; [v,w] = \omega(v,w)$ — Phasenraum-Quantisierung, Bosonen (CCR). In der Physik: (Heisenberg-)Weyl-Algebra.
#
# ---
#
# <font color="blue">**D. Zwei Achsen statt Hierarchie**
#
# Es gibt **keine Verschachtelung und keine Spezialfälle von Spezialfällen**. Stattdessen zwei völlig unabhängige Achsen:
#
# <br>
#
# $
# \begin{array}{c}
# \begin{array}{|c|}
# \hline
# \mathbf{T(V)} \\
# \hline
# \end{array} \\
# \downarrow \\
# \overbrace{
# \begin{array}{ccc}
# \begin{array}{|c|}
# \hline
# \color{#3B2384}{\mathbf{\Lambda(V)}} \\
# \color{#3B2384}{\text{äußere Algebra, } Q = 0} \\
# \hline
# \end{array}
# & \xrightarrow[\text{gr: Chevalley}]{\quad \text{Q einschalten} \quad} &
# \begin{array}{|c|}
# \hline
# \color{#3B2384}{\mathbf{Cl(V, Q)}} \\
# \color{#3B2384}{\text{Clifford, } Q \neq 0} \\
# \hline
# \end{array} \\
# \\
# \begin{array}{|c|}
# \hline
# \color{#094935}{\mathbf{Sym(V)}} \\
# \color{#094935}{\text{Polynome, } \omega = 0} \\
# \hline
# \end{array}
# & \xrightarrow[\text{gr: PBW}]{\quad \omega \text{ einschalten} \quad} &
# \begin{array}{|c|}
# \hline
# \color{#094935}{\mathbf{W(V, \omega)}} \\
# \color{#094935}{\text{Weyl, } \omega \neq 0} \\
# \hline
# \end{array}
# \end{array}
# }^{\text{Quotientenbildung}}
# \end{array}
# $
#
# <br>
#
# * **Senkrecht = Konstruktion:** Alle vier sind gleichrangige Geschwister-Quotienten von $T(V)$, keiner ist Kind eines anderen.
# * **Waagerecht = Deformation:** Je zwei bilden eine Familie; links der Parameter aus, rechts an. „Spezialfall" heißt hier **Parameterstellung** ($Q=0$ bzw. $\omega=0$, physikalisch $\hbar \to 0$ = klassischer Limes), niemals Teilmenge.
# * **Quotient ≠ Teilmenge:** Ein Quotient schneidet nichts heraus, er **klebt zusammen** (Äquivalenzklassen). $\Lambda(V)$ liegt nicht *in* $T(V)$. (In Char. 0 gibt es eine Einbettung der antisymmetrischen Tensoren zurück — aber nur als Vektorräume, nicht als Algebren; der Faktor $\tfrac{(k+l)!}{k!\,l!}$ im Alternierungsoperator ist genau der Beleg, dass $\wedge$ nicht die Einschränkung von $\otimes$ ist.)
# * **Warum beide Achsen zusammenpassen:** $\langle v\otimes v\rangle$ ist **homogen** (reiner Grad 2) → Quotient erbt die $\mathbb{Z}$-Graduierung. $\langle v\otimes v - Q(v)\mathbf{1}\rangle$ ist **inhomogen** (mischt Grad 2 und 0) → nur noch Filtrierung (plus $\mathbb{Z}_2$-Graduierung). **$\mathrm{gr}$ = Deformation wieder ausschalten:** nur den höchstgradigen Anteil jeder Relation behalten → $\mathrm{gr}\,\mathrm{Cl}(V,Q) \cong \Lambda(V)$ (Chevalley), $\mathrm{gr}\,W(V,\omega) \cong \mathrm{Sym}(V)$ (PBW).
# * **Härtetest (Dimension):** Für $\dim V = 2$ haben $\Lambda(\mathbb{R}^2)$ und $\mathrm{Cl}(\mathbb{R}^2,Q)$ beide Dimension 4 mit Basis $\{1, e_1, e_2, e_1 e_2\}$ — Teilmengenbeziehung ausgeschlossen. Gleiches Vektorraumgerüst, andere Multiplikationstabelle: $e_1 \wedge e_1 = 0$ dort, $e_1 e_1 = Q(e_1)$ hier.
#
# > **Merksatz:** Deformation ändert das Produkt, nicht den Raum. Der Quotient sucht den Raum aus, die Bilinearform stellt das Produkt ein.
#
# * Namenskonvention am Rande: Familien werden nach ihrem *generischen* Mitglied benannt, nicht nach dem entarteten Nullpunkt — daher „Clifford-Algebren" (1878), obwohl der Nullpunkt der Familie älter ist und einen eigenen Namen trägt (Graßmann 1844).
#
# ---
#
# <font color="blue">**E. Die große Dualität: symmetrischer vs. antisymmetrischer Zweig**
#
# | Eigenschaft | Der „symmetrische" Zweig | Der „antisymmetrische" Zweig |
# | :--- | :--- | :--- |
# | Fundamentale Form | symmetrisch: Metrik $g$ bzw. $Q$ | antisymmetrisch: symplektische Form $\omega$ |
# | Klassische Algebra ($\hbar \to 0$) | $\Lambda(V)$ — Differentialformen | $\mathrm{Sym}(V)$ — Polynome, klassischer Phasenraum |
# | Quantisierte Algebra | $\mathrm{Cl}(V,Q)$ | $W(V,\omega)$ — (Heisenberg-)Weyl |
# | Definierende Relation | $vw + wv = 2Q(v,w)$ | $[v,w] = \omega(v,w)$ |
# | Quanten-Relation | Antikommutatoren, CAR: $\{a_i, a_j^\dagger\} = \delta_{ij}$ | Kommutatoren, CCR: $[a_i, a_j^\dagger] = \delta_{ij}$ |
# | Grad-2-Elemente (Lie-Algebra) | $\mathfrak{so} \cong \Lambda^2 V$ | $\mathfrak{sp} \cong \mathrm{Sym}^2 V$ |
# | Gruppe → Doppelüberlagerung | $SO(n) \to \mathrm{Spin}(n)$ | $Sp(2n) \to \mathrm{Mp}(2n)$ (metaplektisch) |
# | Darstellung / Fock-Raum | Spinor-Darstellung; fermionischer Fock $= \Lambda(\mathbb{C}^n)$ | Oszillator-Darstellung; bosonischer Fock $= \mathrm{Sym}$ |
# | Geometrie (Feld-Ebene) | Riemannsch — lokale Krümmung existiert | Symplektisch — Darboux: keine lokalen Invarianten |
# | Physik | Raumzeit, Spin, Fermionen, Dirac | Phasenraum, Ort/Impuls, Bosonen, QM |
# | QC: Grad 2 = klassisch simulierbar | Matchgates / freie Fermionen (Valiant) | Clifford-Schaltkreise / Gaussian (Gottesman-Knill) |
# | QC: jenseits Grad 2 | Wechselwirkungen (Grad $\geq 4$ in $a, a^\dagger$) | Magic States / non-Gaussian (Grad $\geq 3$) |
#
# * Die beiden Spalten sind zueinander **dual**, aber nicht ineinander enthalten. In der Supersymmetrie werden sie zu einer einzigen Konstruktion auf $\mathbb{Z}_2$-graduierten Vektorräumen vereinigt.
# * Die Weyl-Algebra heißt in der Literatur (Crumeyrolle) daher **„symplektische Clifford-Algebra"** — das exakte bosonische Spiegelbild der Clifford-Algebra.
# * Die letzten beiden Zeilen sind der **Gradfilter auf beiden Ästen**: Beide Simulierbarkeitstheoreme sind strukturell dasselbe Theorem, einmal für $Sp(2n)$/metaplektisch, einmal für $SO(2n)$/Spin.
#
# ---
#
# <font color="blue">**F. Die beiden Klassisch→Quanten-Übergänge (parallel dokumentiert)**
#
# * Die Sammlung enthält **beide Quantisierungen parallel** — dieselbe Operation (PBW-Deformation durch eine Bilinearform), zweimal ausgeführt:
#   * **Fermionische Quantisierung:** $\Lambda(V) \xrightarrow{\;Q \text{ einschalten}\;} \mathrm{Cl}(V,Q)$ — aus Differentialformen werden Spinoren/CAR.
#   * **Bosonische Quantisierung:** $\mathrm{Sym}(V) \xrightarrow{\;\omega \text{ einschalten}\;} W(V,\omega)$ — aus Phasenraum-Polynomen werden Operatoren/CCR.
# * Der Rückweg ist in beiden Fällen $\mathrm{gr}$ = klassischer Limes ($\hbar \to 0$).
# * **Zyklische Kohomologie als Brücke (Connes):** Das eine Werkzeug der Sammlung, das beide Äste wieder zusammenführt. De-Rham-Kohomologie ist die Homologie-Theorie der *kommutativen* Funktionenalgebra; zyklische Kohomologie ist ihre Fortsetzung auf *nichtkommutative* Algebren — sie erlaubt „Differentialgeometrie auf der Weyl-Seite". Paar-Merkregel: de Rham : kommutativ $\;=\;$ zyklisch : nichtkommutativ.
# * *(Offenes Arbeitsfeld: diese Brücke ausarbeiten — Connes' Charakter, Hochschild vs. zyklisch, Anwendung auf die HW-Algebra.)*
#
# ---
#
# <font color="blue">**G. Querverweise**
#
# * Gesamtkarte (Form? deformiert? Feld? global? diskret?): → Notiz *Vier Schalter, ein Bauplan*.
# * Mainstream vs. exotisch (Kern-Kanon / etabliert-fortgeschritten / Ausreißer GA·diskreter Phasenraum·NCG): → Notiz *Ausreißer*.
# * Mechanik von Quotient und Ideal im Detail: → Notiz *Quotient und Ideal der Tensor Algebra*.

# %% [markdown]
# ###### *Appendix*

# %% [markdown]
# <font color="blue">**Quotient und Ideal der Tensor Algebra**
#
# 1. **Die vier Algebren als Quotienten der Tensoralgebra**
#
# Alle vier Strukturen entstehen aus derselben Tensoralgebra $T(V) = \bigoplus_k V^{\otimes k}$, nur mit unterschiedlichen Relationen:
#
# * **Äußere Algebra (Graßmann):** $\Lambda(V) = T(V)\,/\,\langle v \otimes v \rangle \quad\Rightarrow\quad v \wedge w = -\,w \wedge v$
# * **Symmetrische Algebra (Polynome):** $\mathrm{Sym}(V) = T(V)\,/\,\langle v \otimes w - w \otimes v \rangle \quad\Rightarrow\quad vw = wv$
# * **Clifford-Algebra** (deformiert $\Lambda$ mit einer *symmetrischen* Form $Q$): $\mathrm{Cl}(V,Q) = T(V)\,/\,\langle v \otimes v - Q(v)\rangle \quad\Rightarrow\quad vw + wv = 2Q(v,w)$
# * **Weyl-Algebra** (deformiert $\mathrm{Sym}$ mit einer *antisymmetrischen* Form $\omega$): $W(V,\omega) = T(V)\,/\,\langle v \otimes w - w \otimes v - \omega(v,w)\rangle \quad\Rightarrow\quad [v,w] = \omega(v,w)$
#
# Die Paarung ist also nicht „antisymmetrisch gehört zu antisymmetrisch", sondern überkreuzt:
#
# | | undeformiert ($Q=0$ <br>bzw. $\omega=0$) | deformiert | Physik | Statistik |
# |---|---|---|---|---|
# | **antikommutierende Familie** | $\Lambda(V)$ (Differentialformen) | $\mathrm{Cl}(V,Q)$, $Q$ symmetrisch | Spin, Dirac | Fermionen, CAR: $\{a_i, a_j^\dagger\} = \delta_{ij}$ |
# | **kommutierende Familie** | $\mathrm{Sym}(V)$ (Polynome) | $W(V,\omega)$, $\omega$ antisymmetrisch | Ort/Impuls, $[\hat q,\hat p]=i\hbar$ | Bosonen, CCR: $[a_i, a_j^\dagger] = \delta_{ij}$ |
#
# * Beachte die strukturelle Parallele: $\mathrm{gr}\,\mathrm{Cl}(V,Q) \cong \Lambda(V)$ (Chevalley-Isomorphismus, als Vektorräume sogar $\mathrm{Cl} \cong \Lambda V$) und $\mathrm{gr}\,W(V,\omega) \cong \mathrm{Sym}(V)$ (Poincaré–Birkhoff–Witt).
# * Die Weyl-Algebra wird deshalb in der Literatur (z. B. bei Crumeyrolle) tatsächlich **„symplektische Clifford-Algebra"** genannt — sie ist das exakte bosonische Spiegelbild der Clifford-Algebra, aber sie ist *keine* Unterstruktur der äußeren Algebra.
# * Die beiden Spalten der Tabelle sind zueinander dual (in der Supersymmetrie werden sie zu einer einzigen Konstruktion auf $\mathbb{Z}_2$-graduierten Vektorräumen vereinigt), aber sie sind nicht ineinander enthalten.
#
# 2. **Quotient: Prinzip des „Zusammenfassens“ (gezielten Nullsetzen)**
#   * Einen Quotienten zu bilden (z. B. $T(V)/I$), bedeutet: **Wir nehmen einen großen Raum und erklären bestimmte Dinge per Dekret für gleich null.**
#   * Wir nehmen die gewöhnliche Tensoralgebra $T(V)$. Dort existiert das Element $v \otimes v$. Du sagst jetzt: "Für meine neue äußere Algebra möchte ich, dass dieses Element gar nicht mehr da ist. Es soll null sein." Genau das macht der Quotient. Wenn du den Quotienten $T(V)/I$ bildest, sagst du: **Alles, was in der Menge $I$ liegt, ist ab sofort exakt $0$.**
#   * Dadurch entstehen Äquivalenzklassen. Wenn zwei Elemente $A$ und $B$ sich nur um ein Element aus $I$ unterscheiden (also $A - B \in I$), dann gelten sie in der neuen Algebra als **dasselbe Element**, denn ihr Unterschied ist ja nun "null". Die Quotientenbildung staucht den riesigen Raum $T(V)$ also zusammen, indem sie Dinge, die wir nicht mehr unterscheiden wollen, "verklebt".
#
# 3. **Ideal: Das „Schwarze Loch“ der Multiplikation**
#   * Warum sprechen wir von einem *Ideal* und nicht einfach von einer *Menge* $I$? Wenn wir Dinge null setzen wollen, müssen wir extrem aufpassen, dass wir unsere Rechenregeln (besonders die Multiplikation) nicht kaputt machen.
#   * Wenn wir sagen: $v \otimes v = 0$, was passiert dann, wenn wir von links oder rechts noch etwas anderes dranmultiplizieren? Zum Beispiel einen beliebigen Tensor $A$? Es muss zwingend gelten: $A \otimes (v \otimes v) = A \otimes 0 = 0$.
#   * Ein **Ideal** ist ein spezieller Unterraum, der genau wie ein **schwarzes Loch für die Multiplikation** funktioniert. Es hat die Eigenschaft: Wenn ein Element $x$ im Ideal $I$ liegt und $A$ *irgendein* Element aus der gesamten Algebra ist, dann müssen auch die Produkte $A \otimes x$ und $x \otimes A$ wieder im Ideal $I$ liegen. Nur wenn die Menge, die wir zu Null erklären, diese "Schwarzes-Loch-Eigenschaft" (Absorptions-Eigenschaft) hat, funktioniert die Multiplikation im neuen Quotientenraum noch reibungslos. Deshalb reicht uns nicht irgendein Unterraum, wir brauchen ein Ideal.
#
# 4. **Wie das Ideal die Antisymmetrie erzwingt**
#   * Mechanismus bei äußerer Algebra funktioniert: Das Ideal $I$ wird von allen Elementen der Form $v \otimes v$ erzeugt. Im Quotientenraum $\Lambda(V) = T(V)/I$ ist also jedes $v \otimes v = 0$. Das nennen wir ab jetzt $v \wedge v = 0$.
#   * Warum erzwingt dieses simple "Quadrate sind null" nun plötzlich, dass alles andere antisymmetrisch wird?
#
#
# 5. **Beispiel**
#
# * Nehmen wir zwei Vektoren $v$ und $w$. Wir betrachten den Vektor $(v+w)$. Weil *jedes* Element mit sich selbst im Ideal liegt, muss auch gelten:
#
# $$(v+w) \otimes (v+w) \in I$$.
#
# * Im Quotientenraum ist das also null. Rechnen wir das mal stur aus (wie beim Ausmultiplizieren von Klammern):
#
#
# $$(v+w) \wedge (v+w) = 0$$
#
# $$v \wedge v + v \wedge w + w \wedge v + w \wedge w = 0$$
#
# * Da wir aber schon wissen, dass $v \wedge v = 0$ und $w \wedge w = 0$ (sie stammen ja aus unserem Ideal), fallen diese Terme weg. Es bleibt übrig:
#
#
# $$v \wedge w + w \wedge v = 0$$
#
# $$v \wedge w = - (w \wedge v)$$
#
# * Ergebnis: Nur durch das Nullsetzen von $v \otimes v$ über das Ideal haben wir ganz elegant bewiesen, dass das Vertauschen von zwei verschiedenen Vektoren automatisch das Vorzeichen umdreht.
#
# * **Der universelle Baukasten (Clifford- und Heisenberg-Algebra)**
#   * Genau dieses Prinzip wendet man an, um fast alle Algebren zu konstruieren, die du erwähnt hast. Man startet *immer* mit der gigantischen, völlig regellosen Tensoralgebra $T(V)$ und schneidert sie sich durch ein passendes Ideal zurecht:
#   * **Äußere Algebra:** Ideal ist $v \otimes v$. (Führt zu $v \wedge w = - w \wedge v$).
#   * **Geometrische / Clifford Algebra:** Man möchte, dass das Quadrat eines Vektors seine Länge (oder quadratische Form $Q$) ist. Also definiert man das Ideal $I = \langle v \otimes v - Q(v) \cdot 1 \rangle$. Im Quotienten gilt dann automatisch $v^2 = \|v\|^2$.
#   * **Symmetrische Algebra:** Man möchte, dass die Reihenfolge egal ist. Das Ideal ist $v \otimes w - w \otimes v$. Im Quotienten gilt dann $v \cdot w = w \cdot v$.
#   * Quotient und Ideal sind also im Grunde nur die mathematisch wasserdichte Methode zu sagen: *"Nimm diese rohe Bausubstanz und wende ab jetzt strikt diese eine neue Rechenregel an."*

# %% [markdown]
# <font color="blue">**(1) Du sagtest: exterior algebra = spezialfall der clifford algebra und symmetrische algebra = spezialfall de weyl algebra, aber aus den notizen scheint eher das gegenteil. Wo sehe ich etwas nicht richtig? (2) Auch aus der quotientenbildung (die ich gut verstanden habe), gilt immer noch, dass exterior algebra und symmetrische algebra sowohl als quotient aus der tensor algebra geschnitten werden können (also untermengen sind) als auch untermengen (spezielfälle der clifford und weyl algebra sind? Also spezialfälle aus spezielfällen?**
#
# Beide Fragen haben dieselbe Wurzel: „Spezialfall" und „Quotient" bedeuten hier **nicht** „Teilmenge". Sobald das getrennt ist, lösen sich beide Knoten auf.
#
# 1. Kein Widerspruch — dieselbe Aussage, zwei Leserichtungen
#
# * $\mathrm{Cl}(V,Q)$ ist keine einzelne Algebra, sondern eine **Familie**, parametrisiert durch die Form $Q$.
# * Setzt man $Q = 0$, wird das Ideal $\langle v\otimes v - Q(v)\mathbf{1}\rangle$ zu $\langle v\otimes v\rangle$ — und der Quotient ist wörtlich $\Lambda(V)$. Also:
#
# > „Cl deformiert $\Lambda$" $\;=\;$ „$\Lambda$ ist Cl beim Parameterwert 0"
#
# * Das ist ein und derselbe Satz, einmal vorwärts, einmal rückwärts gelesen. Deine Notiz „keine Unterstruktur" bezieht sich auf *Teilmengen* und ist völlig richtig — mein „Spezialfall" meinte nie eine Teilmenge, sondern eine Parameterstellung.
#
# * Der physikalische Anker macht es greifbar: Auf der symplektischen Seite ist der Parameter $\hbar$. $\mathrm{Sym}(V) = W(V,\omega)$ bei $\hbar \to 0$ ist genau der **klassische Limes** — und deine eigene Tabelle nennt Sym ja bereits „klassischer Phasenraum". „Spezialfall" heißt hier also schlicht: klassischer Grenzfall der Quantenalgebra.
#
# * Kleine Namensmarotte am Rande: Familien werden nach ihrem *generischen* Mitglied benannt, nicht nach dem entarteten. Deshalb heißt die Familie „Clifford-Algebren", obwohl ihr Nullpunkt einen eigenen, älteren Namen trägt (Graßmann 1844 ist 34 Jahre älter als Clifford 1878).
#
# 2. Quotient ist keine Teilmenge — und es gibt keine Verschachtelung
#
# * Hier steckt der eigentliche Denkfehler: Du schreibst „als Quotient aus der Tensoralgebra geschnitten (also Untermengen)". Ein Quotient **schneidet nichts heraus, er klebt zusammen**. Die Elemente von $\Lambda(V)$ sind Äquivalenzklassen, keine ausgewählten Tensoren. $\Lambda(V)$ liegt nicht *in* $T(V)$.
#
# * (Feinheit, die genau deine Alt-Notiz betrifft: In Charakteristik 0 gibt es zwar eine Einbettung der antisymmetrischen Tensoren zurück in $T(V)$ — aber nur als Vektorräume, nicht als Algebren. Der Faktor $\frac{(k+l)!}{k!\,l!}$ in deiner Formel $\alpha\wedge\beta = \frac{(k+l)!}{k!l!}\mathrm{Alt}(\alpha\otimes\beta)$ ist genau der Korrekturfaktor, der zeigt: $\wedge$ ist nicht die Einschränkung von $\otimes$.)
#
# * Damit gibt es **keine Verschachtelung und keine Spezialfälle von Spezialfällen**. Stattdessen zwei völlig unabhängige Achsen:
#
# <br>
#
# $
# \begin{array}{c}
# \begin{array}{|c|}
# \hline
# \mathbf{T(V)} \\
# \hline
# \end{array} \\
# \downarrow \\
# \overbrace{
# \begin{array}{ccc}
# \begin{array}{|c|}
# \hline
# \color{#3B2384}{\mathbf{\Lambda(V)}} \\
# \color{#3B2384}{\text{äußere Algebra, } Q = 0} \\
# \hline
# \end{array}
# & \xrightarrow[\text{gr: Chevalley}]{\quad \text{Q einschalten} \quad} &
# \begin{array}{|c|}
# \hline
# \color{#3B2384}{\mathbf{Cl(V, Q)}} \\
# \color{#3B2384}{\text{Clifford, } Q \neq 0} \\
# \hline
# \end{array} \\
# \\
# \begin{array}{|c|}
# \hline
# \color{#094935}{\mathbf{Sym(V)}} \\
# \color{#094935}{\text{Polynome, } \omega = 0} \\
# \hline
# \end{array}
# & \xrightarrow[\text{gr: PBW}]{\quad \omega \text{ einschalten} \quad} &
# \begin{array}{|c|}
# \hline
# \color{#094935}{\mathbf{W(V, \omega)}} \\
# \color{#094935}{\text{Weyl, } \omega \neq 0} \\
# \hline
# \end{array}
# \end{array}
# }^{\text{Quotientenbildung}}
# \end{array}
# $
#
# <br>
#
# * **Senkrecht = Konstruktion:** Alle vier sind gleichrangige Geschwister-Quotienten von $T(V)$, keiner ist Kind eines anderen.
# * **Waagerecht = Deformation:** Je zwei bilden eine Familie; links der Parameter aus, rechts an.
# * Beide Aussagen gelten gleichzeitig, ohne Hierarchie — es sind einfach zwei verschiedene Fragen an dasselbe Objekt („woraus gebaut?" vs. „welcher Parameterwert?").
#
# 3. Warum die zwei Achsen technisch zusammenpassen
#
# * Der Grund steckt in einem Unterschied zwischen den Idealen, den man leicht übersieht:
#   - $\langle v\otimes v\rangle$ ist **homogen** — erzeugt von Elementen reinen Grades 2. Der Quotient erbt die Graduierung: $\Lambda = \bigoplus_k \Lambda^k$.
#   - $\langle v\otimes v - Q(v)\mathbf{1}\rangle$ ist **inhomogen** — es mischt Grad 2 mit Grad 0. Die Graduierung bricht zusammen; es bleibt nur eine *Filtrierung* $\mathrm{Cl}^{\le k}$ (plus die $\mathbb{Z}_2$-Graduierung gerade/ungerade, weil $2 \equiv 0 \bmod 2$).
# * Und damit wird deine eigene Notiz $\mathrm{gr}\,\mathrm{Cl} \cong \Lambda$ durchsichtig: „Assoziiert graduiert" heißt, von jeder Relation nur den höchstgradigen Anteil zu behalten — also $Q(v)$ wegwerfen und $v\otimes v = 0$ zurückbekommen.
# * **$\mathrm{gr}$ ist nichts anderes als: die Deformation wieder ausschalten.** Genau das ist der Rückweg auf der waagerechten Achse, und derselbe Satz nochmal auf der unteren Zeile heißt PBW.
#
# 4. Der Härtetest gegen die Teilmengen-Lesart
#
# * Zähl einfach die Dimensionen. Für $\dim V = 2$:
#   - $\Lambda(\mathbb{R}^2)$: Basis $\{1,\ e_1,\ e_2,\ e_1\wedge e_2\}$, Dimension 4.
#   - $\mathrm{Cl}(\mathbb{R}^2, Q)$: Basis $\{1,\ e_1,\ e_2,\ e_1e_2\}$, Dimension 4.
# * Identisch groß. Eine Teilmengen-Beziehung ist damit ausgeschlossen — es ist derselbe Vektorraum mit einer *anderen Multiplikationstabelle*: $e_1 \wedge e_1 = 0$ hier, $e_1 e_1 = 1$ dort. Genau das ist die Aussage des Chevalley-Isomorphismus, den du schon notiert hast, und dasselbe gilt via PBW für $\mathrm{Sym}$ und $W$.
#
# > Merksatz für deine Landkarte: **Deformation ändert das Produkt, nicht den Raum.** Der Quotient sucht den Raum aus, die Bilinearform stellt das Produkt ein.

# %% [markdown]
# <font color="blue">**Thema: Bilinearformen und ihre Geometrien – von der Tensoralgebra zur Quantisierung**
#
# * Algebraische Geometrie und Differentialgeometrie der modernen Physik
#   * Aber: beides trifft nicht, was du studierst. Und inhaltlich deckt der Titel nur etwa zwei Drittel deiner Notizen ab:
#   * Deine tiefste Sektion (diskreter Phasenraum, Pauli-Gruppe über $\mathbb{Z}_d$, Gottesman-Knill, Magic States) ist *gar keine* Differentialgeometrie – dort gibt es keine Mannigfaltigkeiten, keine Glattheit, keine Ableitungen, sondern Darstellungstheorie und symplektische lineare Algebra über endlichen Ringen.
#   * Auch die zyklische Kohomologie sprengt den Rahmen bewusst (sie existiert genau dort, wo klassische Differentialgeometrie versagt).
# * Technisch: Deformationen der Tensoralgebra = **Deformationsquantisierung** bzw. PBW-Deformationen quadratischer Algebren
# * Alles beginnt mit der freien, regellosen **Tensoralgebra** $T(V)$. Aus ihr wird alles andere gebaut wird.
# * **Struktur durch Quotienten nach Idealen: Das Prinzip des Quotienten (Regeln aufzwingen):** Die gemeinsame Klammer ist die Methode, wie aus der Tensoralgebra spezifische Räume für die Physik erschaffen werden. Indem man bestimmte Elemente über ein Ideal "zu Null" erklärt, zwingt man dem Raum eine Geometrie auf:
#   * Zwingt man Quadrate auf Null ($v \otimes v = 0$), entsteht die **Äußere Algebra** und damit die Basis für **Differentialformen** und **Kohomologie**.
#   * Symmetrische Algebra: ..
#   * Nutzt man eine symmetrische Form (Metrik), entsteht die **Clifford-Algebra**, die den Raum für Fermionen und Spinoren liefert (CAR)
#   * Nutzt man eine antisymmetrische (symplektische) Form, entsteht die **(Heisenberg-)Weyl-Algebra**, die den Phasenraum für Bosonen und die Quantenmechanik beschreibt (CCR)
#
# * **Die großen Dualitäten in Deinen Themen**: Ein weiteres starkes Motiv, das all Deine Themen verbindet, ist die ständige Dualität zwischen zwei geometrischen Welten, die Du in Deinen Texten auch direkt ansprichst:
#
#   | Eigenschaft | Der "symmetrische" Zweig | Der "antisymmetrische" Zweig |
#   | :--- | :--- | :--- |
#   | Fundamentale Form | Symmetrisch (Metrik $g$ ) | Antisymmetrisch (Symplektische Form $\omega$ ) |
#   | Algebra | Clifford-Algebra | Heisenberg-Weyl-Algebra |
#   | Physik | Raumzeit, Spin, Fermionen | Phasenraum, Ort/Impuls, Bosonen |
#   | Quanten-Relation | Antikommutatoren (CAR) | Kommutatoren (CCR) |

# %% [markdown]
# <font color="blue"> **Die Tensoralgebra und ihre kanonischen Quotienten als gemeinsamer Baukasten von Differentialgeometrie und Quantisierung**. (Alternative)
# * Anstatt zB äußere Algebra als dritten, parallelen Quotienten neben Clifford und Weyl, eine zweistufige Sicht, die in der Tabelle („freies Grundobjekt") schon angelegt ist:
#   - Die äußere Algebra $\Lambda(V)$ ist der Spezialfall der Clifford-Algebra mit $Q = 0$ – ihr „klassischer Limes".
#   - Die symmetrische Algebra $\mathrm{Sym}(V)$ (Polynome, klassischer Phasenraum) ist der Spezialfall der Weyl-Algebra mit $\omega = 0$.
# * Damit ist die Klammer nicht „drei Quotienten", sondern **ein Schema mit zwei Achsen**:
#   * Parität der Form (symmetrisch/antisymmetrisch) × Deformationsparameter an/aus (klassisch/quantisiert)
#   * Quantisierung heißt dann wörtlich: schalte die Bilinearform ein.
# * Die Geometrie-Sektionen (Tensoranalysis, Metrik, Krümmung) sind dann die Globalisierung dieser Algebra auf Mannigfaltigkeiten, und die Kohomologie ist die dritte Ebene obendrauf: die globale Topologie, die aus $d^2 = 0$ auf der äußeren Algebra entsteht.
#
# <font color="blue">**Vorschlag als eigentliche Klammer: vier Schalter, ein Bauplan**
#
# *Deine gesamten Notizen lassen sich als eine Pipeline mit vier Entscheidungen rekonstruieren. Jede Sektion deines Notebooks ist eine bestimmte Schalterstellung:*
#
# 1. **Schalter – Welche Bilinearform trägt der Vektorraum $V$?**
#   * Das ist die fundamentale Weiche, und du hast die zugehörige Tabelle in deiner Differential-Forms-Sektion selbst schon stehen (Riemannsch / Symplektisch / Topologisch).
#   * Im Geiste von Felix Kleins Erlanger Programm gilt: Eine Geometrie *ist* die Invariantentheorie einer Form und ihrer Gruppe.
#   | Form auf $V$ | Geometrie | Symmetriegruppe | Physik |
#   |---|---|---|---|
#   | keine | Differentialtopologie, Cartan-Kalkül ($d$, Stokes) | $GL(V)$ / Diffeomorphismen | Erhaltungssätze, Flüsse |
#   | symmetrisch $g$ | Riemannsche Geometrie | $O(V)$, Überlagerung $\mathrm{Spin}$ | Raumzeit, ART, Fermionen |
#   | antisymmetrisch $\omega$ | Symplektische Geometrie | $Sp(V)$, Überlagerung $\mathrm{Mp}$ | Phasenraum, Hamilton, Bosonen |
#
# 2. **Schalter – Deformiert oder undeformiert?**
#   * Das ist die Quantisierung als algebraischer Akt, und deine Exterior-Algebra-Sektion enthält bereits die korrekte, überkreuzte Vierertabelle:
#     * $\Lambda(V)$ ist die Clifford-Algebra mit $Q=0$, $\mathrm{Sym}(V)$ ist die Weyl-Algebra mit $\omega=0$;
#     * die Rückrichtung liefern Chevalley ($\mathrm{gr}\,\mathrm{Cl}\cong\Lambda$) und
#     * Poincaré–Birkhoff–Witt ($\mathrm{gr}\,W\cong\mathrm{Sym}$).
#   * Das ist ein präziserer Punkt als Geminis „drei parallele Quotienten": Es gibt **zwei Familien mit je zwei Stockwerken**, klassisch unten, quantisiert oben, und der Fahrstuhl heißt „Bilinearform einschalten".
#
# 3. **Schalter – Punktweise oder als Feld?**
#   * Alles bisher war lineare Algebra an einem einzigen Punkt. Deine Tensoranalysis-Sektion (Christoffel, kovariante Ableitung, Levi-Civita, Paralleltransport, Riemann/Ricci, Bianchi, Einstein-Gleichungen) ist die Globalisierung des symmetrischen Astes auf Mannigfaltigkeiten: Aus $g$ auf $V$ wird ein Metrikfeld $g_{\mu\nu}(x)$, und die neue Frage lautet, wie man Tangentialräume verschiedener Punkte vergleicht – Antwort: Zusammenhang, und Krümmung als dessen Nichtkommutativität.
#   * Das exakte symplektische Gegenstück steht in deiner Differential-Forms-Sektion: Aus $\omega$ auf $V$ wird eine geschlossene 2-Form auf einer Mannigfaltigkeit, und Darboux sagt dir, dass es dort – anders als bei Riemann – *keine* lokale Krümmung gibt.
#   * Das ist übrigens eine schöne Asymmetrie, die deine Notizen implizit enthalten, aber nirgends aussprechen: **Der symmetrische Ast hat lokale Invarianten (Krümmung), der symplektische hat keine (Darboux) – seine ganze Information ist global.** Deshalb braucht der Riemann-Strang den Tensorkalkül und der Symplektik-Strang läuft direkt in Topologie und Quantisierung.
#
# 4. **Schalter – Lokal oder global?**
#   * Das ist deine Kohomologie-Sektion: $d^2=0$ auf der äußeren Algebra erzeugt den Kokettenkomplex, geschlossen-modulo-exakt misst die Löcher (dein $2\pi$-Beispiel auf der punktierten Ebene).
#   * Und die zyklische Kohomologie ist derselbe Schalter, umgelegt auf den Fall, dass die zugrundeliegende „Funktionenalgebra" nicht mehr kommutiert – also genau auf deine Weyl-Seite.
#
# 5. **Schalter - Kontinuierlich $\mathbb{R}$ oder diskret $\mathbb{Z}_d$?**
#   * Für den Heisenberg-Weyl-Strang kommt noch ein fünfter Schalter dazu, **kontinuierlich $\mathbb{R}$ oder diskret $\mathbb{Z}_d$**, und deine HW-Sektion dokumentiert beide Stellungen samt Übergang ($ZX=\omega XZ \to [\hat Q,\hat P]=i\hbar$ für $d\to\infty$).
#
# Damit sitzt jede deiner sechs Sektionen eindeutig auf der Karte:
# * *Tensoralgebra/-analysis* = Rohmaterial plus symmetrischer Ast als Feld;
# * *Exterior Algebra* = formfreier Ast punktweise plus die Quotientenmaschine selbst;
# * *Differential Forms* = formfreier Ast als Feld plus symplektischer Ast;
# * *Geometric Algebra* = symmetrischer Ast quantisiert (punktweise);
# * *Heisenberg-Weyl* = symplektischer Ast quantisiert (kontinuierlich und diskret);
# * *Kohomologie* = die globale Ebene über beiden.

# %% [markdown]
# **Ausreisser: Welche Themen weichen vom "Mainstream" ab?**
#   * *Tensoranalysis*, *Differentialformen* und *Äußere Algebra* sind Standard in der klassischen Differentialgeometrie und der Allgemeinen Relativitätstheorie (ART) sind.
#   ' Aber es gibt konzeptionelle Ausreißer, die eher Nischen oder radikale Neuformulierungen darstellen, und interessanterweise zum Teil die *tiefsten* Sektionen:
#   * **Geometric (Clifford) Algebra als radikaler Ansatz:**
#     * Standardmäßig wird die ART in der Sprache der klassischen Tensoranalysis gelehrt. Die Geometrische Algebra (z. B. als *Spacetime Algebra*) weicht vom Mainstream ab, weil sie versucht, abstrakte Tensoren, Matrizen und sogar den Hodge-Stern-Operator durch das einzige, mächtige **geometrische Produkt** ($vw = a \cdot b + a \wedge b$) zu ersetzen. Sie verschweißt Längenmessung und orientierte Flächen zu einer Einheit. Das ist hochelegant und mächtig, aber im klassischen Physik-Curriculum immer noch eine Randerscheinung gegenüber dem Tensorkalkül.
#     * Geometrische Algebra – ja, das Hestenes-Programm (alles durch das geometrische Produkt ersetzen, Spacetime Algebra) ist eine Randerscheinung im Curriculum.
#     * Wichtig ist aber die Unterscheidung: Clifford-Algebren selbst sind absoluter Mainstream (Dirac-Gleichung, Spinoren, Atiyah-Singer). Nische ist nur die GA-*Bewegung* als Ersatz für den Tensorkalkül.
#     * GA ersetze „abstrakte Tensoren", ist leicht übertrieben – sie ersetzt elegant die antisymmetrische Welt und die orthogonalen Transformationen, aber allgemeine $(p,q)$-Tensoren brauchen weiterhin Tensorprodukte.
#     * Clifford-Algebren sind Mainstream; Nische ist das Hestenes-Programm (STA, Gauge Theory Gravity nach Lasenby/Doran), den Tensorkalkül komplett zu ersetzen. Deine Abgrenzungsnotiz („Stabilisator-Formalismus ist symplektisch, dort keine GA-Sprache verwenden") ist genau richtig und bewahrt dich vor dem häufigsten Fehler der GA-Community, alles in GA pressen zu wollen.
#   * **Heisenberg-Weyl im Quantum Computing (Diskrete Welt):**
#     * Die Heisenberg-Weyl-Algebra ist absoluter Mainstream, wenn es um kontinuierliche Variablen in der Quantenmechanik geht ($[\hat{x}, \hat{p}] = i\hbar$). Deine Notizen tauchen aber sehr tief in die **diskrete HW-Welt** ab: Qubits, Qudits, Clock/Shift-Operatoren, Magic States (T-Gates) und Wigner-Negativität. Das weicht inhaltlich stark von der klassischen Differentialgeometrie ab und springt direkt in die hochspezialisierte, moderne **Quanteninformatik**. Hier arbeitet man plötzlich über endlichen Körpern (Modulo-Rechnung) statt auf glatten Mannigfaltigkeiten.
#     * **Diskrete Phasenraum (HW-Welt) im Quantum Computing** – zutreffend. Clock/Shift über $\mathbb{Z}_d$, Gottesman-Knill, Wigner-Negativität und Magic States sind moderne Quanteninformatik (die zentralen Resultate dazu stammen aus den 2010ern), nicht klassische Differentialgeometrie. Dein Notebook geht hier deutlich tiefer als der Standard. Pauli-Gruppe als zentrale Erweiterung mit symplektischer Paarung über $\mathbb{Z}_d$, $\mathcal{C}_n/\mathcal{P}_n \cong Sp(2n,\mathbb{Z}_d)$, Clifford-Hierarchie, Gottesman-Knill, Gross-Wigner-Funktion, Wigner-Negativität als Ressource. Die zentralen Resultate hier (Veitch–Ferrie–Gross–Emerson, Mari–Eisert, Howard et al.) sind Forschungsliteratur der 2010er. Dein „Gradfilter" (Grad ≤1 / 2 / ≥3 des Generators als der eine Knopf, diskret wie kontinuierlich) ist eine wirklich gute Synthese, die man so kompakt in kaum einem Lehrbuch findet.
#     * **Zyklische Kohomologie / Nichtkommutative Geometrie.** – der dritte Ausreißer. De-Rham-Kohomologie ist Standardstoff; die zyklische Kohomologie nach Connes ist dagegen ein hochspezialisiertes Forschungsgebiet, das in kaum einem Physik-Curriculum vorkommt. Ausgerechnet dieser Abschnitt deines Notebooks ist also mit der exotischste – und thematisch der Brückenschlag, der deine beiden „Welten" verbindet: Sie ist genau das Werkzeug, um auf nichtkommutativen Algebren wie der Heisenberg-Algebra „Differentialgeometrie zu treiben".  Der am weitesten entfernte Punkt deiner Karte – Connes' Programm ist ein eigenes Forschungsuniversum. In deinen Notizen ist es (noch) **der dünnste Abschnitt, aber strukturell der wichtigste Brückenkopf: Es ist das einzige Werkzeug in deiner Sammlung, das verspricht, Differentialgeometrie *auf* der Weyl-Seite zu treiben, also deine beiden Äste wieder zu vereinen.**
#   * Aber: **Mainstream vs. exotisch – als Gradient, nicht als Binärentscheidung**
#     * **Kern-Kanon** (jedes Physik-Curriculum, jedes Differentialgeometrie-Lehrbuch): die komplette Tensoranalysis-Sektion, Differentialformen mit Stokes und Hodge-Stern, die äußere Algebra, de Rham, die symplektischen Grundlagen (Darboux, Liouville, $Sp$/$\mathfrak{sp}$), der harmonische Oszillator mit CCR. Hier bist du auf der breitesten Straße, die es gibt.
#     * **Fortgeschritten, aber fest etabliert**: Clifford-Algebren und Spinoren (in der QFT Standard, in Mathe-Methoden-Kursen oft übersprungen), die metaplektische Gruppe, und vor allem deine Quotienten-/Ideal-Systematik mit PBW und Chevalley. Diese Vierertabelle mit „assoziiertem graduierten Objekt" ist Graduierten-Algebra-Niveau – vollkommen etabliert, aber kaum ein Physiker kennt sie in dieser Sauberkeit. Auch die Herleitung der Robertson-Schrödinger-Unschärfe aus $|\omega(X,Y)|^2 \le g(X,X)g(Y,Y)$ ist ein valider, aber unüblicher didaktischer Weg (die meisten Lehrbücher gehen über Cauchy-Schwarz im Hilbertraum, nicht über die Phasenraumgeometrie).
#
# > Die interessanteste Beobachtung an deiner Sammlung ist für mich, dass du unbewusst **beide „Klassisch-zu-Quanten-Übergänge" parallel dokumentiert hast: $\Lambda(V) \to \mathrm{Cl}(V)$ und $\mathrm{Sym}(V) \to \mathcal{W}(V)$ – und mit der zyklischen Kohomologie sogar schon das Werkzeug, das beide Seiten wieder zusammenführt.**
#
# **Eine Verbindung, die in deinen Notizen angelegt ist, aber noch nicht ausgesprochen**
# * Dein GA-Abschnitt erwähnt Free Fermions / Matchgates als „echten Heimathafen" der GA im Quantum Computing. Denk das eine Stufe weiter, dann schließt sich deine Karte perfekt: **Der Gradfilter existiert auf beiden Ästen.**
#   * Auf der symplektischen Seite: quadratische Generatoren → Gaussian/Clifford → Gottesman-Knill-simulierbar; Grad ≥3 → Magic.
#   * Auf der orthogonalen Seite: quadratische Fermion-Hamiltonians (Bivektoren!) → Matchgates/freie Fermionen → Valiant-simulierbar; Wechselwirkungen (Grad ≥4 in den $a, a^\dagger$) → klassisch hart.
#   * Beide Simulierbarkeitstheoreme sind dasselbe Theorem, einmal für $Sp(2n)$/metaplektisch, einmal für $SO(2n)$/Spin.
#   * Das wäre die Zeile, die deine Tabelle vervollständigt – und der eigentliche Grund, warum deine „intrinsisch" gewählten Themen so stark zusammenhängen: Du hast beide Äste desselben Baums parallel hochgeklettert.
# * Als Fazit für deine Landkarte: Du studierst nicht sechs Themen, sondern **einen Bauplan mit vier Schaltern** (Form? Deformiert? Feld? Global?), und deine Sammlung deckt fast alle Schalterstellungen ab.
#   * Mainstream bist du überall dort, wo die Schalter auf „symmetrisch + Feld" stehen (ART-Strang) oder auf „formfrei + global" (de Rham).
#   * Exotisch wird es an den drei Rändern: symplektisch + diskret (Quanteninformation), symmetrisch + quantisiert als Gesamtprogramm (GA/GTG), und global + nichtkommutativ (zyklische Kohomologie).

# %% [markdown]
# ###### <font color="blue">*Tensor Calculus*

# %% [markdown]
# <font color="blue">Tensor Algebra
#
# **Multilineare Algebra vs Tensor Algebra**
# * Die multilineare Algebra entspricht der Untersuchung von Polynomen und Gleichungen. Multilinear Algebra ist das Studium der mathematischen Beziehungen und Abbildungen (die "Theorie").
# * Die Tensoralgebra entspricht dem Konstruieren eines Polynomrings, also der Rechenstruktur, die es erlaubt, diese Objekte miteinander zu multiplizieren und zu addieren. Tensor Algebra ist die konkrete Struktur und Rechenregel (das "Werkzeug"), mit der wir diese Objekte kombinieren und bearbeiten können.
#
# **Tensoranalysis (Tensorkalkül)**: Während die multilineare Algebra Tensoren in flachen Vektorräumen betrachtet, bringt die Tensoranalysis **Analysis und Geometrie** ins Spiel: Sie untersucht Tensorfelder auf gekrümmten Räumen. Das ist die mathematische Basis der Allgemeinen Relativitätstheorie und der Kontinuumsmechanik.
#
#
# **Transformationsverhalten (Kontra- und Kovarianz)**
#   * In der Tensoranalysis definiert man Tensoren meist darüber, wie sich ihre Komponenten ändern, wenn du das Koordinatensystem von $x$ auf ein neues System $x'$ wechselst.
#
# * **Kontravarianter Vektor (Index oben):** Vektoren im Tangentialraum (wie Geschwindigkeiten). Sie transformieren sich mit der Jacobi-Matrix der Koordinatentransformation:
#
# $$V'^\mu = \frac{\partial x'^\mu}{\partial x^\nu} V^\nu$$
#
#
# * **Kovarianter Vektor / 1-Form (Index unten):** Elemente des Dualraums (wie der Gradient einer skalaren Funktion). Sie transformieren sich mit der inversen Jacobi-Matrix:
#
# $$W'_\mu = \frac{\partial x^\nu}{\partial x'^\mu} W_\nu$$
#
#
# * **Allgemeiner $(p, q)$-Tensor:** Transformiert sich als Produkt aus kontravarianten und kovarianten Faktoren. Ein gemischter Tensor vom Typ $(1,1)$ transformiert sich beispielsweise so:
#
# $$T'^\mu_\nu = \frac{\partial x'^\mu}{\partial x^\alpha} \frac{\partial x^\beta}{\partial x'^\nu} T^\alpha_\beta$$
#
#
# **Vektoren als Derivationen** (kontravariant)
#   * als Richtungsableitungen einer Funktion, zB: $\vec{e_x} = \frac{\delta}{ \delta_x}$
#   * Vector: $\vec{v} = v^i \vec{e}_i = \widetilde{v}^i \vec{\widetilde{e}}_i$
#   * **Basis Vectors / Covariant (1,0-Tensor)**: $\vec{\widetilde{e}}_j = F_j^i \vec{e}_i \qquad \vec{e}_j = B_j^i \vec{\widetilde{e}}_i$
#   * **Vector components / Contravariant (0,1-Tensor)**: $\widetilde{v}^i = B_j^i v^j \qquad v^i = F_j^i \widetilde{v}^j$
#   * * Erinnerung, das sind alle die gleiche Notationen für Basis vectors:
#
# $$\overrightarrow{e_k} \equiv \frac{\partial}{\partial x^k} \equiv \partial_k$$
#
# **Kovektoren als Differentialformen** (kovariant)
#   * als "Schichten", die von Vektoren durchstoßen werden
#   * Kovector: $\alpha = \alpha_i \epsilon^i = \widetilde{\alpha}_i \widetilde{\epsilon}^i$
#   * **Basis Covectors / Contravariant (0,1-Tensor)**: $\widetilde{\epsilon}^i = B_j^i \epsilon^j \qquad \epsilon^i = F_j^i \widetilde{\epsilon}^j$
#   * **Covector Components / Covariant (1,0-Tensor)**: $\widetilde{\alpha}_j = F_j^i \alpha_i \qquad \alpha_j = B_j^i \widetilde{\alpha}_i$
#   * Note: **Differential Forms are totally antisymmetric rank (0,k) tensors!** [video](https://www.youtube.com/watch?v=dNT8OLNMsQ0&list=PLBn8lN0DcvpljsQ8SbFGJxyd_0IlRwiMf&index=5$0)
#   * Algebraic Topology meets Differential Geometry
#   * Beispiel: Erste Ableitung bilden von $z = f(x,y)$: wir benötigen $Δx$ und $Δy$ für $Δf$
#     * $\Delta f=\frac{\partial f}{\partial x} \Delta x+\frac{\partial f}{\partial y} \Delta y$
#     * $d f=\frac{\partial f}{\partial x} d x+\frac{\partial f}{\partial y} d y$ (we can replace the deltas $Δ$ by $d$)
#     * $d f=\frac{\partial f}{\partial x_1} d x_1+\frac{\partial f}{\partial x_2} d x_2+\cdots+\frac{\partial f}{\partial x_n} d x_n$ (can generalize to many variables)
#   * Path integral $\gamma$: has Integrability: integral only depends on the boundary (Poincare 1887), e..g between points a and b: $\int_\gamma A_1 d x_1+A_2 d x_2+\cdots+A_n d x_n=\int_\gamma d f=f(b)-f(a)$
#     * **Integrability Lemma from Poincare**: differential form omega $ω$ (as some combinations of $dx_i$ is integrable if some combinations of derivates equal 0: $d ω = 0$
#   * Christoffel symbol are Differential 2-forms (Curvature 2 forms), easier written than Christoffel
#
# $$\begin{array}{rlrl}\Gamma_{j k}^i & =\frac{1}{2} g^{i l}\left(\partial_k g_{l j}+\partial_j g_{l k}-\partial_l g_{j k}\right) & d \theta^i+\omega_j^i \wedge \theta^j & =0 \\ R_{j k l}^i & =\partial_k \Gamma_{l j}^i-\partial_l \Gamma_{k j}^i+\Gamma_{k m}^i \Gamma_{l j}^m-\Gamma_{l m}^i \Gamma_{k j}^m & d \omega_j^i+\omega_k^i \wedge \omega_j^k & =\Omega_j^i\end{array}$$
#
#   * Differential 2-forms (Curvature 2 forms) also appeard in Gauge theory:
#     * Differential geometry: $\quad d \omega_j^i+\omega_k^i \wedge \omega_j^k=\Omega_j^i$
#     * Gauge theory: $\quad d \mathbf{A}+\mathbf{A} \wedge \mathbf{A}=\mathbf{F}$
#   * Examples of differential forms:
#     * Stoke's theorem: $\int_{\partial D} \overrightarrow{\mathbf{F}} \cdot d \overrightarrow{\mathbf{r}}=\int_D \nabla \times \overrightarrow{\mathbf{F}} \cdot d \overrightarrow{\mathbf{S}}$ - If curl is 0, there is Scalar potential: $\nabla \times \overrightarrow{\mathbf{E}}=\overrightarrow{\mathbf{0}} \Longrightarrow \overrightarrow{\mathbf{E}}=-\nabla V$
#     * Divergence theorem: $\int_{\partial D} \overrightarrow{\mathbf{F}} \cdot d \overrightarrow{\mathbf{S}}=\int_D \nabla \cdot \overrightarrow{\mathbf{F}} d V$ - If divergence is 0, there is Vector Potential $\nabla \cdot \overrightarrow{\mathbf{B}}=0 \Longrightarrow \overrightarrow{\mathbf{B}}=\nabla \times \overrightarrow{\mathbf{A}}$
#     * Generalized Stoke's theorem: $\int_{\partial D} \omega=\int_D d \omega$ - Poincare lemma $d F=0 \Longrightarrow F=d A$ (generalization of Scalar potential and Vector Potential)
# * **Vektoren (Derivationen) vs Kovektoren (Differentialformen):**
#   * **Vektoren (Derivationen):** Leben im Tangentialraum $T_pM$. Sie sind Richtungsableitungen. Basis: $\frac{\partial}{\partial x^i}$.
#   * **Kovektoren (Differentialformen):** Leben im dualen Kotangentialraum $T^*_pM$. Sie messen Vektoren. Basis: $dx^i$.
#   * Die Dualität ist fundamental: $dx^i\left(\frac{\partial}{\partial x^j}\right) = \delta^i_j$ (Kronecker-Delta).
#
#
# **Felder (Vektorfeld, Kovektorfeld/Differentialform)**
#
# * **Vector fields** mit Basiswechsel (Funktor) und Jacobimatrix
#   * Vector: $\vec{e}_1 \longleftrightarrow \frac{\partial}{\partial x} \qquad \vec{e}_2 \longleftrightarrow \frac{\partial}{\partial y}$ (derivatives)
#   * Vector Fields (Kettenregel für Tangentialvektoren): $\frac{d}{d\lambda} = \frac{dc^i}{d\lambda} \frac{\partial}{\partial c^i} = \frac{dp^i}{d\lambda} \frac{\partial}{\partial p^i}$
#   * Basis Vectors / Covariant: $\frac{\partial}{\partial p^j} = \frac{\partial c^i}{\partial p^j} \frac{\partial}{\partial c^i} \qquad \frac{\partial}{\partial c^j} = \frac{\partial p^i}{\partial c^j} \frac{\partial}{\partial p^i}$
#   * Vector Components / Contravariant: $\frac{dp^i}{d\lambda} = \frac{\partial p^i}{\partial c^j} \frac{dc^j}{d\lambda} \qquad \frac{dc^i}{d\lambda} = \frac{\partial c^i}{\partial p^j} \frac{dp^j}{d\lambda}$
# * **Covector fields** mit Basiswechsel (Funktor) und Jacobimatrix
#   * Covector: $\epsilon^1 \longleftrightarrow dx \qquad \epsilon^2 \longleftrightarrow dy$ (differentials)
#   * Covector Fields (Totales Differential einer Funktion): $df = \frac{\partial f}{\partial c^i} dc^i = \frac{\partial f}{\partial p^i} dp^i$
#   * Basis Covectors / Contravariant: $dp^i = \frac{\partial p^i}{\partial c^j} dc^j \qquad dc^i = \frac{\partial c^i}{\partial p^j} dp^j$
#
#
# **Räume**
#
# * **Tangentialraum $T_pM$:** ein Punkt $p$ auf Mannigfaltigkeit und untersuchen die Vektorräume, die an diesem Punkt "kleben".
#   * Vektoren (Derivationen) und Kovektoren (1-Formen) koordinatenfreie, abstrakte Objekte
# * **Kotangentialraum**
#
# **Metrik Tensor (Bilinearform / First Fundamental Form):**
#   * (0,2)-Tensor. Instrument zur Messung von Abständen und Winkeln, Indezes ziehen. Index Raising and Lowering: The most powerful feature of the metric tensor is its ability to convert covariant indices into contravariant ones, and vice versa (musikalische Isomorphismus)
#   * Metrischer Tensor: symmetrisches, nicht-ausgeartetes Tensorfeld ein. Eine Bilinearform, die zwei Vektoren eine Zahl zuordnet: $ds^2 = g = g_{ij} \, dx^i \otimes dx^j$
#   * $g_{kl} = B^i_k B^j_l \widetilde{g}_{ij}$
#
# $$\widetilde{g}_{ij} = F^k_i F^l_j g_{kl}$$
#
# * Metrische Tensor ($g_{\mu\nu}$)
#   * Der metrische Tensor ist der absolut wichtigste $(0,2)$-Tensor einer Riemannschen Mannigfaltigkeit. Er verleiht dem Raum seine Geometrie, da er Abstände und Winkel definiert.
#   * **Linienelement:** Das Quadrat des infinitesimalen Abstands $ds$ zwischen zwei unendlich nah benachbarten Punkten: $ds^2 = g_{\mu\nu} dx^\mu dx^\nu$
#   * **Indizes heben und senken:** Die Metrik $g_{\mu\nu}$ und ihre Inverse $g^{\mu\nu}$ (für die $g_{\mu\alpha} g^{\alpha\nu} = \delta_\mu^\nu$ gilt) werden als Werkzeuge genutzt, um zwischen ko- und kontravarianten Komponenten hin- und herzuwechseln: $V_\mu = g_{\mu\nu} V^\nu \quad \text{und} \quad W^\mu = g^{\mu\nu} W_\nu$
# * **Metric Tensor:** covariant $g_{i,j}$ from $V$ with $\vec{v}$ to $V^*$, lives in $V^* \otimes V^*$.   * *Convert from vector to covector with metric tensor:*
#   * $\vec{v} = v^j \vec{e}_j = \widetilde{v}^j \widetilde{\vec{e}}_j$ (vector)
#   * $\vec{v} \cdot \_ = v_i \epsilon^i = \widetilde{v}_i \widetilde{\epsilon}^i$ (covector)
#   * $v_i = g_{ij} v^j$ bzw.
#
# $$\widetilde{v}_i = \widetilde{g}_{ij} \widetilde{v}^j$$
#
# * Metric Tensor for Curved Surfaces:
#
# $$\begin{bmatrix}
# \frac{d \vec{R}}{d u} \cdot \frac{d \vec{R}}{d u} & \frac{d \vec{R}}{d u} \cdot \frac{d \vec{R}}{d v} \\
# \frac{d \vec{R}}{d v} \cdot \frac{d \vec{R}}{d u} & \frac{d \vec{R}}{d v} \cdot \frac{d \vec{R}}{d v}
# \end{bmatrix}$$
#
# * bzw. als Vector:
#
# $$\begin{bmatrix}
# \vec{e}_u \cdot \vec{e}_u & \vec{e}_u \cdot \vec{e}_v \\
# \vec{e}_v \cdot \vec{e}_u & \vec{e}_v \cdot \vec{e}_v
# \end{bmatrix}$$
#
#
# * Sandwich Metric tensor between covector and vector:
#
# $$g(\vec{v}, \vec{w})=v^i w^j g_{i j}$ = $=\left[\begin{array}{ll}v^1 & v^2\end{array}\right]\left[\begin{array}{ll}g_{11} & g_{12} \\ g_{21} & g_{22}\end{array}\right]\left[\begin{array}{l}w^1 \\ w^2\end{array}\right]$$
#
# * Anwendung in u, v:
#
# $$\left\|\frac{d \vec{R}}{d \lambda}\right\|^2=\frac{d \vec{R}}{d \lambda} \cdot \frac{d \vec{R}}{d \lambda}$ $=\left[\begin{array}{ll}\frac{d u}{d \lambda} & \frac{d v}{d \lambda}\end{array}\right]\left[\begin{array}{ll}\frac{d \vec{R}}{d u} \cdot \frac{d \vec{R}}{d u} & \frac{d \vec{R}}{d u} \cdot \frac{d \vec{R}}{d v} \\ \frac{d \vec{R}}{d v} \cdot \frac{d \vec{R}}{d u} & \frac{d \vec{R}}{d v} \cdot \frac{d \vec{R}}{d v}\end{array}\right]\left[\begin{array}{l}\frac{d u}{d \lambda} \\ \frac{d v}{d \lambda}\end{array}\right]$$
#
# * Anwendung in X, Y, Z:
#
# $$\left\|\frac{d \vec{R}}{d \lambda}\right\|^2=\frac{d \vec{R}}{d \lambda} \cdot \frac{d \vec{R}}{d \lambda}$ = $\left[\begin{array}{lll}\frac{d X}{d \lambda} & \frac{d Y}{d \lambda} & \frac{d Z}{d \lambda}\end{array}\right]\left[\begin{array}{lll}\frac{\partial \vec{R}}{\partial X} \cdot \frac{\partial \vec{R}}{\partial X} & \frac{\partial \vec{R}}{\partial X} \cdot \frac{\partial \vec{R}}{\partial Y} & \frac{\partial \vec{R}}{\partial X} \cdot \frac{\partial \vec{R}}{\partial Z} \\ \frac{\partial \vec{R}}{\partial Y} \cdot \frac{\partial \vec{R}}{\partial X} & \frac{\partial \vec{R}}{\partial Y} \cdot \frac{\partial \vec{R}}{\partial Y} & \frac{\partial \vec{R}}{\partial Y} \cdot \frac{\partial \vec{R}}{\partial Z} \\ \frac{\partial \vec{R}}{\partial Z} \cdot \frac{\partial \vec{R}}{\partial X} & \frac{\partial \vec{R}}{\partial Z} \cdot \frac{\partial \vec{R}}{\partial Y} & \frac{\partial \vec{R}}{\partial Z} \cdot \frac{\partial \vec{R}}{\partial Z}\end{array}\right]\left[\begin{array}{l}\frac{d X}{d \lambda} \\ \frac{d Y}{d \lambda} \\ \frac{d Z}{d \lambda}\end{array}\right]$$
#
# **Inverse Metric Tensor:** contravariant $\mathfrak{g_{i,j}}$, lives in $V \otimes V$
#   * **Metric tensor and invers metric tensor with $∇ f$ (gradient, vector) and $d f$ (differential, covector):**
#   * Use metric tensor $g = (\nabla f)^i g_{i j}=\frac{\partial f}{\partial c^j}$ to go from vector field **$∇ f$ (gradient)** to covector field **$d f$ (differential, exterior derivative of $f$)**.
#   * Use inverse metric tensor $\mathfrak{g}$ = $(\nabla f)^k= \mathfrak{g}^{j k} \frac{\partial f}{\partial c^j}$ to go from covector field **$d f$ (differential, exterior derivative of $f$)** back to vector field **$∇ f$ (gradient)** .
#   * **Kronecker delta** when both combined: $\mathfrak{g}^{k i} \otimes g_{i j}=\delta_j^k$
#   * **(m,n)- Tensor** Transformation rule. Definition der Indizes: $T^{ijk\dots \quad  → \text{ contravariant indexes}}_{rst\dots \quad  → \text{ covariant indexes}}$
#   * Transformation zu den neuen Indizes:
#
# $$\widetilde{T}^{abc\dots}_{xyz\dots} = (B^a_i B^b_j B^c_k \dots) T^{ijk\dots}_{rst\dots} (F^r_x F^s_y F^t_z \dots)$$
#
# **Transformation zu den alten Indizes:**
#
# $$T^{ijk\dots}_{rst\dots} = (F^i_a F^j_b F^k_c \dots) \widetilde{T}^{abc\dots}_{xyz\dots} (B^x_r B^y_s B^z_t \dots)$$
#
# * **Musikalische Isomorphismen:** Die Metrik erlaubt es uns, Indizes zu heben (Sharp $\sharp$) und zu senken (Flat $\flat$). Sie verwandelt Vektoren in Formen und umgekehrt. $v_i = g_{ij} v^j \quad (\text{Flat-Operator: Vektor } \to \text{ Form})$
#     * **Lowering an index:** $v_i = g_{ij} v^j$ which is the $\flat$ operator (from vector arrow to flat covector stack)
#     * **Raising an index:** $v^i = g^{ij} v_j$ which is the $\sharp$ operator (from covector $\alpha$ to vector $\vec{a}$
#   * (Note: The contravariant metric tensor $g^{ij}$ is the matrix inverse of the covariant tensor $g_{ij}$).
# * (1,1)-Tensor with: $\widetilde{L}^i_j = B^i_k L^k_l F^l_j$ and: $L^i_j = F^i_k \widetilde{L}^k_l B^l_j$

# %% [markdown]
# <font color="blue">Tensor Calculus I
#
# **Holonomy**
#   * Two main ways to detect curvature: 1. **holonomy** or 2. geodesic deviation
#   * Beschreibt die globale Diskrepanz – oft eine Drehung –, die ein Vektor erfährt, nachdem er auf einer gekrümmten Mannigfaltigkeit parallel entlang einer vollständig geschlossenen Schleife transportiert wurde.
#
# $$\text{Hol}(\gamma) = \mathcal{P} \exp \left( \oint_\gamma \Gamma_\mu dx^\mu \right)$$
#
# **Geodesic equation**
#   * Two main ways to detect curvature: 1. holonomy or 2. **geodesic deviation**
#   * Eine Geodäte ist geradestmögliche Bahn in einem gekrümmten Raum (die Verallgemeinerung einer Geraden, zB Flugbahn eines Objekts im freien Fall). Ein Teilchen bewegt sich auf einer Geodäte, wenn sein eigener Geschwindigkeitsvektor entlang seiner Bahn parallel transportiert wird
#   * Geodesics are where the tangential component are zero (because geodesics are curves where the acceleration vector is always normal, light will follow this path). Christoffel Symbols Γ = tangential component.
#   * geradeste Kurve in einem gekrümmten Raum, entlang derer der eigene **Tangentialvektor parallel transportiert** wird, sodass ihre intrinsische Beschleunigung verschwindet.
#   * In der Geodesic equation ist der covariant derivate (connection) = Null!
#   * In curved space, a straight path has **zero tangential acceleration** when we travel along it at constant speed.
#   * **To compute geodesic curves, we need to find curves where the acceleration vector is <u>normal</u> to the surface:**
#
# <font color="blue">$$0 = \Gamma_{i j}^k \frac{d u^i}{d \lambda} \frac{d u^j}{d \lambda} + \frac{d^2 u^k}{d \lambda^2}$$
#
# $$\frac{d^2 x^\mu}{d\tau^2} + \Gamma^\mu_{\alpha\beta} \frac{dx^\alpha}{d\tau} \frac{dx^\beta}{d\tau} = 0$$
#
# **Parallel Transport**
#   * Parallel Transport (global) = zero covariant derivative (infinitesimal)! = Exponential der Lie Algebra
#   * Paralleltransport ist Operation, einen Vektor entlang einer Kurve so zu verschieben, dass er "in sich parallel" bleibt (sich also aus seiner eigenen Perspektive nicht ändert). Ein Vektorfeld $V^\mu$ ist entlang einer Kurve mit dem Parameter $\tau$ parallel verschoben, wenn die absolute Ableitung null ist: $\frac{DV^\mu}{d\tau} = \frac{dx^\nu}{d\tau} \nabla_\nu V^\mu = 0$
#   * ist eine Vorschrift, die bestimmt, wie ein Vektor entlang einer Kurve verschoben wird, sodass er im geometrischen Sinne "konstant" bleibt und die lokale Krümmung der Koordinaten exakt ausgleicht.
#   * Der Unterschied zwischen den Endvektoren der perfekt parallel transportierten Vektoren in Vektorfeldern wird durch den **Torsion Tensor** gemessen. Der Unterschied zwischen den Endvektoren der tatsächlich transportierten Vektoren in Vektorfeldern wird durch die **Lie Braket** gemessen.
#   * Parallel Transport provides a connection between tangent spaces in a curved space. e.g. from $T_pS$ to $T_qS$
#   * Covariant derivative provides connection between these tangent spaces in curved space $\nabla_{\frac{d}{d \lambda}} \vec{v}=\overrightarrow{0}$
#     * Thats why covariant derivate is something called connection, because it connects!
#     * This means: Parallel Transport = zero covariant derivative = special case of connection
#     * And Christoffel symbols $\Gamma$ are connection coefficients! $\nabla_{\overrightarrow{e_i}} \overrightarrow{e_j}=\Gamma_{i j}^k \overrightarrow{e_k}$
#
# $$\nabla_{\dot{\gamma}} V = 0 \iff \frac{dV^i}{d\lambda} + \Gamma^i_{jk} V^j \frac{dx^k}{d\lambda} = 0$$
#
# **Acceleration Vector**
#   * Acceleration Vector = **Christoffel Symbols + Second Fundamental Form**
#   * Extrinsic approach: in geodesic curves, the acceleration vector is normal to the surface
#   * $\frac{\partial \overline{e_j}}{\partial u^i}=\Gamma_{i j}^1 \overrightarrow{e_1}+\Gamma_{i j}^2 \overrightarrow{e_2}+L_{i j} \hat{n}$ bzw.: $\frac{\partial^2 \vec{R}}{\partial u^i \partial u^j}=\Gamma_{i j}^1 \frac{\partial \vec{R}}{\partial u^1}+\Gamma_{i j}^2 \frac{\partial \vec{R}}{\partial u^2}+L_{i j} \hat{n}$
#   * Acceleration Vector = Christoffel Symbols Γ (tangential) + Second Fundamental Form L (normal)
#
# $$ \frac{d^2 \vec{R}}{d \lambda^2} =\left(\frac{d^2 u^k}{d \lambda^2}+\Gamma_{i j}^k \frac{d u^i}{d \lambda} \frac{d u^j}{d \lambda}\right) \frac{\partial \vec{R}}{\partial u^k}\quad + \quad L_{i j} \frac{d u^i}{d \lambda} \frac{d u^j}{d \lambda} \widehat{n}$$
#
# $$\frac{d^2 \vec{R}}{d \lambda^2}= \quad \quad \underbrace{\left(\frac{d^2 \vec{R}}{d \lambda^2}\right)^{\text {tangential }}}_{=0} \quad \quad \quad + \quad \quad \left(\frac{d^2 \vec{R}}{d \lambda^2}\right)^{\text {normal }}$$
#
# **Second fundamental form**
#   * https://de.wikipedia.org/wiki/Zweite_Fundamentalform: Während die erste Fundamentalform die innere Geometrie einer Fläche beschreibt (also Eigenschaften, die sich durch Längenmessungen innerhalb der Fläche ermitteln lassen), hängt die zweite Fundamentalform von der Lage der Fläche im umgebenden Raum ab. Sie wird für Krümmungsberechnungen benötigt und kommt beispielsweise in den Mainardi-Codazzi-Gleichungen vor. Mit ihrer Hilfe und mit Hilfe der ersten Fundamentalform werden die Hauptkrümmungen, die mittlere Krümmung und die Gaußsche Krümmung der Fläche definiert.
#   * $L_{i j} \hat{n}$ (normal vector), tells us how much of the normal vector we take
#
# $$L_{i j}=\frac{\partial^2 \vec{R}}{{\partial} u^i {\partial} u^j} \cdot \frac{\overrightarrow{e_i} \times \overrightarrow{e_j}}{\left\|\overrightarrow{e_i} \times \overrightarrow{e_j}\right\|}$$
#
# **Christoffel symbols**
#   * Christoffel symbols $\Gamma_{i j}^k$ or $\Gamma_{i j}^1$ and $\Gamma_{i j}^2$ = correction term or 'connection coefficients' in covariant derivative!
#   * **Christoffel-Symbole $\Gamma^k_{ij}$:** Das sind die Korrekturterme, die beschreiben, wie sich das Koordinatensystem selbst krümmt und dreht. Im Levi-Civita-Zusammenhang (torsionsfrei & metrikverträglich) werden sie direkt aus den Ableitungen der Metrik berechnet: $\Gamma^k_{ij} = \frac{1}{2} g^{kl} (\partial_i g_{jl} + \partial_j g_{il} - \partial_l g_{ij})$
#   * Christoffel Symbols give tangential components of $\frac{\partial^2 \vec{R}}{\partial u^i \partial u^j}$ (how much of each tangent basis vector in tangent plane we take). How local basis vectors change from point to point on a surface? (to define derivate vector in curved space)
#
# $$\Gamma^k_{ij} = \frac{1}{2} g^{kl} (\partial_i g_{jl} + \partial_j g_{il} - \partial_l g_{ij}) =\frac{\partial^2 \vec{R}}{\partial u^i \partial u^j} \cdot \frac{\partial \vec{R}}{\partial u^l} \mathfrak{g}^{l k}$$
#
# **Connection or Covariant Derivative**
#   * Connection/Covariant Derivative = Navigationssystem (Zusammenhang/Kovariante Ableitung) = Lie Algebra
#   * Wenn man auf einem gekrümmten Raum (oder in Polarkoordinaten) die normale partielle Ableitung ($\partial_\mu$) eines Vektorfeldes bildet, ist das Ergebnis *kein* Tensor mehr. Der Grund: Die Basisvektoren selbst ändern sich von Punkt zu Punkt! Die kovariante Ableitung repariert dieses Problem.
#   * Wie vergleicht man Vektoren in verschiedenen Tangentialräumen? Man braucht eine Vorschrift, wie man ein Koordinatensystem "parallel" von einem Punkt zum anderen schiebt.
#   * **Kovariante Ableitung ($\nabla_\mu$ oder $;_\mu$):** Sie ergänzt die gewöhnliche Ableitung um einen Korrekturterm mit dem Christoffel-Symbol, sodass das Resultat wieder ein echter Tensor ist.
#     * Für einen kontravarianten Vektor: $\nabla_\mu V^\nu = \partial_\mu V^\nu + \Gamma^\nu_{\mu\lambda} V^\lambda$
#     * Für einen kovarianten Vektor: $\nabla_\mu W_\nu = \partial_\mu W_\nu - \Gamma^\lambda_{\mu\nu} W_\lambda$
#   * Kovariante Ableitung bzw Zusammenhang $\nabla$ verallgemeinert die Richtungsableitung. Wenn Sie ein Vektorfeld $Y$ in Richtung von $X$ ableiten, lautet das Ergebnis in lokalen Koordinaten: $\nabla_X Y = \left( X^i \frac{\partial Y^k}{\partial x^i} + \Gamma^k_{ij} X^i Y^j \right) \frac{\partial}{\partial x^k}$
#   * **Covariant derivative (= Connection = Lie Algebra) = infinitesimal!**
#   * Covariant derivative called connection because connects between tangent spaces in a curved space, e.g. from $T_pS$ to $T_qS$
#   * **Die Geodesic equation ist eine spezielle Lösung der covariant derivate (connection), wo covariant derivative = Null ist!**
#   * Covariant derivative is a tool used to measure the rate of change of a tensor field along a specific direction in a curved space or curved spacetime. It is a derivative with normal componentent substracted of a vector field on curved surfaces: $\nabla_{\text{Direction}} \text{Input Field} = \text{Output Field (rate of change)} = \text{Connection}$
#   * Background: In flat Cartesian spaces, calculating derivative of vector or tensor simple: take partial derivative of its components. In curved spaces (or curvilinear like polar or spherical coordinates), coordinate basis vectors change from point to point.
#   * If you take a standard partial derivative, the result incorrectly mixes the change of the tensor's components with the change in the basis vectors themselves, meaning the result is not a true tensor. The covariant derivative fixes this by properly adjusting for the twisting, turning, and stretching of the coordinate system.
#   * The covariant derivative introduces **correction terms using mathematical objects called connection coefficients (most commonly the Christoffel symbols, denoted as ($\Gamma$)**
#   * Standard partial derivative $\frac{{\partial} v^k}{{\partial} u^i}$ of the vector component and correction term $\Gamma$: $\nabla_{\frac{\partial}{\partial u^i}} \vec{v} = \left[\frac{\boldsymbol{\partial} v^k}{\boldsymbol{\partial} u^i}+v^j \boldsymbol{\Gamma}_{i j}^k\right] \overrightarrow{e_k}$
#     * $\text{extrinsic (with dot product):} \quad \Gamma_{i j}^m = \left(\frac{\partial \overrightarrow{e_j}}{\partial u^i} \cdot \overrightarrow{e_l}\right) g^{l m}$
#     * $\text{intrinsic:} \quad \Gamma_{j k}^m=\frac{1}{2} g^{m i}\left(\frac{\partial\left(g_{i j}\right)}{\partial u^k}+\frac{\partial\left(g_{k i}\right)}{\partial u^j}-\frac{\partial\left(g_{j k}\right)}{\partial u^i}\right)$
#   * Example of a covariant derivative: $\nabla_{\frac{d}{d \lambda}} \frac{d}{d \lambda}$
#     * $\lambda$ : Curve = some function of parameter $\lambda$. Tangent Vectors: $\nabla \frac{d}{d \lambda}$. Geodesic: $\nabla_{\frac{d}{d \lambda}} \frac{d}{d \lambda}$
#     * Parallel transport if covariant derivative is 0: $\nabla_{\frac{d}{d \lambda}} \vec{v}=\overrightarrow{0}$ (covariant derivative of the vector field is zero)
#   * Properties of Covariant Derivates - generalizes partial derivatives so that resulting derivative transforms properly as a tensor:
#     * $\nabla_{a \vec{w}+b \vec{t}} \vec{v}=a \nabla_{\vec{w}} \vec{v}+b \nabla_{\vec{t}} \vec{v}$
#     * $\nabla_{\vec{w}}(\vec{v}+\vec{u})=\nabla_{\vec{w}} \vec{v}+\nabla_{\vec{w}} \vec{u}$
#     * $\nabla_{\vec{w}}(a \vec{v})=\left(\nabla_{\vec{w}} a\right) \vec{v}+a\left(\nabla_{\vec{w}} \vec{v}\right)$
#     * $\nabla_{\partial_i}(a)=\frac{\partial a}{\partial u^i}$
#
# **Levi-Civita Connection**
#   * Different connection coefficients will give us different instructions for performing parallel transport!
#   * Insight 1: The coveriant derivate is zero $\nabla_{\vec{v}}(\vec{u})=\overrightarrow{0}$ and $\nabla_{\vec{u}}(\vec{v})=\overrightarrow{0}$, but results can look vastly different.
#   * Insight 2: Christoffel symbols $\Gamma$ are NOT unique, there are many different ways to describe the connection coefficients!
#   * **Levi-Civita Connection = most important covariant derivative!:** = Two properies make Christoffel symbols $\Gamma_{j k}^m=\frac{1}{2} \mathfrak{g}^{i m}\left(\partial_k g_{i j}+\partial_j g_{k i}-\partial_i g_{j k}\right)$ unique:
#     * **Torsion free property**: $\nabla_{\vec{w}} \vec{v}=\nabla_{\vec{v}} \vec{w}$ or written: $\nabla_{\vec{w}} \vec{v}-\nabla_{\vec{v}} \vec{w}=[\vec{v}, \vec{w}]$ with **Lie Bracket** included $[\vec{v}, \vec{w}]=\vec{v} \vec{w}-\vec{w} \vec{v}$ bzw. $\nabla_Z g = 0 \quad \text{und} \quad \nabla_X Y - \nabla_Y X = [X,Y]$
#     * **Metric compatability**: $\nabla_{\vec{w}}(\vec{v} \cdot \vec{u})=\left(\nabla_{\vec{w}} \vec{v}\right) \cdot \vec{u}+\vec{v} \cdot\left(\nabla_{\vec{w}} \vec{u}\right)$ bzw. $\nabla_{\frac{\partial}{\partial u^i}} \vec{v}=\left(\frac{\partial v^k}{\partial u^i}+v^j \Gamma_{i j}^k\right) \overrightarrow{e_k} $
#   * Ein affiner Zusammenhang ermöglicht die richtungsabhängige (kovariante) Ableitung von Tensorfeldern; der Levi-Civita-Zusammenhang ist der eindeutige Zusammenhang, der sowohl torsionsfrei ist als auch die Metrik respektiert (die Längen und Winkel bei Paralleltransport erhält) = Torsion free + Metric compatability
#
# **'Boring' connection**
#   * no curvature (is that true?). Christoffel symbols are zero: $\widetilde{\Gamma_{i j}^k}=0$
#
# $$\widetilde{\nabla}_{\frac{\partial}{\partial u^i}} \vec{v}=\left(\frac{\partial v^k}{\partial u^i}+v^j \widetilde{\Gamma_{i j}^k}\right) \overrightarrow{e_k}$$
#
# > <font color="blue">**A connection is a Lie Algebra** ! Und **Paralleltransport ist das Exponential** $e$ dieses Lie-Algebra-Wertes entlang des Weges ("path-ordered exponential"), was uns ein Element der Lie-Gruppe liefert. Eine connection ($\nabla$, in der Algebra) ist das Infinitesimale, und der Paralleltransport ($P_\gamma$, in Gruppe) ist dessen Exponentiation!

# %% [markdown]
# <font color="blue">Tensor Calculus II
#
# **Lie Bracket (Commutator):**
#   * (hier hat Parallel Transport keine bedeutung!). Coordinate lines are just flow curves along basis vectors
#   * Lie Bracket / Commutator = measures how much vector field flow curves fail to close.
#   * Sie misst die Nicht-Kommutativität zweier Vektorfelder $X$ und $Y$, also gewissermaßen die infinitesimale "Lücke", die entsteht, wenn man die Flüsse der beiden Felder in unterschiedlicher Reihenfolge durchläuft.
#
# $$[\vec{u}, \vec{v}]=\vec{u}(\vec{v})-\vec{v}(\vec{u})$$
#
# $$[X, Y]^i = X^j \partial_j Y^i - Y^j \partial_j X^i$$
#
# **Torsion Tensor**
#   * Torsion Tensor = covariant derivates  + Lie Bracket! (hier hat parallel transport eine zentrale bedeutung!)
#   $T(\vec{u}, \vec{v})=\nabla_{\vec{u}} \vec{v}-[\vec{u}, \vec{v}]-\nabla_{\vec{v}} \vec{u}$ mit $T^k_{ij} = \Gamma^k_{ij} - \Gamma^k_{ji}$ und **wenn** $T(\vec{u}, \vec{v})=\nabla_{\vec{u}} \vec{v}-[\vec{u}, \vec{v}]-\nabla_{\vec{v}} \vec{u} = 0$, **dann**: $\nabla_{\vec{u}} \vec{v}-\nabla_{\vec{v}} \vec{u}=[\vec{u}, \vec{v}]$, **bedeutet**: the difference of the covariant derivates is equal to the Lie Braket (which is difference of ordinary derivative)
#   * Dieser Tensor fängt den asymmetrischen Teil des Zusammenhangs ein und gibt geometrisch an, inwiefern sich infinitesimale Parallelogramme, die durch den Paralleltransport gebildet werden, nicht schließen. Separation between parallel transported vector lines. Lie bracket is included in it. "Torsion-Free" means parallel-transported vectors close properly.
#   * This is a property of connections only! Only depends on the connection coefficients, not the vector field.
#   * Notation: $\nabla_{\vec{u}} \vec{v} \quad \nabla_{\vec{v}} \vec{u}$ wobei: $\vec{u}$ and $\vec{v}$ = Vector fields, und $\nabla$ = Connection $\Gamma^k_{ij}$, concretely the Levi Civita connection $\Gamma_{j k}^m=\frac{1}{2} \mathfrak{g}^{i m}\left(\partial_k g_{i j}+\partial_j g_{k i}-\partial_i g_{j k}\right)$, sowie: $\nabla_{\vec{u}} \vec{v}=\overrightarrow{0}$ parallel transport.
#   * Torsion Tensor: für zwei Vektofelder $X,Y\in \Gamma (TM)$ und Lie-Klammer $[\cdot ,\cdot ]$ mit einer differenzierbaren Mannigfaltigkeit $(M,\nabla )$ und einem affinen Zusammenhang $\nabla$ ist der Torsionstensor $T$ ein Tensorfeld, definiert:
#
# $$T(X,Y)=\nabla _{X}Y-\nabla _{Y}X-[X,Y]$$
#
# **Krümmungstensoren** (allgemein)
#   * In einem flachen euklidischen Raum spielt es keine Rolle, in welcher Reihenfolge man partielle Ableitungen ausführt. In einem gekrümmten Raum kommutieren kovariante Ableitungen hingegen *nicht*. Die Differenz dieser Ableitungen misst exakt die Krümmung des Raumes.
#   * **Riemannscher Krümmungstensor ($R^\rho_{\sigma\mu\nu}$):** Er misst, wie sehr ein Vektor rotiert wird, wenn du ihn entlang einer winzigen geschlossenen Schleife parallel verschiebst: $[\nabla_\mu, \nabla_\nu] V^\rho = \nabla_\mu \nabla_\nu V^\rho - \nabla_\nu \nabla_\mu V^\rho = R^\rho_{\sigma\mu\nu} V^\sigma$
#   * Die Formel zur Berechnung aus den Christoffel-Symbolen lautet: $R^\rho_{\sigma\mu\nu} = \partial_\mu \Gamma^\rho_{\nu\sigma} - \partial_\nu \Gamma^\rho_{\mu\sigma} + \Gamma^\rho_{\mu\lambda} \Gamma^\lambda_{\nu\sigma} - \Gamma^\rho_{\nu\lambda} \Gamma^\lambda_{\mu\sigma}$
#   * **Ricci-Tensor ($R_{\mu\nu}$):** Eine bestimmte Verjüngung (Kontraktion) des Riemann-Tensors. Er beschreibt, wie das Volumen eines Schwarmes von Testteilchen im freien Fall schrumpft oder wächst: $R_{\mu\nu} = R^\rho_{\mu\rho\nu}$
#   * **Ricci-Skalar ($R$):** Die weitere Verjüngung des Ricci-Tensors mit der Metrik ($R = g^{\mu\nu} R_{\mu\nu}$). Es ist eine einzelne Zahl, die an jedem Punkt die gesamte skalare Krümmung angibt.
#   * Die **Einstein'schen Feldgleichungen** kombinieren genau diese drei Bausteine (Metrik, Ricci-Tensor, Ricci-Skalar), um zu beschreiben, wie Masse und Energie die Geometrie des Universums krümmen:
#
# $$R_{\mu\nu} - \frac{1}{2} R g_{\mu\nu} + \Lambda g_{\mu\nu} = \frac{8\pi G}{c^4} T_{\mu\nu}$$
#
# **Riemann Curvature Tensor**
#   * Krümmung ist die Unfähigkeit von Vektoren, beim Paralleltransport entlang einer geschlossenen Schleife wieder identisch bei sich selbst anzukommen (Holonomie), oder das Versagen der Kommutativität von Ableitungen.
#   * Riemann Curvature Tensor: $R$: Ein $(1,3)$-Tensor, der diese Nicht-Kommutativität exakt misst. (1 contravariant,3 covariant)-Tensor quantifiziert intrinsisch die Krümmung des Raumes, indem er die Nicht-Kommutativität der zweiten kovarianten Ableitungen misst.
#   * Riemann curvature tensor **components** (berechnet mit den connection components): $R_{c a b}^d=\partial_a\left(\Gamma_{b c}^d\right)-\partial_b\left(\Gamma_{a c}^d\right)+\Gamma_{b c}^i \Gamma_{a i}^d-\Gamma_{a c}^j \Gamma_{b j}^d$. Riemann curvature tensor is:
#
# $$R(\vec{u}, \vec{v}) \vec{w}=\nabla_{\vec{u}} \nabla_{\vec{v}} \vec{w}-\nabla_{\vec{v}} \nabla_{\vec{u}} \vec{w}-\nabla_{[\vec{u}, \vec{v}]} \vec{w}$$
#
# $$R(X,Y)Z = \nabla_X \nabla_Y Z - \nabla_Y \nabla_X Z - \nabla_{[X,Y]} Z$$
#
# **Ricci Tensor**
#   * Aus dem Riemann-Tensor gewinnt man durch Spurbildung (Kontraktion) den **Ricci-Tensor** $R_{ij}$ (beschreibt Volumenverzerrungen) und den **Ricci-Skalar** $R$, welche das Herzstück der Einsteinschen Feldgleichungen in der Allgemeinen Relativitätstheorie bilden. Both considered a summary of the Riemann curvature tensor
#   * **Ricci-Curvature-Tensor** tracks how volume change along geodesic (that's why the Ricci tensor represents gravity $R_{\mu \nu}$ in the general theory of relativity in Einstein field equations: $R_{\mu \nu}-\frac{1}{2} g_{\mu \nu}+\Lambda g_{\mu \nu}=\frac{8 \pi G}{c^4} T_{\mu \nu}$)
#   * The Ricci curvature is the sum of all scalar curvatures in every basis vector direction $\sum_{i=1}^D K\left(\overrightarrow{e_i}, \vec{v}\right)$. The Ricci curvature (left) can also be computed using the Ricci tensor $R_{i j}$ with: $\text{Ric}(\vec{v}, \vec{v})=R_{i j} v^i v^j$
#   * Two geometrical approaches in understanding Ricci-Curvature-Tensor: Sectional Curvature and Volume Form
#   * For an orthonormal basis $\overrightarrow{e_1}, \overrightarrow{e_2}, \ldots, \overrightarrow{e_n}$ and a direction vector $\vec{v}=\overrightarrow{e_n}$, the Ricci-Curvature-Tensor is:
#
# $$\text{Ric}(\vec{v}, \vec{v})=\sum_{i=1}^D K\left(\overrightarrow{e_i}, \vec{v}\right)=\sum_i \frac{\left[R\left(\overrightarrow{e_i}, \vec{v}\right) \vec{v}\right] \cdot \overrightarrow{e_i}}{\left(\overrightarrow{e_i} \cdot \overrightarrow{e_i}\right)(\vec{v} \cdot \vec{v})-\left(\overrightarrow{e_i} \cdot \vec{v}\right)^2}$$
#
# **Sectional Curvature**
#   * Ricci Curvature-Tensor can only tell us about volume, not shape! because if $K\left(\overrightarrow{e_1}, \vec{v}\right)>0 \quad K\left(\overrightarrow{e_2}, \vec{v}\right) < 0$, then the overall Ricci tensor is the same: $\text{Ric}(\vec{v}, \vec{v})=\sum_{i=1}^D K\left(\overrightarrow{e_i}, \vec{v}\right)=0$, only the shape changed.
#   * for an orthonormal base (with Levi Civita symbol). The Ricci-Curvature-Tensor is zero: $\text{Ric}(\vec{v}, \vec{v})=\sum_{i=1}^D K\left(\overrightarrow{e_i}, \vec{v}\right)=0$ for following **Sectional curvatures** (whose sum is the Ricci curvature): $K\left(\overrightarrow{e_1}, \vec{v}\right)=0 \quad K\left(\overrightarrow{e_2}, \vec{v}\right)=0$. General Sectional curvatures:
#
# $$K(\vec{s}, \vec{v})=\frac{[R(\vec{s}, \vec{v}) \vec{v}] \cdot \vec{s}}{(\vec{s} \cdot \vec{s})(\vec{v} \cdot \vec{v})-(\vec{s} \cdot \vec{v})^2}$$
#
# **Volume Element Derivative**
#   * for any base!
#
# **Volume Form $ω$**
#   * Metric compatability of Levi-Civita connection preserves vector lengths and angles, and therefore preserves volume. This means covariant derivate is zero: $\nabla_{\vec{v}} V=0$ where this formula is: $=\nabla_{\vec{v}}[\omega(\vec{a}, \vec{b}, \vec{c})]$
#   * Volume Form $ω$: Take 2nd derivative of volume form along a geodesic path to get the Ricci tensor
#
# $$\nabla_{\vec{v}} \nabla_{\vec{v}} \omega(\vec{u}, \vec{w}, \vec{t})$$
#
# **Ricci-Scalar**:
#   * compare volume of a ball in curved space to volume of a ball of same radius in flat space (measures deviation). Curved space means we can fit a large area into a smaller boundary.
#   * Der Ricci-Tensor entsteht durch Spur-Bildung (Kontraktion) des Riemann-Tensors und misst die Volumenänderung eines geodätischen Balls; eine weitere Kontraktion liefert den Ricci-Skalar, eine einzige Zahl pro Punkt, die die totale Skalarkrümmung angibt.
#
# $$R_{ij} = R^k_{\ ikj} \quad \text{und} \quad R = g^{ij} R_{ij}$$
#
# **Bianchi-Identität**
#   * differentielle Identitäten, sind die geometrischen Entsprechungen der Erhaltungssätze (Energie und Impuls)
#   * sie diktieren, wie sich Krümmung von Punkt zu Punkt stetig und konsistent verhalten muss.
#
# $$\nabla_l R^i_{\ jkm} + \nabla_k R^i_{\ jml} + \nabla_m R^i_{\ jlk} = 0$$
#
# **Schnittkrümmung (Sectional Curvature)**
#   * liefert eine anschauliche zweidimensionale Krümmungsmaßzahl (vergleichbar mit der Gaußschen Krümmung), die angibt, wie stark eine durch zwei Tangentialvektoren $X$ und $Y$ aufgespannte "Ebene" gekrümmt ist.
#
# $$K(X,Y) = \frac{\langle R(X,Y)Y, X \rangle}{\langle X,X \rangle \langle Y,Y \rangle - \langle X,Y \rangle^2}$$
#
# * Videos: Eigenchris: [Tensor Calculus](https://youtube.com/playlist?list=PLJHszsWbB6hpk5h8lSfBkVrpjsqvUGTCx&si=vJ64vdbqtgjDXHbv) and [Tensors for Beginners](https://youtube.com/playlist?list=PLJHszsWbB6hrkmmq57lX8BV-o-YIOFsiG&si=Ibojdh_9nI3SIYgA)

# %% [markdown]
# **Kleine fachliche Korrekturen (da du um Bewertung gebeten hast)**
#
# Die Notizen sind insgesamt bemerkenswert kohärent und weit überwiegend korrekt. Drei Stellen würde ich reparieren:
#
# 1. In der Tensor-Sektion steht „Christoffel symbols are Differential 2-forms (Curvature 2 forms)". Das stimmt nicht: Die Christoffel-Symbole bilden die Zusammenhangs-**1**-Formen $\omega^i_j = \Gamma^i_{jk}\,dx^k$; erst die Krümmung $\Omega^i_j = d\omega^i_j + \omega^i_k \wedge \omega^k_j$ ist die 2-Form. Deine eigene Cartan-Gleichung direkt daneben zeigt das übrigens korrekt – nur die Überschrift ist falsch. (Zusätzliche Feinheit: $\omega^i_j$ ist nicht einmal tensoriell.)
# 2. Der Merksatz „A connection **is** a Lie Algebra" ist als Slogan gemeint, aber so falsch: Ein Zusammenhang ist eine Lie-Algebra-*wertige* 1-Form, und Paralleltransport ist deren pfadgeordnetes Exponential in die Gruppe. Deine eigene Formulierung zwei Zeilen tiefer („das Infinitesimale … dessen Exponentiation") ist die richtige; ich würde den Merksatz entsprechend umformulieren.
# 3. Im Clifford-vs-Weyl-Vergleich (Differential-Forms-Sektion) ist ein Satz verrutscht: Unter dem *Clifford*-Punkt steht „Die symplektische Lie-Algebra ist das symmetrische Quadrat. Es ist die orthogonale Algebra $\mathfrak{so}$…" – da sind zwei Sätze ineinander kopiert. Korrekt (und in deiner Tabelle daneben richtig): $\mathfrak{so} \cong \Lambda^2 V$ lebt als Grad-2-Elemente in der Clifford-Algebra, $\mathfrak{sp} \cong \mathrm{Sym}^2 V$ als Grad-2-Elemente in der Weyl-Algebra.
#
# Und eine offene Frage, die du dir selbst in den Notizen gestellt hast („Boring connection – no curvature (is that true?)"): Ja – wenn die Christoffel-Symbole in einer Karte identisch verschwinden, ist die Krümmung dort null, denn $R$ ist aus $\Gamma$ und dessen Ableitungen gebaut. Aber Vorsicht mit der Umkehrung: Krümmung null heißt nur *lokal* trivial. Auf nicht einfach zusammenhängenden Räumen kann ein flacher Zusammenhang trotzdem nichttriviale Holonomie um Schleifen haben – das ist exakt dein Kohomologie-Beispiel mit der punktierten Ebene, nur in der Sprache der Zusammenhänge (physikalisch: Aharonov-Bohm, das du in der HW-Sektion sogar schon erwähnst). Die drei Stellen deines Notebooks, an denen dasselbe Phänomen auftaucht – geschlossene, nicht exakte Form / flacher Zusammenhang mit Holonomie / Phasenfaktor $e^{i\pi qp/d}$ – sind ein und dieselbe Mathematik.

# %% [markdown]
# ###### <font color="blue">*Differential Forms*

# %% [markdown]
# <font color="blue">**(Multilinear) Map**
#
# * **0-Map**: 0-lineare Abbildung) ist ein [Skalar](https://de.wikipedia.org/wiki/Skalar_(Mathematik)), eine Zahl aus dem zugrundeliegenden Körper, z. B. $R$ oder $C$. Wartet auf keinen Vektor. Ist bereits eine Zahl.
# * **1-Map**: [Linear Map](https://de.wikipedia.org/wiki/Lineare_Abbildung) (Vector-Covector-Pairs)
#   * Vektor $w$ aus dem Zielraum $W$ und einen Covektor $\alpha$ aus dem Dualraum $V^*$. Tensorprodukt $w \otimes \alpha$. Multiplikation mit Vektor $v$. Covektor (Linearform) $\alpha$ verarbeitet Vektor $v$. Ergebnis von $\alpha(v)$ ist Zahl (Skalar). Diese Zahl wird nun mit Vektor $w$ multipliziert = $(w \otimes \alpha)(v) = \alpha(v) \cdot w$. Eine Zahl mal einem Vektor ergibt einen Vektor (in $W$) = lineare Abbildung.
#   * Beispiel: Matrix. Ist lineare Abbildung, multipliziert man nach dem Prinzip Zeile (Covektoren, nehmen den Spaltenvektor und berechnen das Skalarprodukt) mal Spalte (Basisvektoren des Zielraums). **Output: Vektor.**
#   * **Merke: Maps haben Vektor (oder Funktion) als Output, Forms eine Zahl!**
#   * Jede lineare Abbildung $L$ lässt sich also als Summe von Vektor-Covektor-Paaren schreiben (wobei $e_i$ die Basisvektoren und $e^j$ die dualen Basis-Covektoren sind): $L = \sum_{i,j} L^i_j (e_i \otimes e^j)$
# * **2-Map**: [Bilinear Map](https://de.wikipedia.org/wiki/Bilineare_Abbildung):  z.B. [Metric tensor](https://de.wikipedia.org/wiki/Metrischer_Tensor) with two vectors as input and a scalar as output. $ g(P)\colon V\times V\to \mathbb {R} $ eine positiv definite, symmetrische Bilinearform.
# * **k-Map**: [Multilinear Map](https://de.wikipedia.org/wiki/Multilineare_Abbildung): z.B. [Determinante](https://de.wikipedia.org/wiki/Determinante)
# * **Linear Map vs. Operator**: Lineare Abbildung: Jede Struktur, die Vektoren von Raum $V$ in einen Raum $W$ transportiert und dabei die Linearkombinationen erhält (also $f(x+y) = f(x)+f(y)$ und $f(c \cdot x) = c \cdot f(x)$). [Operator](https://de.wikipedia.org/wiki/Operator_(Mathematik)) benutzt man für Endomorphismen (Abbildung einen Vektorraum in sich selbst abbildet $f: V \to V$ und lineare Abbildung zwischen Funktionenräumen einen "Operator" (z. B. der Ableitungsoperator, der eine Funktion nimmt und deren Ableitung ausgibt).

# %% [markdown]
# <font color="blue">**(Multilinear) Form**
# * 'Multilinear Form': for **Single Vector** und **symmetrische Form** (wird in Riemann Geometrie genutzt). General 'Form' (Algebraic): a homogeneous polynomial. Example: x² + y² = 0 is a 2-form (or quadratic form)
# * **0-Form**: [Glatte_Funktion](https://de.wikipedia.org/wiki/Glatte_Funktion)
# * **1-Form**: [Linear Form](https://de.wikipedia.org/wiki/Linearform): auch 1-Multilinearform, One-Form, Covector, kovarianter Tensor erster Stufe, [Pfaff'sche Form](https://de.wikipedia.org/wiki/Pfaffsche_Form), Element des Dualraums: lineare Abbildung $\alpha: V \to K$, die einen Vektor auf eine Zahl abbildet
# * **2-Form**: [Bilinear Form](https://de.wikipedia.org/wiki/Bilinearform): Covektor-Covektor-Paar: ordnet zwei Vektoren einen Wert zu. Z. B. [Skalarprodukt](https://de.wikipedia.org/wiki/Skalarprodukt). Ist symmetrisch $B(v,w) = B(w,v)$.
#   * Bilinearform $B$ lässt sich als Linearkombination von Paaren der Basis-Covektoren darstellen: $B = \sum_{i,j} B_{ij} (e^i \otimes e^j)$.
#   * Die Koeffizienten $B_{ij}$ sind die Einträge der Darstellungsmatrix der Bilinearform. Das $e^i \otimes e^j$ ist das Covektor-Paar, das abfragt, wie stark die Vektoren in die jeweiligen Basisrichtungen zeigen.
#   * Beispiel: zwei Covektoren $\alpha \in V^*$ und $\beta \in V^*$ verarbeiten zwei Vektoren $v$ und $w$. Ergebnis: neue Funktion von den Ergebnissen der Multiplikation beider Covektoren über das Tensorprodukt $\alpha \otimes \beta$: $f(v, w) = \alpha(v) \cdot \beta(w)$.
# * **k-Form**: [Multilinear Form](https://de.wikipedia.org/wiki/Multilinearform)
# * **Linear Form vs. Funktional**:  erfüllen beide dieselben Axiome. Linearform eher algebraischer Begriff für endlichdimensionale, additive und homogene Abbildungen $f: V \to K$ von Vektorraum $V$ in Grundkörper $K$, z.B. reellen Zahlen $\mathbb{R}$).  [Funktional](https://de.wikipedia.org/wiki/Funktional) für unendlich dimensionale Räume in Funktionalanalysis, in denen Vektoren selbst Funktionen sind (z.B. Raum aller stetigen Funktionen) denen eine Zahl zugeordnet ist (z.B. ein Integral).

# %% [markdown]
# <font color="blue">**Differential Form**
# * The core of differentail forms: https://youtu.be/DOPwupMCcUs?is=xTEZ8znQMMGBdLBX$0
# * Lecture 5 Differential Forms https://youtu.be/4zicWglBfIE?is=wH_pSVq1GCtygXtI$0
# * Differential Form = Multilinear Form + Exterior derivative properties (antisymmetry) and for entire for Vector Field.
#   * Differentialform ordnet Punkt einer Mannigfaltigkeit eine alternierende Multilinearform auf dem zugehörigen Tangentialraum zu.
#   * Um eine Differentialform vom Grad $k$ zu erhalten, multipliziert man 1-Formen (und Funktionen) miteinander. Das äußere Produkt ist per Definition alternierend. Für 1-Formen $\alpha $ und $\beta $ gilt: $\alpha \wedge \beta = -(\beta \wedge \alpha)$. Antisymmetry in k-Form: $\omega(v_1, \dots, v_i, \dots, v_j, \dots, v_k) = -\omega(v_1, \dots, v_j, \dots, v_i, \dots, v_k)$
#   * Differentialformen $\Omega^k(M) = \Gamma(\Lambda^k T^*M)$ sind  = antisymmetrische Tensorfelder mit Keilprodukt (Graßmann). Measure vector with covector, measure k-vector with k-form. Eine algebraische Form lebt starr in einem einzigen Vektorraum, während eine Differentialform ein ganzes Feld von Formen ist, das sich von Punkt zu Punkt in einem Raum ändert.
#   * Directional derivative : vector + change of rate of a scalar (via one form).
#   * Used to measure and integrate lengths, areas, and volumes functions over curves, surfaces, and higher-dimensional spaces. Understands direction and spatial size. Adjusts to stretching or squishing space to accurately measure size of an area or line.
# * **Differential 0-Form (Glatte Funktion)**: Normale skalare Funktionen $f(x, y, z)$ (z. B. Temperatur). Man "integriert" sie über 0-dimensionale Punkte (das bedeutet einfach, man wertet die Funktion am Punkt aus).
# * **Differential 1-Form:** $dx, dy, dz$. Objekte, die man über eindimensionale Kurven integriert (z. B. Arbeit, die man entlang eines Weges leistet). Auch: glattes **Covector Field** und Pfaffsche Form. Symmetrie und Antisymmetrie bei 1-Form irrelevant (bei nur einem Argument kann man nichts vertauschen).
# * **Differential 2-Form**: $dx \wedge dy$ und $ dy \wedge dz$. Spezielle Bilinearform, die zwei Vektoren nimmt und eine reelle Zahl berechnet.
#   * Linear und alternierend (antisymmetrisch) $\omega(v, w) = -\omega(w, v)$. Setzt man zweimal denselben Vektor ein, ist das Ergebnis immer Null (z. B. $\omega(v, v) = 0$).
#   * Zur Berechnung eines Flächeninhalts, z.B. [Determinante](https://de.wikipedia.org/wiki/Determinante). Vertauscht man die zwei Vektoren, die die Fläche aufspannen, wird die Fläche negativ. Zur Integration zweidimensionaler Flächen (z.B. magnetischer Fluss durch eine Leiterschleife). [Bivektor](https://de.wikipedia.org/wiki/Bivektor).
#   * 2-Differentialform ist ortsabhängig - hängt an jedem Punkt eines geometrischen Raumes (z.B. Fläche oder eines Volumens) von den dortigen Koordinaten ab und wird mit äußeren Produkt (Keilprodukt $\land $) dargestellt.
# * **Differential 3-form**: $dx \wedge dy \wedge dz$. Objekte, die man über dreidimensionale Volumina integriert (z. B. Massendichte in Raum).
# * **Differential k-form**: vollständig antisymmetrischer kovarianter Tensor vom Rang $k$

# %% [markdown]
# <font color="blue">**Symplectic Form**
#
# 1. **Symplectic Form = Differential 2-Form $\omega$ (antisymmetrische Bilinearform) + Geschlossen + Nicht-ausgeartet**. Symplektische Form $\omega$ als Objekt, auf Phasenraum ist $\omega = \sum_{i=1}^n dp_i \wedge dq_i \;\in\; \Omega^2(M) = \Gamma(\Lambda^2 T^*M)$. $\omega$ ist punktweise ein Element von $\Lambda^2 V^*$.
# * **Alternierend/Schief-symmetrisch:** $\omega(v, w) = -\omega(w, v)$ für alle $v, w \in V$. Alternierend: $\omega(v, v) = 0$ für alle $v \in V$.
# * **Global geschlossen $d\omega = 0$**($d$ ist äußere Ableitung, Differentialoperator auf äußeren Algebra). Eine normale 2-Differentialform ist zwar immer alternierend (antisymmetrisch), aber sie ist nicht automatisch geschlossen. Das äußere Differential einer beliebigen 2-Form kann eine von null verschiedene 3-Form ergeben. Die symplektische Form wird explizit dazu gezwungen, geschlossen zu sein.
# * **Nicht-entartete (non-degenerate) Bilinearform** (Differential-2-Form): Wenn $\omega(v, w) = 0$ für alle $w \in V$, dann muss $v = 0$ sein. Nichtausgeartet ist (aus $\omega(v, w) = 0$ für alle $w$ folgt $v = 0$).
# * Punktweise an jedem Tangentialraum $T_xM$ verhält sich $\omega_x$ wie ein Element der äußeren Algebra $\Lambda^2(T_x^*M)$. Das $m$-fache Keilprodukt $\omega \wedge \dots \wedge \omega = \omega^m$ (wobei $\dim M = 2m$) verschwindet an keinem Punkt. Diese Top-Form $\omega^m$ ist die Liouville-Volumenform aus der äußeren Algebra.
# * **Kern-Eigenschaft:** Für jeden Tangentialvektor $v \neq 0$ muss es einen anderen Vektor $w$ geben, sodass $\omega(v, w) \neq 0$ gilt = Für jede Richtung (jeden Vektor) gibt es mindestens eine andere Richtung, bei der das Ergebnis der Form nicht Null ist. * Wenn eine Bilinearform $B(x,y)$ für einen festen Vektor $x$ und alle beliebigen Vektoren $y$ stets den Wert $0$ ergibt, dann muss $x$ zwingend der Nullvektor sein.Formel: $\forall y: B(x,y) = 0 \implies x = 0$. Kein Vektor ist in der Lage, mit allen anderen Vektoren gleichzeitig zu Null zu verschwinden. Ein nicht-ausgeartetes System stellt sicher, dass man Operationen eindeutig umkehren kann.
# * **Matrixdarstellung** dieser Form darf also keine Nullzeilen oder Nullspalten haben und ihre Determinante darf nicht null sein. Sichtweise über Matrizen: Wenn Sie die Form durch eine Matrix darstellen, bedeutet „nicht-ausgeartet“, dass diese Matrix invertierbar (bzw. regulär) ist und ihre Determinante ungleich Null ist.
# * **Geometrische Intuition**: Das klassische Standardskalarprodukt aus der Geometrie ist ebenfalls nicht-ausgeartet. Wenn zwei Vektoren senkrecht (orthogonal) aufeinander stehen, ist ihr Skalarprodukt $0$. Das ist nichts Besonderes. Bei einer nicht-ausgearteten Form ist der Nullvektor jedoch der einzige Vektor, der auf allen anderen Vektoren senkrecht steht.
# * **Konsequenzen**: symplektische Mannigfaltigkeiten haben immer **gerade Dimension** (wie $2n$). In der theoretischen Physik spiegelt sich das im Phasenraum der klassischen Mechanik wider, wo jedem Freiheitsgrad des Ortes genau ein Freiheitsgrad des Impulses zugeordnet ist.
# 2. **Symplektische Gruppe $\mathrm{Sp}(2n, \mathbb{K})$**
#   * Linearen Automorphismen, die $\omega$ invariant lassen: $\mathrm{Sp}(2n,\mathbb{K}) = \{ S \in \mathrm{GL}(2n,\mathbb{K}) : S^T J S = J \}$. Elemente heißen **symplektische Abbildungen**.
#   * Die symplektische Gruppe verhält sich zur *alternierenden* Bilinearform exakt so wie die orthogonale Gruppe (längentreue Abbildungen) zur nichtausgearteten *symmetrischen* Bilinearform:
#   | Bilinearform | invariante Gruppe |
#   |---|---|
#   | symmetrisch, nichtausgeartet ($g$) | orthogonale Gruppe $\mathrm{O}(V, g)$ |
#   | alternierend, nichtausgeartet ($\omega$) | symplektische Gruppe $\mathrm{Sp}(V, \omega)$ |
#   * Die **doppelte Überlagerung** von $\mathrm{Sp}(2n,\mathbb{R})$ ist die **metaplektische Gruppe** $\mathrm{Mp}(2n,\mathbb{R})$ — genau die Gruppe, deren Darstellung auf dem Fock-Raum die Gaussian unitaries liefert (Oszillatordarstellung).
# 3. **Symplektische Lie-Algebra $\mathfrak{sp}(2n, \mathbb{K})$**
#   * Lie-Algebra der symplektischen Gruppe $\mathfrak{sp}(2n,\mathbb{K}) = \{ A \in \mathbb{K}^{2n \times 2n} : A^T J + J A = 0 \}$ sind linearen Abbildungen, die $\omega$ erhalten:  $S = e^{tA}$ in $S^T J S = J$ auf Gruppenebene, und bei $t = 0$ differenzieren infinitesimal formerhaltend: $A^T J + J A = 0$.
#   * **Geometrische Bedeutung:** Elemente von $\mathfrak{sp}(2n)$ sind lineare Hamiltonschen Vektorfelder, Erzeuger der linearen Phasenraumflüsse der klassischen Mechanik.
#   * **Blockgestalt:** Die Bedingung ist äquivalent zu $A = \begin{pmatrix} B & C \\ D & -B^T \end{pmatrix}, \qquad C = C^T,\; D = D^T,\; B \text{ beliebig}$
#   * **Dimension:** $\dim \mathfrak{sp}(2n,\mathbb{K}) = \underbrace{n^2}_{B} + \underbrace{\tfrac{n(n+1)}{2}}_{C} + \underbrace{\tfrac{n(n+1)}{2}}_{D} = 2n^2 + n = n(2n+1)$
#   * **Klassifikation:** Über $\mathbb{R}$ bzw. $\mathbb{C}$ eine der **vier klassischen einfachen Lie-Algebren** ($A_n = \mathfrak{sl}$, $B_n = \mathfrak{so}_{2n+1}$, $C_n = \mathfrak{sp}_{2n}$, $D_n = \mathfrak{so}_{2n}$).
# 4. **Symplektischer Vektorraum $(V, \omega)$**:
#   * Sei $V$ ein endlich-dimensionaler Vektorraum. Die äußere Algebra $\Lambda(V^*)$ ist die direkte Summe aller alternierenden Multilinearformen auf $V$: $\Lambda(V^*) = \bigoplus_{k=0}^{\dim V} \Lambda^k(V^*)$.
#   * Ein Vektorraum $V$ zusammen mit einer symplektischen Form $\omega$ auf $V$ (=Element des Raumes der 2-Formen $\Lambda^2(V^*)$, welches zwei Bedingungen erfüllt: alternierende und nicht-ausgeartete Bilinearform) ist ein symplektischen Vektorraum.
#   * **Darboux-Basis:** Jeder symplektische Vektorraum besitzt eine Basis, in der $\omega$ die Standard-Matrixgestalt annimmt: $J = \begin{pmatrix} 0 & I_n \\ -I_n & 0 \end{pmatrix}$ mit $I_n$ als $n$-dimensionaler Einheitsmatrix. Es gibt nur einen symplektischen Vektorraum pro Dimension.
#   * **Satz von Darboux**: Während in der euklidischen Geometrie das innere Produkt (Skalarprodukt) beliebig viele Formen annehmen kann, gibt es in der symplektischen Algebra keine lokalen Invarianten außer der Dimension. Nach dem Satz von Darboux gibt es in jedem symplektischen Vektorraum der Dimension $n = 2m$ immer eine spezielle Basis, die sogenannte Darboux-Basis $\{p_1, \dots, p_m, q_1, \dots, q_m\}$, sodass die symplektische Form in der äußeren Algebra exakt wie folgt dargestellt wird: $\omega = \sum_{i=1}^{m} dp_i \wedge dq_i$
#   * **Erhaltungssätze (Satz von Liouville)**: Keilprodukt der äußeren Algebra liefert fundamentale physikalische Gesetze. Wenn ein System entlang des Hamiltonschen Vektorfelds $X_H$ fließt (die Zeitentwicklung des Systems), bleibt die symplektische Form invariant. Das Phasenraumvolumen bleibt während der physikalischen Bewegung exakt erhalten.
#
# <font color="blue">**Unterschied Multilinear Form (symmetrisch, Clifford/Geometric) vs Symplectic Form (antisymmetrisch, Heisenberg-Weyl)**
# * **Clifford (Riemann):** $\underbrace{g \text{ (symmetrisch, Riemann)}}_{\text{Eingabe}} \to \mathrm{Clifford}(V,g) \to \underbrace{\mathfrak{so} = \Lambda^2 V \to \mathrm{Spin}\text{-Darstellung}}_{\text{Grad-2-Elemente}} \to \text{Fermion, } \Lambda\text{-Fock}$
#   * $\text{Metrik } g \in \mathrm{Sym}^2 V^* \;\longrightarrow\; \text{Clifford} \;\supset\; \mathfrak{so} \cong \Lambda^2 V$
#   * Symmetrische Eingabe → antikommutierende Ausgabe (und die Erhaltungsalgebra ist das äußere Quadrat)
#   * Die symplektische Lie-Algebra ist das **symmetrische** Quadrat. Es ist die *orthogonale* Algebra $\mathfrak{so}$, die aus Bivektoren $e_i \wedge e_j$ besteht und daher in der Clifford-Algebra lebt (als quadratische Elemente $\tfrac{1}{4}[e_i, e_j]$ — das ist die Spin-Darstellung).
#   * In geometrischer Algebra nutzt man oft Metrik mit gemischter Signatur (wie im Phasenraum), um symplektische Transformationen direkt als Rotationen (Mischung von Ort und Impuls) innerhalb einer Clifford-Algebra abzubilden. Das äußere Produkt $\wedge$ dient dabei weiterhin dazu, die symplektischen Flächenelemente $dp_i \wedge dq_i$ geometrisch als Bivektoren darzustellen.
#
# * **Weyl (Symplektisch):** $\underbrace{\omega \text{ (antisymmetr., symplekt.)}}_{\text{Eingabe}} \to \text{Weyl}(V,\omega) \to \underbrace{\mathfrak{sp} = \mathrm{Sym}^2 V \to \text{metaplektisch}}_{\text{Grad-2-Elemente}} \to \text{Boson, } \mathrm{Sym}\text{-Fock}$
#   * $\text{Symplektische Form } \omega \in \Lambda^2 V^* \;\longrightarrow\; \text{Weyl} \;\supset\; \mathfrak{sp} \cong \mathrm{Sym}^2 V$ . Weyl-Algebra = Symplektische Clifford-Algebra
#   * Antisymmetrische Eingabe → kommutierende Ausgabe (und die Erhaltungsalgebra ist das symmetrische Quadrat)
#   * $\mathfrak{sp}(2n)$ als quadratische Elemente in der **Weyl-Algebra**: Die symmetrisierten Produkte $\tfrac{1}{2}\{\hat r_i, \hat r_j\}$ mit $\hat r = (\hat q_1,\dots,\hat q_n,\hat p_1,\dots,\hat p_n)$ schließen unter dem Kommutator genau auf $\mathfrak{sp}(2n,\mathbb{R})$ — das ist die metaplektische (Oszillator-)Darstellung, das bosonische Gegenstück zur Spinordarstellung.
#
# | Geometrie | Fundamentale Form | Algebra-Struktur | Physikalisches Pendant |
# |---|---|---|---|
# | Riemannsch | Symmetrisch ($g$) | Clifford-Algebra ($vw+wv=2g$) | Raumzeit / Fermionen |
# | Symplektisch | Antisymmetrisch ($\omega$) | Weyl-Algebra ($vw-wv=\omega$) | Phasenraum / Bosonen |
# | Topologisch | Keine Metrik / Form | Äußere Algebra ($\omega \wedge \eta$) | Differentialformen / Erhaltungssätze |
#
# * Die Clifford-Algebra entsteht, indem man das Tensorprodukt durch das Ideal $v \otimes v = g(v,v)$ teilt (Quantisierung eines symmetrischen Tensors). Wenn man exakt dasselbe Verfahren auf ein antisymmetrisches Gebilde (wie die symplektische Form $\omega$) anwendet, landet man in der Quantenmechanik.
# * **Die Weyl-Algebra (Symplektische Clifford-Algebra)**: Teilt man die Tensoralgebra nicht durch ein symmetrisches Ideal, sondern erzwingt die Relation: $v \otimes w - w \otimes v = \omega(v,w) \cdot 1$, dann erhält man die sogenannte Weyl-Algebra (auch bekannt als symplektische Clifford-Algebra).
#   * In der normalen Clifford-Algebra gilt für orthogonale Vektoren: $vw + wv = 0$ (Antikommutator, beschreibt Fermionen).
#   * In der symplektischen Clifford-Algebra gilt für kanonische Variablen: $qp - pq = \hbar$ (Kommutator, beschreibt Bosonen).
# * Die symplektische Geometrie ist also das klassische Gegenstück zur Weyl-Algebra, genau wie die riemannsche Geometrie das klassische Gegenstück zur standardmäßigen Clifford-Algebra ist.
# * Beispiel aus der klassischen Mechanik und der Geometrie ist die Standardform $\omega = \sum dx_i \wedge dy_i$, welche die Grundlage für Hamiltonsche Systeme in der Physik bildet. In der Physik spannen die Ortskoordinaten $q_i$ und die Impulskoordinaten $p_i$ diesen Raum auf (den Phasenraum). Die fundamentale Form lautet dort: $\omega = \sum_{i=1}^n dp_i \wedge dq_i$
#
#
#
# <font color="blue">**So entsteht die Heisenbergsche Unschärferelation direkt aus der symplektischen Form**
#
# * Die Heisenbergsche Unschärferelation ist im Kern kein rein quantenmechanisches Phänomen, sondern eine mathematische Eigenschaft, die direkt aus der Geometrie des Phasenraums – genauer gesagt aus der Nicht-Degeneriertheit der symplektischen Form – hervorgeht.
# * In der Quantenmechanik wird diese Geometrie lediglich über Operatoren abgebildet. Hier ist der direkte geometrische und algebraische Weg von der symplektischen Form zur Unschärferelation.
#
#
# 1. Das geometrische Fundament
#
# * Cauchy-Schwarz-Ungleichung für Formen
# Um die Unschärfe zu verstehen, betrachten wir zwei statistische Zustände (Vektoren im Phasenraum oder Wellenfunktionen) und die darauf definierte symplektische Form $\omega$.
# Für jede symplektische Form $\omega$ und ein gegebenes Skalarprodukt $g$ (das die Standardabweichungen misst) existiert eine fundamentale geometrische Ungleichung für zwei Vektoren $X$ und $Y$:
# $$\vert{}\omega(X, Y)\vert{}^2 \leq g(X, X) \cdot g(Y, Y)$$
# Das bedeutet: Der durch die symplektische Form gemessene, gerichtete Flächeninhalt des von $X$ und $Y$ aufgespannten Parallelogramms kann niemals größer sein als das Produkt der metrischen Längen (Normen) dieser Vektoren.
#
#
# 2. Der Übergang zur Physik (Varianz und Kovarianz)
#
# * In der Physik interpretieren wir die Vektoren $X$ und $Y$ als die statistischen Abweichungen (Fluktuationen) der physikalischen Observablen vom Mittelwert:
#   * Let $X = A - \langle A \rangle$ (Fluktuation der Observablen $A$)
#   * Let $Y = B - \langle B \rangle$ (Fluktuation der Observablen $B$)
# * Die metrischen Längen $g(X,X)$ und $g(Y,Y)$ entsprechen in der statistischen Auswertung exakt den Varianzen $(\Delta A)^2$ und $(\Delta B)^2$. Setzen wir dies in die obige geometrische Ungleichung ein, erhalten wir:
# $$(\Delta A)^2 \cdot (\Delta B)^2 \geq \vert{}\omega(X, Y)\vert{}^2$$
#
#
# 3. Einsetzen der symplektischen Struktur
# * die symplektische Struktur ist das algebraische Gegenstück zum Kommutator in der Weyl-Algebra (Quantisierung). Für die Quantenmechanik gilt die mathematische Identität, dass der Erwartungswert des Kommutators zweier Operatoren genau dem Wert der symplektischen Form entspricht (multipliziert mit der imaginären Einheit $i$ und normiert durch $\hbar$):
# $$\omega(X, Y) = \frac{1}{2i} \langle [A, B] \rangle$$
#
# * Setzen wir diesen Wert nun in unsere geometrische Flächenungleichung ein, transformiert sich das rein geometrische Verhältnis in die berühmte physikalische Formel:
# $$(\Delta A)^2 \cdot (\Delta B)^2 \geq \left\vert{} \frac{1}{2i} \langle [A, B] \rangle \right\vert{}^2 = \frac{1}{4} \vert{} \langle [A, B] \rangle \vert{}^2$$
#
# * Zieht man auf beiden Seiten die Quadratwurzel, resultiert die allgemeine Robertson-Schrödinger-Unschärferelation:
# $$\Delta A \cdot \Delta B \geq \frac{1}{2} \vert{} \langle [A, B] \rangle \vert{}$$
#
#
# 4. Das konkrete Beispiel: Ort und Impuls
#
# * Wählen wir für die Observable $A$ den Ort ($q$) und für $B$ den Impuls ($p$), greift die fundamentale Definition der symplektischen Form im Phasenraum ($\omega = dp \wedge dq$). Da Ort und Impuls kanonisch konjugiert sind, ist ihre symplektische Fläche normiert: $[q, p] = i\hbar$.
# * Daraus folgt direkt:
# $$\Delta q \cdot \Delta p \geq \frac{1}{2} \vert{}i\hbar\vert{} = \frac{\hbar}{2}$$
#
# 5. Zusammenfassung
#
# * Die Heisenbergsche Unschärferelation besagt geometrisch, dass man im Phasenraum keinen Zustand auf einen Punkt reduzieren kann, weil die symplektische Form $\omega$ jedem Zustand eine minimale, unteilbare "Fläche" (ein quantenmechanisches Wirkungselement) auferlegt.
# * Das äußere Produkt verhindert durch seine fundamentale Struktur, dass diese Fläche kollabiert und zu Null wird.
#
# <font color="blue">**Appendix: Symplectic in Heisenberg-Weyl** (Gaussisch vs. non-Gaussian, Grad 2 vs. Grad 3)
#   * Quantenoptik-Literatur wird „symplektisch" oft für alles verwendet, was mit Gaussian dynamics zu tun hat.
#   * Die Heisenberg-Weyl-Algebra ist als Vektorraum $\mathrm{Sym}(V)$ — Polynome in $\hat q, \hat p$ — und sie ist nach Polynomgrad *filtriert*:
#   * **Grad ≤ 1** (linear plus Konstante) bildet die **Heisenberg-Lie-Algebra** $\mathfrak{h}_n$: $[\hat q, \hat p] = i\hbar$. Exponenzieren gibt Verschiebungen (Displacement-Operatoren $D(\alpha)$).
#   * **Grad 2** (quadratische Hamiltonians $H = \tfrac{1}{2}\hat r^T M \hat r$) bildet unter dem Kommutator genau $\mathfrak{sp}(2n,\mathbb{R})$. Exponenzieren gibt die metaplektische Gruppe, und im Heisenberg-Bild wirkt so ein $U = e^{-iHt}$ **linear** auf die Quadraturen: $U^\dagger\, \hat r\, U = S\, \hat r, \qquad S \in \mathrm{Sp}(2n,\mathbb{R}).$ Das sind die Gaussian unitaries (Squeezing, Beamsplitter, Phasenrotation), die Gauß-Zustände auf Gauß-Zustände abbilden. Zusammen: $\mathfrak{sp}(2n) \ltimes \mathfrak{h}_n$ — die Algebra der Gaussian operations.
#   * **Grad ≥ 3:** Nimmst du $H = \gamma \hat q^3$ (Cubic-Phase-Gate), liegt $H$ außerhalb von $\mathfrak{sp} \ltimes \mathfrak{h}$, und die Heisenberg-Evolution wird **nichtlinear**: $e^{i\gamma \hat q^3 t}\, \hat p\, e^{-i\gamma \hat q^3 t} = \hat p - 3\gamma t\, \hat q^2.$
#     * Ist man noch symplektisch? **Grad ≥ 3 ist keine lineare symplektische Abbildung $S\hat r$ mehr**, und Gauß-Zustände werden non-Gaussian. Aber die unitäre Evolution erhält weiterhin die CCR, also $[\,U^\dagger \hat q U,\; U^\dagger \hat p U\,] = i\hbar$.
#     * Die symplektische *Struktur* des Phasenraums (die 2-Form $\omega$, das „Regelwerk") bleibt vollständig intakt; jede unitäre Zeitentwicklung ist ein Automorphismus der Weyl-Algebra. Was verloren geht, ist die *Linearität* der Abbildung auf den Quadraturen — **man fällt aus der endlichdimensionalen Gruppe $\mathrm{Sp}(2n)$ heraus, nicht aus der symplektischen Geometrie**.
#     * (Klassisches Analogon: Ein kubischer Hamiltonian erzeugt einen nichtlinearen, aber immer noch symplektischen Fluss — Hamiltonsche Flüsse erhalten $\omega$ per Liouville immer.)
#   * **Summary**: Gaussian/non-Gaussian: Kubische Exponenten verlassen die symplektische Grad-≤2-Schicht, nicht die Weyl-Algebra oder die symplektische Geometrie selbst.
#   * Die symplektische Form ist die wichtigste einzelne Differentialform, aber symplektische Dynamik wird durch die Weyl-Algebra (symmetrische Seite) quantisiert.
#   * Eine einzelne Differentialform ($\omega$) ist der Bauplan der Weyl-Algebra, aber die Algebra der Differentialformen ($\Lambda$, Keilprodukt) ist nicht ihre Struktur — sie ist die Struktur der Clifford-Seite. Die Elemente der Weyl-Algebra $\hat q$, $\hat p$ (deren Polynome, Differentialoperatoren) sind symmetrische Objekte, keine Formen.

# %% [markdown]
# ###### <font color="blue">*Exterior Algebra*

# %% [markdown]
# <font color="blue">**Beispiel: Übergang vom Tensorprodukt zur äußeren Algebra**
#
# Der genaue Übergang vom Tensorprodukt zur äußeren Algebra erfolgt durch das Quotientenbildung-Verfahren über ein bestimmtes Ideal. Dabei wird die freie Struktur des Tensorprodukts so eingeschränkt, dass alle symmetrischen Anteile herausfallen und die gewünschte Antisymmetrie entsteht.
# Hier ist die exakte mathematische Konstruktion Schritt für Schritt erklärt.
#
# 1. **Die Tensoralgebra aufbauen**: Zuerst konstruiert man die gesamte Tensoralgebra $T(V)$ über einem Vektorraum $V$. Diese Algebra enthält alle denkbaren Tensoren jeder Stufe (Skalare, Vektoren, Bilinearformen, Multilinearformen). Sie ist definiert als die direkte Summe aller Tensorpotenzen:
# $$T(V) = \bigoplus_{k=0}^{\infty} T^k(V) = \mathbb{K} \oplus V \oplus (V \otimes V) \oplus (V \otimes V \otimes V) \oplus \dots$$
# In dieser Algebra ist das Tensorprodukt $\otimes$ die Verknüpfung. Es ist assoziativ, aber absolut nicht kommutativ und besitzt noch keine Symmetrieeigenschaften.
#
#
# 2. **Das zweiseitige Ideal definieren**: Um die Antisymmetrie zu erzwingen, definiert man ein zweiseitiges Ideal $I$, das von allen Elementen der Form $v \otimes v$ für $v \in V$ erzeugt wird.
# $$I = \langle \{ v \otimes v \mid v \in V \} \rangle$$
# Dieses Ideal enthält alle Elemente, die verschwinden müssen, wenn man die äußere Algebra konstruiert.
#
# 3. **Den Quotientenraum bilden**: Die äußere Algebra $\Lambda(V)$ (oder Graßmann-Algebra) entsteht nun, indem man die Tensoralgebra $T(V)$ durch dieses Ideal $I$ faktorisiert:
# $$\Lambda(V) = T(V) / I$$
# Zwei Tensoren in $T(V)$ werden in der äußeren Algebra also genau dann als gleich betrachtet, wenn ihre Differenz im Ideal $I$ liegt. Das Produkt in dieser neuen Algebra nennen wir das äußere Produkt (Keilprodukt) $\wedge$. Für zwei Vektoren $v, w \in V$ gilt per Definition:
# $$v \wedge w = [v \otimes w] \pmod I$$
#
# 4. **Warum Antisymmetrie entsteht**: Aus der Bedingung, dass $v \otimes v \in I$ liegt, folgt im Quotientenraum direkt die Eigenschaft:
# $$v \wedge v = 0 \quad \forall v \in V$$
# Wenn wir nun das äußere Produkt von zwei unterschiedlichen Vektoren $v + w$ mit sich selbst bilden, erhalten wir:
# $$0 = (v + w) \wedge (v + w) = (v \wedge v) + (v \wedge w) + (w \wedge v) + (w \wedge w)$$
# Da $v \wedge v = 0$ und $w \wedge w = 0$ sind, vereinfacht sich die Gleichung zu:
# $$0 = (v \wedge w) + (w \wedge v) \implies v \wedge w = -(w \wedge v)$$
# Durch die Definition des Ideals wird die Struktur also automatisch gezwungen, antisymmetrisch zu sein.
#
#
# 5. **Projektion und der Alternierungsoperator**: In der Praxis (besonders bei Differentialformen) möchte man oft ein Element aus $T^k(V)$ direkt in $\Lambda^k(V)$ abbilden. Das geschieht über den Alternierungsoperator $\operatorname{Alt}$.
# Für einen k-Tensor $T$ (wie eine Multilinearform) filtert dieser Operator alle symmetrischen Komponenten heraus, indem er über alle Permutationen $\sigma$ der symmetrischen Gruppe $S_k$ summiert und mit dem Vorzeichen der Permutationsparität $\operatorname{sgn}(\sigma)$ gewichtet:
# $$\operatorname{Alt}(T)(v_1, \dots, v_k) = \frac{1}{k!} \sum_{\sigma \in S_k} \operatorname{sgn}(\sigma) \cdot T(v_{\sigma(1)}, \dots, v_{\sigma(k)})$$
# Das äußere Produkt zweier Formen lässt sich somit auch als reiner Tensor schreiben, den man nachträglich alterniert:
# $$\alpha \wedge \beta = \frac{(k+l)!}{k! \cdot l!} \operatorname{Alt}(\alpha \otimes \beta)$$
#
# 6. **Zusammenfassung der Konstruktion:**
# Der Übergang von der Tensoralgebra zur äußeren Algebra ist der mathematische Schritt $\Lambda(V) = T(V) / \langle v \otimes v \rangle$. Das Tensorprodukt liefert den freien Raum aller Multilinearformen, während das Herausteilen des Ideals alle symmetrischen Terme eliminiert und die totale Antisymmetrie der Differentialformen erzeugt.

# %% [markdown]
# <font color="blue">**Bedeutung der Äußere Ableitung für Differentialformen**
#
# > spezialfall der clifford algebra
#
# * Äußere Algebra (Graßmann-Algebra): Um Formen höheren Grades zu bauen, multipliziert man Formen niedrigeren Grades mit dem Keilprodukt ($\wedge$).
#   * **Antikommutativität:** Flächen haben eine Orientierung. Wenn du Länge und Breite vertauschst, drehst du die Fläche um (das Vorzeichen ändert sich). Daher gilt zwingend: $dx \wedge dy = - (dy \wedge dx)$
#   * **Null-Quadrat:** Wenn eine Fläche zweimal in dieselbe Richtung aufgespannt wird, hat sie den Flächeninhalt null. Daher gilt für jedes $dx$: $dx \wedge dx = 0$
# * **Die äußere Ableitung** ist ein Operator, der einer k-Differentialform eine (k+1)-Differentialform zuordnet. Betrachtet man sie auf der Menge der 0-Differentialformen, also auf der Menge der glatten Funktionen, so entspricht die äußere Ableitung der üblichen Ableitung für Funktionen.
#   * In der Vektoranalysis musstest du dir drei verschiedene Ableitungsoperatoren merken: Gradient, Rotation (Curl) und Divergenz. Die Theorie der Differentialformen ersetzt all diese durch einen einzigen Operator: die äußere Ableitung $d$. Der Operator $d$ nimmt eine $k$-Form und macht daraus eine $(k+1)$-Form. Wie er klassische Operatoren ersetzt:
#     * Wendest du $d$ auf eine 0-Form (Funktion) an, erhältst du den **Gradienten** (eine 1-Form).
#     * Wendest du $d$ auf eine 1-Form an, erhältst du die **Rotation** (eine 2-Form).
#     * Wendest du $d$ auf eine 2-Form an, erhältst du die **Divergenz** (eine 3-Form).
#   * **Die goldene Regel ($d^2 = 0$):** Wendest du die Ableitung zweimal hintereinander an, ist das Ergebnis immer exakt Null: $d(d\omega) = 0$. Das ist der Grund, warum "die Rotation eines Gradienten" und "die Divergenz einer Rotation" in der Physik immer Null sind!
# * Der allgemeine **Satz von Stokes (Die Integration)**: Dies ist die wichtigste Formel der gesamten Differentialgeometrie. Sie ist der Grund, warum Differentialformen erfunden wurden.
#   * Hauptsatz der Differential- und Integralrechnung? $\int_a^b f'(x) dx = f(b) - f(a)$.
#   * Die Theorie der Differentialformen verallgemeinert diesen Satz für jede beliebige Dimension und jeden gekrümmten Raum in eine Gleichung, die unfassbar kurz ist: $\int_{\Omega} d\omega = \int_{\partial \Omega} \omega$
# * Was diese Formel aussagt: Das Integral der Ableitung einer Form ($d\omega$) über ein Gebiet ($\Omega$) ist exakt dasselbe wie das Integral der ursprünglichen Form ($\omega$) über den **Rand** dieses Gebietes ($\partial \Omega$).
#   * In 1D ist es der Hauptsatz der Analysis.
#   * In 2D ist es der Satz von Green.
#   * In 3D (Flächen im Raum) ist es der klassische Satz von Stokes.
#   * In 3D (Volumina) ist es der Satz von Gauß (Divergenzsatz).
# * Der Hodge-Stern-Operator ($\star$)
#   * Das letzte Puzzleteil. In einem Raum der Dimension $n$ gibt es eine tiefe Symmetrie zwischen $k$-Formen und $(n-k)$-Formen.
#   * In unserem 3D-Raum gibt es zum Beispiel drei Basis-1-Formen ($dx, dy, dz$) und drei Basis-2-Formen ($dy \wedge dz, dz \wedge dx, dx \wedge dy$).
#   * Der Hodge-Stern-Operator $\star$ verwandelt die einen in die anderen. Er übersetzt zum Beispiel "Linien" in "die Flächen, die senkrecht darauf stehen".
#   * **Warum das in der Physik wichtig ist:** Elektromagnetische Felder sind eigentlich Differentialformen. Das elektrische Feld $E$ ist eine 1-Form, das magnetische Feld $B$ ist eine 2-Form. Der Hodge-Stern verbindet sie im Vakuum.
# * Differentialformen "putzen" die klassische Mathematik förmlich auf. Sie entfernen alle Matrizen, Indizes und künstlichen Koordinatensysteme und hinterlassen nur die reine, geometrische Wahrheit.

# %% [markdown]
# <font color="blue">**Wie überträgt sich eine konkrete Metrik (wie der Metrische Tensor) auf die äußere Algebra?**
#
# * Eine konkrete Metrik (ein symmetrischer Tensor 2. Stufe, $g \in T^2(V^*)$) überträgt sich auf die äußere Algebra $\Lambda(V)$, indem sie ein inneres Produkt auf jedem Unterraum $\Lambda^k(V)$ induziert.
# * Dieses induzierte Skalarprodukt bildet die Grundlage für geometrische Operationen wie Längen- und Volumenberechnungen von Formen sowie für den Hodge-Stern-Operator.
#
# 1. Das induzierte Skalarprodukt über die Determinante
# Wenn Sie zwei $k$-Formen (äußere Produkte von 1-Formen) gegeben haben, berechnet sich ihr Skalarprodukt über die Determinante der paarweisen metrischen Abstände ihrer Komponenten.
# Für zwei einfache $k$-Formen $\omega = v_1 \wedge \dots \wedge v_k$ und $\eta = w_1 \wedge \dots \wedge w_k$ ist das induzierte Skalarprodukt definiert als:
# $$\langle v_1 \wedge \dots \wedge v_k, \, w_1 \wedge \dots \wedge w_k \rangle_{\Lambda^k} = \det \begin{pmatrix} g(v_1, w_1) & g(v_1, w_2) & \dots & g(v_1, w_k) \\ g(v_2, w_1) & g(v_2, w_2) & \dots & g(v_2, w_k) \\ \vdots & \vdots & \ddots & \vdots \\ g(v_k, w_1) & g(v_k, w_2) & \dots & g(v_k, w_k) \end{pmatrix}$$
#
# * Eigenschaft: Diese Determinante sorgt dafür, dass die Antisymmetrie der äußeren Algebra perfekt respektiert wird. Vertauscht man zwei Vektoren, wechselt eine Zeile/Spalte der Matrix das Vorzeichen, wodurch sich der Wert der Determinante umkehrt. [1]
#
# 2. Berechnung in Komponenten (Koordinatenschreibweise)
# Wählt man eine Basis $\{e_1, \dots, e_n\}$ des Vektorraums und die dazu duale Basis $\{dx^1, \dots, dx^n\}$, wird die Metrik durch ihre Komponenten $g_{ij} = g(e_i, e_j)$ beschrieben.
# Das Skalarprodukt zweier allgemeiner $k$-Formen $\alpha = \frac{1}{k!} \alpha_{i_1 \dots i_k} dx^{i_1} \wedge \dots \wedge dx^{i_k}$ und $\beta = \frac{1}{k!} \beta_{j_1 \dots j_k} dx^{j_1} \wedge \dots \wedge dx^{j_k}$ lautet mit Einsteinscher Summenkonvention:
# $$\langle \alpha, \beta \rangle = \frac{1}{k!} \alpha_{i_1 \dots i_k} \beta_{j_1 \dots j_k} g^{i_1 j_1} \dots g^{i_k j_k}$$
# Hierbei ist $g^{ij}$ die inverse Matrix der Metrik $g_{ij}$, welche die Indizes der Komponenten "hebt".
#
# 3. Orthonormalbasen vereinfachen das Produkt
# Besonders anschaulich wird es, wenn man eine bezüglich $g$ orthonormierte Basis $\{\theta^1, \dots, \theta^n\}$ wählt, für die $g(\theta^i, \theta^j) = \delta^{ij}$ (oder $\eta^{ij}$ in der Minkowski-Metrik) gilt.
# Die induzierte Basis der äußeren Algebra $\Lambda^k(V)$ besteht dann aus den Elementen $\theta^{i_1} \wedge \dots \wedge \theta^{i_k}$ mit aufsteigenden Indizes $i_1 < \dots < i_k$. Diese Basisformen sind unter dem neuen Skalarprodukt ebenfalls orthonormal:
# $$\langle \theta^{i_1} \wedge \dots \wedge \theta^{i_k}, \, \theta^{j_1} \wedge \dots \wedge \theta^{j_k} \rangle = \begin{cases} 1 & \text{falls } (i_1, \dots, i_k) = (j_1, \dots, j_k) \\ 0 & \text{sonst} \end{cases}$$
#
# 4. Das Bindeglied: Der Hodge-Stern-Operator ($\star$)
# Sobald eine Metrik $g$ und eine Orientierung (Volumenform $\text{vol}_g$) auf dem Raum existieren, ermöglicht die Metrik die Definition des Hodge-Stern-Operators. Dieser bildet eine $k$-Form auf eine duale $(n-k)$-Form ab.
# Die Metrik verbindet das äußere Produkt und den Hodge-Stern über die fundamentale Gleichung:
# $$\alpha \wedge \star \beta = \langle \alpha, \beta \rangle \, \text{vol}_g$$
# Das äußere Produkt zweier Formen liefert also unter Zuhilfenahme des Hodge-Sterns genau das metrische Skalarprodukt multipliziert mit dem Volumenelement des Raumes.

# %% [markdown]
# ###### <font color="blue">*Clifford & Geometrische Algebra*

# %% [markdown]
# <font color="blue">**Geometrische (Clifford) Algebra**
#
# > **Geometrische Algebra = Metrik (symmetric bilinearform) + Exterior Product (antisymmetric bilinearform, bivector, differential forms)**
#
# Die geometrische (Clifford-)Algebra kommt ins Spiel, indem sie das äußere Produkt und die Metrik in einem einzigen, mächtigeren Produkt vereinigt: dem **geometrischen Produkt**. Kurz gesagt:
# * Die äußere Algebra (Differentialformen) liefert die topologische und kombinatorische Struktur (Volumina, Schnitte, Ableitungen).
# * Die Clifford-Algebra fügt dieser Struktur metrische Eigenschaften (Längen, Winkel, Spiegelungen) direkt auf Algebra-Ebene hinzu, ohne dass man ein separates Skalarprodukt mitschleppen muss.
#
# Hier ist das genaue Verhältnis und die Konstruktion im Detail.
#
# 1. Das geometrische Produkt: Die Synthese
#
# In der äußeren Algebra haben Sie das äußere Produkt $\wedge$ (das Formen aufspannt). Um Längen oder Winkel zu berechnen, mussten wir im vorherigen Schritt mühsam eine Metrik $g(v,w)$ als separate Struktur einführen.
# Die Clifford-Algebra $Cl(V, g)$ definiert ein neues, fundamentaleres Produkt – das geometrische Produkt (oft einfach durch Nebeneinanderschreiben $vw$ ausgedrückt). Für zwei Vektoren $v, w$ ist es definiert als:
# $$vw = g(v,w) + v \wedge w$$
# Das geometrische Produkt ist die Summe aus einem Skalar (Metrik) und einem Bivektor (äußeres Produkt).
#
# 2. Symmetrie vs. Antisymmetrie im geometrischen Produkt
#
# Aus dieser Definition können Sie die beiden bekannten Produkte direkt isolieren, indem Sie das Produkt symmetrisieren oder antisymmetrisieren:
#
# * Das metrische Skalarprodukt ist der symmetrische Teil:
# $$g(v,w) = \frac{1}{2}(vw + wv)$$
# * Das äußere Produkt ist der antisymmetrische Teil:
# $$v \wedge w = \frac{1}{2}(vw - wv)$$
#
# Wenn Sie einen Vektor mit sich selbst multiplizieren, kollabiert das äußere Produkt ($v \wedge v = 0$), und es bleibt nur die Metrik übrig: $v^2 = g(v,v) = \Vert{}v\Vert{}^2$. Das ist das definierende Merkmal der Clifford-Algebra.
#
# 3. Vektorraum-Isomorphie: Sie teilen sich denselben Raum
#
# Als Vektorräume (ohne Berücksichtigung des Produkts) sind die äußere Algebra $\Lambda(V)$ und die Clifford-Algebra $Cl(V,g)$ isomorph.
#
# * Beide Räume haben für einen $n$-dimensionalen Vektorraum exakt dieselbe Dimension $2^n$.
# * Beide Räume sind in Grade unterteilt (Skalare, Vektoren, Bivektoren/$2$-Formen, ..., Multivektoren/$n$-Formen).
#
# Der entscheidende Unterschied liegt in der Multiplikationsstruktur:
#
# * In $\Lambda(V)$ verändert das Produkt $\wedge$ immer den Grad (es macht aus einer $1$-Form und einer $1$-Form eine $2$-Form).
# * In $Cl(V,g)$ mischt das geometrische Produkt die Grade. Das Produkt zweier Vektoren hat einen Grad-0-Anteil (Skalar) und einen Grad-2-Anteil (Bivektor).
#
# 4. Das Verhältnis zu Differentialformen
#
# Differentialformen sind Schnitte im äußeren Bündel $\Lambda^*(T^*M)$ eines Raumes. Man kann sie jedoch eins-zu-eins als Elemente der Clifford-Algebra auffassen (oft als Clifford-Formen bezeichnet).
# Durch diesen Wechsel gewinnt man enorme Vorteile bei geometrischen Operationen:
#
# | Operation | In der Welt der Differentialformen ($\Lambda$) | In der Welt der Clifford-Algebra ($Cl$) |
# |---|---|---|
# | Dualität | Benötigt den separaten Hodge-Stern $\star \omega$ | Geschieht durch Multiplikation mit dem Pseudoskalar $I$ ($\omega \cdot I$) |
# | Metrik | Benötigt ein separates Skalarprodukt $\langle \alpha, \beta \rangle$ | Ist im Produkt selbst eingebaut ($\alpha \cdot \beta$) |
# | Spiegelung | Komplizierte koordinatenbasierte Transformation | Einfache "Sandwich"-Formel: $v' = -u v u^{-1}$ |
# | Rotation | Über Matrizen oder Lie-Algebren | Über Rotoren $R$: $v' = R v R^{-1}$ (Verallgemeinerung von Quaternionen) |
#
# 5. Dirac-Operator statt Cartan-Ableitung
#
# In der Analysis auf Mannigfaltigkeiten manifestiert sich das Verhältnis am deutlichsten in den Differentialoperatoren.
# Bei Differentialformen haben Sie die äußere Ableitung $d$ (Grad +1) und deren Adjungierte $\delta$ (Grad -1). In der Clifford-Algebra verschmelzen diese beiden zum Dirac-Operator (oft auch Vektor-Ableitung $\nabla$ genannt):
# $$\nabla = d + \delta$$
# Quadriert man diesen Clifford-Operator, erhält man direkt den Laplace-Beltrami-Operator ($\nabla^2 = \Delta$), was in der Physik (z.B. bei den Maxwell-Gleichungen oder der Dirac-Gleichung für Elektronen) eine massive Notationseinsparung bedeutet.
#
# 6. Zusammenfassung
#
# Die äußere Algebra ist ein Spezialfall der Clifford-Algebra für den Fall, dass die Metrik null ist ($g=0$). Sobald Ihr Raum eine echte Geometrie (Metrik) besitzt, liefert die Clifford-Algebra das vollständige Bild, indem sie die topologische Struktur der Differentialformen ($\wedge$) und die metrische Struktur des Raumes ($g$) unzertrennlich miteinander verschweißt.
#
#
# 0. Was sie Geometric (Clifford) Algebra & woher sie kommt
#
# * Die Geometrische Algebra (GA) $\mathcal G(V,Q)$ **ist** die Clifford-Algebra — gleiche Struktur, nur mit Betonung auf Multivektoren und dem geometrischen Produkt. Sie ist der **orthogonale Ast** aus deinem Abschnitt *Quantenalgebren und -gruppen*: derselbe Quotient der Tensoralgebra,
#
# $$\mathcal G(V,Q)=\mathrm{Cl}(V,Q)=T(V)\big/\bigl\langle\,v\otimes v-Q(v)\mathbf 1\,\bigr\rangle,$$
#
# * erzwingt also die Regel „**Vektor zum Quadrat $=$ Länge zum Quadrat**", $a^2=Q(a)=|a|^2$. Die ganze Pointe der GA ist, dass sie das *symmetrische* (Länge, aus $Q$) und das *antisymmetrische* (Fläche, der Wedge aus dem Abschnitt *Tensor Algebra*) Produkt in **eine** assoziative, invertierbare Multiplikation zusammenfasst.
#
# 1. Das geometrische Produkt (das Herzstück)
#
# * Für zwei Vektoren $a,b$: $\quad$ $ab=a\cdot b+a\wedge$
#
# * Es zerfällt in einen *symmetrischen Skalar* und einen *antisymmetrischen Bivektor*:
#
# $$a\cdot b=\tfrac12(ab+ba)\ \ (\text{Skalar: Länge/Winkel}),\qquad a\wedge b=\tfrac12(ab-ba)\ \ (\text{Bivektor: orientierte Fläche}).$$
#
# * Spezialfälle, die alles erklären: stehen $a,b$ **parallel**, ist $a\wedge b=0$ und $ab=a\cdot b$ (reine Zahl); stehen sie **senkrecht**, ist $a\cdot b=0$ und $ab=a\wedge b$ — dann *antikommutieren* sie: $ab=-ba$. Das ist exakt die CAR-Relation aus der Bridge.
#
# 2. Grade & Multivektoren
#
# * Aus $V$ ($\dim=n$) entsteht eine $2^n$-dimensionale Algebra, gestaffelt nach **Grad** (Anzahl „verkeilter" Richtungen):
#
# $$\mathcal G=\underbrace{\Lambda^0}_{\text{Skalar}}\!\oplus\underbrace{\Lambda^1}_{\text{Vektor}}\!\oplus\underbrace{\Lambda^2}_{\text{Bivektor}}\!\oplus\cdots\oplus\underbrace{\Lambda^n}_{\text{Pseudoskalar}},\qquad \dim\Lambda^k=\binom nk.$$
#
# * Ein allgemeines Element (Multivektor) ist eine Summe verschiedener Grade; $\langle A\rangle_k$ projiziert auf den Grad-$k$-Anteil. Ein **Blade** ist ein reines Produkt orthogonaler Vektoren (ein „reiner" Grad-$k$-Block, geometrisch ein orientiertes $k$-Volumen).
#
# 3. Pseudoskalar & Dualität
#
# * Das höchste Element $I=e_1e_2\cdots e_n$ heißt **Pseudoskalar**; es kodiert Orientierung und Volumen. Im 3D-Raum:
#
# $$I=e_1e_2e_3,\qquad I^2=-1,\qquad a\wedge b=I\,(a\times b)\ \Leftrightarrow\ a\times b=-I\,(a\wedge b).$$
#
# * Das erklärt das alte Kreuzprodukt: $a\times b$ ist nur der **Dual** des Bivektors $a\wedge b$ — der Normalenvektor zur aufgespannten Ebene. (Deshalb funktioniert das Kreuzprodukt *nur* in 3D, der Wedge dagegen in jeder Dimension.) Allgemein dualisiert $A^\ast=AI^{-1}$ einen $k$-Blade zu einem $(n-k)$-Blade.
#
# 4. Rotoren & Spiegelungen (die Krone)
#
# * Hier zahlt die GA ihren Hauptnutzen. Eine **Spiegelung** an der Hyperebene senkrecht zum Einheitsvektor $\hat n$ ist
#
# $$v\ \mapsto\ -\,\hat n\,v\,\hat n .$$
#
# * Zwei Spiegelungen ergeben eine **Drehung** (Cartan–Dieudonné). Das Produkt zweier Einheitsvektoren ist ein **Rotor**:
#
# $$\;R=e^{-B\theta/2},\quad B^2=-1\ (\text{Einheits-Bivektor der Drehebene}),\qquad v'=R\,v\,\tilde R,\quad \tilde R R=1\;$$
#
# * $R$ dreht $v$ um den Winkel $\theta$ in der Ebene $B$. Hier ist $\tilde R$ das **Reverse** (Reihenfolge der Vektoren umkehren). Rotoren *multiplizieren* sich (Drehungen verketten sich), und bilden die Gruppe $\mathrm{Spin}(n)$, die **Doppelüberlagerung** von $SO(n)$ (→ *Lie Algebra*; physikalisch realisiert in deinem Abschnitt *Free Fermions*, wo Bivektor $=$ Hamiltonian und Rotor $=SO(2n)$).
#
# 5. Reverse & gerade Unteralgebra
#
# * Das Reverse wirkt auf Grad $k$ mit Vorzeichen $\tilde A_k=(-1)^{k(k-1)/2}A_k$ (Skalar $+$, Vektor $+$, Bivektor $-$, …). Die **gerade Unteralgebra** $\mathcal G^+$ (nur gerade Grade) enthält genau die Rotoren — und ist in kleinen Dimensionen vertraut:
#
# $$\mathcal G_2^+\cong\mathbb C\quad(\text{komplexe Zahlen}),\qquad \mathcal G_3^+\cong\mathbb H\quad(\text{Quaternionen}).$$
#
# * So entpuppen sich „$i$" und die Quaternionen als **Bivektoren** — Drehungen, keine mysteriösen Zahlen.
#
# 6. Konkret: die Ebene und der Raum
#
# * **Rechenbeispiel — $\mathcal G_2$ (Ebene).** Basis $\{1,\ e_1,e_2,\ e_1e_2\}$. Der Bivektor $i:=e_1e_2$ erfüllt $i^2=e_1e_2e_1e_2=-e_1e_1e_2e_2=-1$. Also ist $\mathcal G_2^+=\{x+yi\}\cong\mathbb C$, und der Rotor $R=e^{-i\theta/2}$ dreht um $\theta$. Die „komplexe Ebene" *ist* die gerade Unteralgebra der Ebene.
#
# * **Rechenbeispiel — $\mathcal G_3$ (Raum) $=$ Pauli-Algebra.** Basis: $1$; $e_1,e_2,e_3$; drei Bivektoren $e_1e_2,e_2e_3,e_3e_1$; Pseudoskalar $I=e_1e_2e_3$ ($2^3=8$ Dim). Setzt man $e_i\leftrightarrow\sigma_i$, so reproduziert das geometrische Produkt die Pauli-Relation $\sigma_i\sigma_j+\sigma_j\sigma_i=2\delta_{ij}$, und der Bivektor $e_1e_2\leftrightarrow i\sigma_3$. Der Rotor um die $3$-Achse ist $R=e^{-e_1e_2\,\theta/2}\leftrightarrow e^{-i\sigma_3\theta/2}$ — **exakt die Qubit-$Z$-Rotation** (vgl. *Free Fermions*, Rechenbeispiel). Damit ist $\mathcal G_3^+\cong\mathbb H$ und $\mathrm{Spin}(3)\cong SU(2)$ der Ursprung des **Qubits als Rotor**.
#
# <font color="blue">*Quick Reference — Geometrische Algebra auf einen Blick*
#
# * $\mathcal G(V,Q)=\mathrm{Cl}(V,Q)$ — GA $=$ Clifford-Algebra; Quotient von $T(V)$ mit $a^2=Q(a)$; $\dim=2^n$.
# * **Geometrisches Produkt** $ab=a\cdot b+a\wedge b$ — Skalar (symmetrisch) $+$ Bivektor (antisymmetrisch).
# * $a\cdot b=\tfrac12(ab+ba)$ — inneres Produkt, *senkt* den Grad (Länge/Winkel).
# * $a\wedge b=\tfrac12(ab-ba)$ — äußeres Produkt, *hebt* den Grad (orientierte Fläche).
# * $\langle A\rangle_k$ — Grad-Projektion; Skalar/Vektor/Bivektor/…/Pseudoskalar.
# * $I=e_1\cdots e_n$ — Pseudoskalar; Dualität $A^\ast=AI^{-1}$; 3D: $a\times b=-I(a\wedge b)$.
# * $R=e^{-B\theta/2}$, $v'=R v\tilde R$ — Rotor; Drehung in Ebene $B$; $\mathrm{Spin}(n)\to SO(n)$ ($2{:}1$).
# * $v\mapsto-\hat n v\hat n$ — Spiegelung; zwei davon $=$ eine Drehung.
# * $\tilde A$ — Reverse, $(-1)^{k(k-1)/2}$ auf Grad $k$; $\mathcal G^+$ — gerade Unteralgebra (Rotoren).
# * $\mathcal G_2^+\cong\mathbb C$, $\mathcal G_3^+\cong\mathbb H$, $e_i\leftrightarrow\sigma_i$ — komplexe Zahlen & Quaternionen sind Bivektoren.
#
# **Drei Merksätze.**
# 1. Das **geometrische Produkt** vereint Länge (symmetrisch) und Fläche (antisymmetrisch) in *einer* invertierbaren Multiplikation — das ist der ganze Trick.
# 2. **Orientierte Fläche** wird hier als eigenständiges Objekt (Bivektor) *gespeichert* — im Gegensatz zur symplektischen Form (HW-Strang), die sie nur zu einer Zahl *misst*.
# 3. **Rotoren** ($\mathcal G^+$) machen Drehungen zu Multiplikation; $\mathbb C$, $\mathbb H$ und das Qubit-als-Rotor sind alle Spezialfälle.

# %% [markdown]
# <font color="blue">**Geometric Algebra in Quantum Computing (Kurzhinweise)**
#
# * **Ein-Qubit-Rotoren (implizit, überall).** $\mathrm{Spin}(3)\cong SU(2)$: jede Bloch-Drehung *ist* ein GA-Rotor $R=e^{-B\theta/2}$. Präsent als Struktur, aber in der QC-Notation untergegangen — man nutzt es ständig, nennt es nur nicht so.
#
# * **Free Fermions / Matchgates (der echte Heimathafen).** Hier rechnen Wedge/Bivektor/Rotor *wörtlich*: Fock-Raum $=\Lambda(\mathbb C^n)$, Gaußscher Hamiltonian $=$ Bivektor, Zeitentwicklung $=$ Rotor mit $\mathrm{Spin}(2n)\to SO(2n)$ (→ Sektion *Free Fermions*). Eigenes aktives Feld (Quantensimulation, Quantenchemie), aber beim *Algorithmen*-Schreiben selten sichtbar.
#
# * **Abgrenzung — wo GA *nicht* hingehört.** Der Stabilisator-/Clifford-Formalismus (Qubits, Qudits, Magic States, Gottesman–Knill) ist **symplektisch (HW)**, nicht orthogonal — dort keine GA-Sprache verwenden. **Merksatz:** HW ist die Grundlage aller QC-Algorithmen; GA ist die Geometrie hinter Einzel-Qubit-Drehungen und der Rahmen für Free Fermions.
#
#
# <font color="blue">*Benutzt man in general relativity die tensor algebra, oder deren quotinet (regel aufgezwungen!) clifford algebra*
#
#
# Die kurze Antwort lautet: **Standardmäßig nutzt man die klassische Tensoralgebra**, aber sobald man bestimmte physikalische Probleme betrachtet oder modernere Formulierungen wählt, wird die **Clifford-Algebra** unverzichtbar.
#
# Deine Formulierung ist mathematisch absolut präzise: Die Clifford-Algebra $\mathcal{C}\ell(V, g)$ ist exakt der Quotient der Tensoralgebra $T(V)$ nach dem beidseitigen Ideal, das durch die "aufgezwungene Regel" generiert wird:
#
#
# $$v \otimes v - g(v,v)\mathbf{1} = 0$$
#
# Hier ist die genaue Aufteilung, wie und wo beide Konzepte in der Allgemeinen Relativitätstheorie (ART) verwendet werden:
#
# 1. Der historische Standard: Tensoralgebra
#
# Wenn du ein Standardlehrbuch zur ART aufschlägst, wirst du fast ausschließlich die reine **Tensoralgebra** und Tensoranalysis (auf Basis der Differentialgeometrie) finden.
#
# * **Der Grund:** Einstein und Hilbert haben die Theorie in genau dieser mathematischen Sprache formuliert, aufbauend auf der riemannschen Geometrie.
# * **Die Praxis:** Alle zentralen Größen sind Tensoren auf dem Tangentialbündel der Mannigfaltigkeit: Der metrische Tensor $g_{\mu\nu}$, der Riemannsche Krümmungstensor $R^{\rho}_{\sigma\mu\nu}$ und der Energie-Impuls-Tensor $T_{\mu\nu}$. Die Metrik $g$ wird der Theorie hinzugefügt, aber die zugrundeliegenden Tensorprodukte $V \otimes V$ bleiben in ihrer Struktur unbeschränkt (kein Quotient).
#
# 2. Die Erweiterung: Warum man Clifford-Algebren in der ART braucht
#
# Die reine Tensoralgebra hat ein entscheidendes physikalisches Defizit: Sie kann fundamentale Materie mit halbzahligem Spin (Fermionen wie Elektronen oder Quarks) nicht beschreiben.
# Sobald man Fermionen in eine gekrümmte Raumzeit einbetten will, versagt der klassische Tensor-Formalismus.
#
# * **Spin-Strukturen:** Um die Dirac-Gleichung in der ART zu formulieren, *muss* man Spinoren verwenden. Diese Spinoren sind Darstellungsräume von **Clifford-Algebren**. Man führt lokale Bezugssysteme (Vierbeine / Tetraden) ein und konstruiert den sogenannten Spin-Zusammenhang (Spin Connection).
# * **Die Bedeutung der "Regel":** Hier greift genau deine aufgezwungene Regel $v \otimes v = g(v,v)\mathbf{1}$. Sie zwingt der reinen Algebra die Struktur der Raumzeit-Metrik auf. Da die Metrik in der ART das Gravitationsfeld ist, koppelt die Clifford-Algebra die Geometrie der Raumzeit direkt und untrennbar an die algebraischen Eigenschaften des Spins.
#
# 3. Der radikale Ansatz: Spacetime Algebra (Geometric Algebra)
#
# Es gibt eine elegante, alternative Formulierung der gesamten ART, die die klassische Tensorrechnung komplett durch die Clifford-Algebra ersetzt. In diesem Kontext spricht man meist von **Geometric Algebra**.
#
# * Hierbei formuliert man die Physik in der **Spacetime Algebra (STA)**, der Clifford-Algebra des Minkowski-Raums $\mathcal{C}\ell_{1,3}(\mathbb{R})$.
# * In der **Gauge Theory Gravity (GTG)** (stark vorangetrieben von Forschern in Cambridge wie Lasenby und Doran) wird die Krümmung nicht durch abstrakte Tensoren auf einer gekrümmten Mannigfaltigkeit beschrieben. Stattdessen operiert man mit dem geometrischen Produkt (das das Skalar- und das Dachprodukt vereint).
# * Das Ergebnis: Diese Formulierung ist experimentell und theoretisch zu 100 % äquivalent zur klassischen Einstein-Cartan-Theorie, macht aber Rechnungen oft wesentlich kompakter. Die Symmetrien (Lie-Gruppen der Rotationen und Boosts) lassen sich durch die exponentielle Abbildung von Bivektoren innerhalb der Clifford-Algebra extrem natürlich beschreiben.
#
#
# <font color="blue">**Heisenberg-Weyl vs Clifford Algebra in Quantum**
#
# > Regarding use cases of geometric algebra and clifford algebra, i‘m reading : „Quantum Mechanics: Unifies the Pauli and Dirac matrices and provides the most natural mathematical framework to represent spinors (the mathematical properties of particles with half-integer spin, like electrons).“ Bit isnt QM formulated in heisenberg-weyl algebra, die other quotient of tensor algebra, and not geometric / ckifford algebra?
#
# You have hit on a profound and beautiful mathematical duality in quantum physics. You are entirely correct that the Heisenberg-Weyl algebra is fundamental to Quantum Mechanics (QM), but the text you are reading is also correct.
#
# They are not mutually exclusive. Instead, they are the two fundamental algebraic structures needed to describe two completely different physical properties. Both are indeed constructed as quotients of the tensor algebra $T(V)$, but they use different ideals to describe different geometries and particle statistics.
#
# Here is how they divide the labor in quantum theory.
#
# 1. The Heisenberg-Weyl Algebra (Position, Momentum, and Bosons)
#
# The Weyl algebra handles the **kinematics** of the quantum system—where things are and how they move through space.
#
# * **The Math:** It is defined as the quotient of the tensor algebra $T(V)$ by the ideal generated by:
#
# $$v \otimes w - w \otimes v - \omega(v,w)$$
#
#
#
# where $\omega$ is an anti-symmetric (symplectic) bilinear form.
# * **The Physics:** This mathematical structure yields the **Canonical Commutation Relations (CCR)**. It gives us the familiar rules for continuous observables like position $\hat{x}$ and momentum $\hat{p}$, where $[\hat{x}, \hat{p}] = i\hbar$.
# * **The Application:** It is used to formulate the continuous phase space of a system, infinite-dimensional Hilbert spaces, the quantum harmonic oscillator, and the creation/annihilation operators for **bosons** (particles that can share the same quantum state, like photons).
#
# 2. Geometric / Clifford Algebra (Spin, Spinors, and Fermions)
#
# The Clifford algebra handles the **intrinsic internal structure** of the particles themselves.
#
# * **The Math:** It is defined as the quotient of the tensor algebra $T(V)$ by the ideal generated by:
#
# $$v \otimes v - Q(v)$$
#
#
#
# where $Q$ is a symmetric bilinear form (a quadratic form, like the metric of spacetime).
# * **The Physics:** This structure yields the **Canonical Anti-Commutation Relations (CAR)**. Instead of commutators, it relies on anti-commutators $\{A, B\} = AB + BA$.
# * **The Application:** Because of the Pauli Exclusion Principle, **fermions** (particles with half-integer spin, like electrons) cannot share the same quantum state. Mathematically, this means their operators must anti-commute. Clifford algebra provides the natural geometric space for this. The Pauli matrices (for 3D space) and Dirac matrices (for 4D spacetime) are literally just the basis vectors of specific Clifford algebras ($Cl_{3,0}$ and $Cl_{1,3}$ respectively).
#
# The "Quantization" Duality
#
# Your intuition about them being "the other quotient" is spot on. They are parallel "quantizations" of classical geometries:
#
# 1. If you take the Weyl algebra and set $\hbar \to 0$, it reduces to the **Symmetric Algebra** (classical phase space).
# 2. If you take the Clifford algebra and set the metric $Q \to 0$, it reduces to the **Exterior (Grassmann) Algebra** (classical differential forms / volume elements).
#
# Summary Comparison
#
# | Feature | Heisenberg-Weyl Algebra | Geometric / Clifford Algebra |
# | --- | --- | --- |
# | **Quotient Ideal** | $v \otimes w - w \otimes v - \omega(v,w)$ | $v \otimes v - Q(v)$ |
# | **Underlying Geometry** | Symplectic (Anti-symmetric form) | Metric (Symmetric quadratic form) |
# | **Quantum Relation** | Commutators $[A, B]$ | Anti-commutators $\{A, B\}$ |
# | **Physical Role** | Phase space (Position & Momentum) | Intrinsic angular momentum (Spin) |
# | **Particle Type** | Bosons (Integer spin) | Fermions (Half-integer spin) |
# | **Key Matrices/Operators** | $\hat{x}, \hat{p}$, Creation/Annihilation ($a, a^\dagger$) | Pauli matrices ($\sigma_i$), Dirac matrices ($\gamma^\mu$) |
#
# In short, standard introductory Quantum Mechanics mostly focuses on the Heisenberg-Weyl algebra because it deals with the Schrödinger equation and wavefunctions in space. However, the moment you need to describe the electron's spin (Pauli equation) or make QM compatible with special relativity (Dirac equation), you must introduce Clifford algebra to build the spinors. Modern Quantum Field Theory requires both.

# %% [markdown]
# ###### <font color="blue">*Heisenberg-Lie Algebra*

# %% [markdown]
# <font color="blue">**Ist Heisenberg-Lie-Algebra die Lie algebra oder eine lie algebra?**
#
# 1. Die Heisenberg-Lie-Algebra ist **eine** Lie-Algebra.
#
# * Es gibt in der Mathematik unendlich viele verschiedene Lie-Algebren (wie beispielsweise die Lie-Algebra der dreidimensionalen Rotationen, $\mathfrak{so}(3)$). Die Heisenberg-Lie-Algebra ist lediglich ein ganz spezielles, berühmtes Mitglied aus dieser riesigen Struktur-Familie.
#
# * Man nennt sie deshalb oft **die** Heisenberg-Lie-Algebra, weil sie eine eindeutig definierte, spezifische algebraische Struktur ist, die vor allem in der Quantenmechanik eine zentrale Rolle spielt.
#
# 2. Wie sie funktioniert
#
# * Eine Lie-Algebra ist grundlegend ein Vektorraum, auf dem eine Verknüpfung definiert ist: die sogenannte Lie-Klammer (oft als Kommutator geschrieben), die bestimmte Regeln wie die Jacobi-Identität erfüllt.
#
# * Die Heisenberg-Lie-Algebra (meist mit $\mathfrak{h}_n$ bezeichnet) wird von Elementen aufgespannt, die den physikalischen Observablen von Ort und Impuls entsprechen. Für $n$ Freiheitsgrade hat sie die Basis-Elemente $Q_i$ (Ort), $P_i$ (Impuls) und ein zentrales Element $Z$.
#
# * Ihre Struktur ist durch folgende Kommutatorrelationen (die Lie-Klammern) exakt definiert:
#
# $$[Q_i, P_j] = \delta_{ij} Z$$
#
# $$[Q_i, Q_j] = 0$$
#
# $$[P_i, P_j] = 0$$
#
# $$[Q_i, Z] = [P_i, Z] = 0$$
#
# * Das ist exakt die mathematische Abstraktion der kanonischen Vertauschungsrelationen aus der Physik, wobei das zentrale Element $Z$ meist für $i\hbar$ steht.
#
# 3. Der Weg zur Weyl-Algebra
#
# * Wenn du aus dieser abstrakten Lie-Algebra (in der es erst einmal nur Vektoraddition und die Lie-Klammer gibt) eine Struktur machst, in der du die Elemente auch wie Polynome miteinander multiplizieren kannst, konstruierst du die sogenannte *universelle einhüllende Algebra*.
#
# * **Genau dieser Schritt führt von der Heisenberg-Lie-Algebra direkt zur Heisenberg-Weyl-Algebra, welche das fundamentale algebraische Werkzeug für quantenmechanische Operatoren darstellt.**

# %% [markdown]
# <font color="blue">**Background: Weyl Algebra vs Heisenberg-Weyl Algebra**
#
# > Die symmetrische Algebra $\mathrm{Sym}(V)$ (Polynome, klassischer Phasenraum) ist der Spezialfall der Weyl-Algebra mit $\omega = 0$
#
# *Mathematiker reden öfter von weyl algebra reden, aber physiker (vor allem in quanteninformatik) von heisenberg-weyl algebra. Gibt es da einen unterschied, oder ist es das gleiche?*
#
# Beides — mit einer Feinheit, die genau an deiner diskreten Sektion beißt.
#
# **Was ich meinte:** das allgemeine $W(V,\omega) = T(V)/\langle v\otimes w - w\otimes v - \omega(v,w)\rangle$, also exakt das Objekt, das deine eigenen Notizen „Weyl-Algebra (symplektische Clifford-Algebra)" nennen. Für $V=\mathbb{R}^{2n}$ mit der Standardform ist das deine kontinuierliche HW-Algebra. Insofern: dasselbe, nur einmal koordinatenfrei-allgemein und einmal als konkreter Fall.
#
# **Warum die Namen auseinanderlaufen:** Es sind streng genommen drei Objekte, die in der Physik gern zusammengeworfen werden – und deine Notizen sagen die Beziehung im Abschnitt A bereits korrekt („universelle Einhüllende der Heisenberg-Lie-Algebra … modulo $z=1$"):
#
# | Objekt | Was es ist | Wer sagt so |
# |---|---|---|
# | Heisenberg-Lie-Algebra $\mathfrak{h}_n$ | Lie-Algebra, $\dim = 2n{+}1$, $[q,p]=z$ zentral | Mathematiker |
# | Weyl-Algebra $A_n$ | assoziativ, unendlichdim.: alle Polynome in $\hat q,\hat p$ = polynomiale Differentialoperatoren; $A_n = U(\mathfrak h_n)/(z-1)$ | Mathematiker |
# | „Heisenberg-Weyl-Algebra" | meist beides gleichzeitig gemeint, je nach Kontext | Physiker |
#
# Die Namenswahl hat einen historischen Grund: „Weyl-Algebra" ehrt Weyls *exponenzierte* Fassung der CCR (die Weyl-Relationen mit unitären Operatoren, Stone–von Neumann), obwohl $A_n$ selbst die unexponenzierte polynomiale Version ist. Daher auch noch ein vierter Namensträger: die Weyl-**C\***-Algebra (CCR-Algebra) in der Operatoralgebra – wieder etwas anderes.
#
# **Wo der Unterschied wirklich wichtig wird:** bei deinen Qudits. Der Mathematiker-Weyl-Algebra $A_n$ hat in Charakteristik 0 **keine** endlichdimensionalen Darstellungen – aus $[\hat q,\hat p]=1$ folgt beim Spurbilden sofort $0 = \dim$, Widerspruch. Deine Clock/Shift-Operatoren sind aber $d\times d$-Matrizen. Also ist die diskrete HW-Welt *nicht* die Weyl-Algebra, sondern deren exponenzierte, endliche Verwandte: eine endliche Gruppe (zentrale Erweiterung), deren getwistete Gruppenalgebra bei primitivem $\omega$ isomorph zu $M_d(\mathbb{C})$ ist – die vollen Matrizen. Genau deshalb funktioniert $ZX=\omega XZ$ endlichdimensional, während $[\hat q,\hat p]=i\hbar$ das nicht kann.
#
# Praktisch heißt das für deine Landkarte: „Heisenberg-Weyl" ist bei dir ein Dachbegriff über zwei formal verschiedene Objekte – die unendlichdimensionale Weyl-Algebra (CV-Seite) und die endliche HW-Gruppe (Qudit-Seite) –, verbunden durch Exponenzierung und den Limes $d\to\infty$, den du schon notiert hast.

# %% [markdown]
# <font color="blue">**Wie lässt sich die Heisenberg-Lie-Algebra im Kontext von Differentialformen und symplektischer Geometrie formulieren?**
#
# Der eleganteste Weg, die Heisenberg-Lie-Algebra geometrisch zu fassen, führt über den klassischen Phasenraum. In der Sprache der Differentialgeometrie ist die Heisenberg-Lie-Algebra das direkte Resultat der symplektischen Struktur, wenn man sie auf die einfachsten Observablen reduziert.
#
# Hier ist die schrittweise Konstruktion, wie diese abstrakten mathematischen Konzepte ineinandergreifen:
#
# 1. Der Phasenraum und die symplektische 2-Form
#
# Wir starten mit einem Phasenraum, der mathematisch ein $2n$-dimensionaler Vektorraum $V = \mathbb{R}^{2n}$ (oder allgemeiner ein Kotangentialbündel) ist. Er hat die Koordinaten $(q_1, \dots, q_n, p_1, \dots, p_n)$ für Ort und Impuls.
#
# Die grundlegende Struktur auf diesem Raum ist die symplektische Form $\omega$. Sie ist eine geschlossene, nicht-ausgeartete Differentialform vom Grad 2 (eine 2-Form):
#
# $$\omega = \sum_{i=1}^n dp_i \wedge dq_i$$
#
# Da sie geschlossen ist, gilt $d\omega = 0$. Sie weist jeder Fläche im Phasenraum eine orientierte "Fläche" (Wirkung) zu.
#
# 2. Vom Differential zum Vektorfeld
#
# Um eine Algebra zu bauen, brauchen wir eine Verknüpfung. In der symplektischen Geometrie wird jeder glatten Funktion $f$ (einer klassischen Observablen) ein sogenanntes Hamiltonsches Vektorfeld $X_f$ zugeordnet.
#
# Diese Zuordnung passiert über das äußere Differential $df$ und die Kontraktion (das innere Produkt $\iota$) mit der symplektischen Form:
#
# $$df = \iota_{X_f} \omega = \omega(X_f, \cdot)$$
#
# 3. Die Poisson-Klammer als Lie-Klammer
#
# Mit diesen Vektorfeldern können wir nun die Verknüpfung zwischen zwei Funktionen $f$ und $g$ definieren. Die symplektische Form liefert uns direkt die Poisson-Klammer:
#
# $$\{f, g\} = \omega(X_f, X_g) = X_f(g)$$
#
# Die Menge aller glatten Funktionen auf dem Phasenraum bildet zusammen mit der Poisson-Klammer (die alle Eigenschaften einer Lie-Klammer wie Antisymmetrie und Jacobi-Identität erfüllt) eine unendlichdimensionale Lie-Algebra.
#
# 4. Die Heisenberg-Lie-Algebra als Unteralgebra
#
# Um zur Heisenberg-Lie-Algebra zu gelangen, betrachten wir nicht *alle* Funktionen, sondern beschränken uns auf einen sehr spezifischen, endlichdimensionalen Unterraum.
#
# Wir nehmen nur lineare Kombinationen der Koordinaten $q_i, p_i$ und fügen die konstante Funktion $1$ hinzu. Unser Vektorraum wird also aufgespannt durch:
#
#
# $$\text{span}(q_1, \dots, q_n, p_1, \dots, p_n, 1)$$
#
# Berechnen wir nun die Poisson-Klammern (unsere Lie-Klammer) für diese speziellen Basis-Funktionen, erhalten wir:
#
# $$\{q_i, p_j\} = \delta_{ij} \cdot 1$$
#
# $$\{q_i, q_j\} = 0$$
#
# $$\{p_i, p_j\} = 0$$
#
# $$\{1, q_i\} = \{1, p_i\} = 0$$
#
# Dieser $(2n+1)$-dimensionale Unterraum formt exakt die **Heisenberg-Lie-Algebra $\mathfrak{h}_n$**. Die konstante Funktion $1$ übernimmt die Rolle des zentralen Elements $Z$, das mit allem kommutiert.
#
# ---
#
# > **Der kohomologische Blickwinkel**
# > Man kann die Heisenberg-Lie-Algebra auch als eine *zentrale Erweiterung* der abelschen Lie-Algebra $\mathbb{R}^{2n}$ (der reinen Translationen im Phasenraum) um ein eindimensionales Zentrum $\mathbb{R}$ verstehen. Solche Erweiterungen werden durch die Lie-Algebra-Kohomologie klassifiziert. Der 2-Kozyklus, der diese spezifische zentrale Erweiterung definiert, ist exakt die symplektische Form $\omega$ am Ursprung evaluiert.

# %% [markdown]
# <font color="blue">***Wie kommt man durch 'Geometrische Quantisierung' von dieser symplektischen Geometrie zur quantenmechanischen Weyl-Algebra?**
#
# Lass uns diesen Schritt gehen. Die **Geometrische Quantisierung** (entwickelt von Kostant und Souriau) ist der mathematisch rigorose Versuch, das "Quantisierungs-Kochrezept" der Physik systematisch aus der Differentialgeometrie abzuleiten. Das Ziel ist es, aus klassischen Observablen (Funktionen auf dem Phasenraum) quantenmechanische Observablen (Operatoren auf einem Hilbertraum) zu machen.
#
# Der Weg zur Weyl-Algebra verläuft dabei typischerweise in zwei großen Schritten: der **Präquantisierung** und der **Polarisation**.
#
# 1. Präquantisierung: Der Sprung in die Kohomologie
#
# Wir haben unseren symplektischen Phasenraum $(M, \omega)$ und wollen Funktionen $f \in C^\infty(M)$ linearen Operatoren $\hat{f}$ zuordnen. Diese Operatoren sollen auf einem komplexen Hilbertraum wirken und die Dirac-Bedingung erfüllen:
#
#
# $$[\hat{f}, \hat{g}] = -i\hbar \widehat{\{f, g\}}$$
#
# Hier kommt die Topologie ins Spiel: Wir konstruieren ein komplexes Geradenbündel (Line Bundle) $L \to M$ über dem Phasenraum. Damit das geometrisch konsistent funktioniert, muss die symplektische Form $\omega$ eine ganz bestimmte Bedingung erfüllen, die sogenannte **Weil-Ganzzahligkeitsbedingung**. Ihre Kohomologieklasse muss (bis auf Faktoren) ganzzahlig sein:
#
#
# $$\left[ \frac{\omega}{2\pi\hbar} \right] \in H^2(M, \mathbb{Z})$$
#
# Wenn das erfüllt ist, statten wir dieses Bündel mit einem hermiteschen Skalarprodukt und einem Zusammenhang (einer kovarianten Ableitung) $\nabla$ aus, dessen Krümmungsform exakt proportional zu unserer symplektischen Form $\omega$ ist.
#
# Unser Hilbertraum ist vorerst der Raum der quadratintegrierbaren Schnitte $\Gamma(L)$ in diesem Bündel. Der Präquantisierungs-Operator für eine klassische Observable $f$ ist dann:
#
#
# $$\hat{f} = -i\hbar \nabla_{X_f} + f$$
#
#
# Wobei $X_f$ das Hamiltonsche Vektorfeld von $f$ ist.
#
# Das Problem: Dieser Hilbertraum ist noch "zu groß". Die Wellenfunktionen hängen hier klassisch von Ort *und* Impuls ab, was der Heisenbergschen Unschärferelation widerspricht.
#
# 2. Polarisation: Den Hilbertraum halbieren
#
# Um die überflüssigen Freiheitsgrade loszuwerden, führt man eine **Polarisation** ein. Geometrisch wählt man in jedem Tangentialraum einen Unterraum, der die halbe Dimension des Phasenraums hat (genauer: eine integrierbare Lagrangesche Distribution).
#
# In der Standard-Quantenmechanik wählt man oft die *vertikale Polarisation*. Man fordert, dass die physikalischen Zustände (die Schnitte $\psi$ im Geradenbündel) entlang der Impuls-Richtungen konstant sind:
#
#
# $$\nabla_{\partial / \partial p_i} \psi = 0$$
#
#
# Das zwingt die Wellenfunktionen dazu, nur noch vom Ort $q$ (und nicht mehr von $p$) abzuhängen. Der physikalische Hilbertraum schrumpft auf $L^2(\mathbb{R}^n)$, den Raum der quadratintegrierbaren Funktionen des Ortes.
#
# 3. Die Geburt der Weyl-Algebra
#
# Jetzt wenden wir unsere Präquantisierungs-Operatoren auf diesen "halbierten" Hilbertraum an, aber speziell für unsere elementaren Koordinatenfunktionen des Phasenraums: Ort $q_j$ und Impuls $p_k$.
#
# Dank der Struktur der kovarianten Ableitung $\nabla$ in unserer gewählten Polarisation ergibt sich für die Operatoren:
#
# * **Für den Ort ($f = q_j$):** Das Hamiltonsche Vektorfeld $X_{q_j}$ zeigt in Impulsrichtung. Da unsere Wellenfunktionen in Impulsrichtung kovariant konstant sind, fällt der Ableitungsterm $\nabla_{X_q}$ weg. Es bleibt nur der Multiplikationsterm:
#
# $$\hat{q}_j \psi(q) = q_j \cdot \psi(q)$$
#
#
# * **Für den Impuls ($f = p_k$):** Das Hamiltonsche Vektorfeld $X_{p_k}$ zeigt in negative Ortsrichtung. Der Zusammenhang $\nabla$ liefert hier genau die partielle Ableitung:
#
# $$\hat{p}_k \psi(q) = -i\hbar \frac{\partial}{\partial q_k} \psi(q)$$
#
#
#
# Wenn wir nun diese konkreten Operatoren anschauen, sehen wir, dass sie eine Algebra erzeugen. Multiplizieren (also Nacheinanderausführen) und Addieren dieser Operatoren liefert genau die **Heisenberg-Weyl-Algebra** (bzw. die Weyl-Algebra, wenn man zu den generierten Polynomen in diesen Operatoren übergeht).
#
# Durch diesen geometrischen Prozess haben wir aus dem algebraischen Gebilde der Poisson-Klammern auf der klassischen symplektischen Mannigfaltigkeit die fundamentale nicht-kommutative Algebra der Quantenmechanik konstruiert.

# %% [markdown]
# ###### <font color="blue">*Symmetrische Algebra*

# %% [markdown]
# spezialfall de weyl algebra
#
# weiter oben in Differential Forms steht: Antisymmetrisch unter fundamentalform der weyl algebra?
#
# Die symmetrische Algebra $\mathrm{Sym}(V)$ (Polynome, klassischer Phasenraum) ist der Spezialfall der Weyl-Algebra mit $\omega = 0$.

# %% [markdown]
# ###### <font color="blue">*Kohomologie*

# %% [markdown]
# **Kohomologie: Die Algebra der "Löcher"**
#
# Kohomologie ist ein algebraisches Werkzeug, um die globale Gestalt (Topologie) eines Raumes zu messen. Die mathematische Grundidee beruht auf einem Operator $d$, für den stets $d^2 = 0$ gilt:
#
# * **Geschlossene Objekte (Kozykel):** Objekte $\omega$ mit $d\omega = 0$ (lokal "randlos" oder "flach").
# * **Exakte Objekte (Koränder):** Objekte, die selbst das Ergebnis einer Ableitung sind ($\omega = d\eta$).
# * **Kohomologie-Gruppe:** $H = \text{Geschlossen} / \text{Exakt}$. Sie misst das globale Hindernis: Warum ist ein lokal geschlossenes Objekt nicht global das Ergebnis eines anderen? Die Ursache ist fast immer ein "Loch" oder eine Krümmung im Raum.
#
# ---
#
# **Verbindung zu Differentialformen (de Rham-Kohomologie)**
#
# Differentialformen bilden die Basis der de-Rham-Kohomologie! Die **de Rham-Kohomologie** ist die Anwendung dieses Prinzips auf Differentialformen, wobei $d$ die äußere Ableitung ist. Da $d(d\omega) = 0$ gilt, bilden Differentialformen einen sogenannten Kokettenkomplex.
#
# * *Beispiel:* Auf der punktierten Ebene $\mathbb{R}^2 \setminus \{(0,0)\}$ ist die Winkel-1-Form $\omega = \frac{-y\,dx + x\,dy}{x^2+y^2}$ geschlossen ($d\omega = 0$). Wäre sie exakt ($\omega = d\theta$), müsste das Integral über jeden geschlossenen Kreis Null sein. Das Kreisintegral ergibt jedoch $2\pi$. Die Form "spürt" das Loch im Ursprung.
#
# ---
#
# **Zyklische Kohomologie**
#
# Die de Rham-Kohomologie funktioniert nur auf klassischen, geometrischen Räumen (wo Funktionen kommutieren: $f \cdot g = g \cdot f$). In der **Nichtkommutativen Geometrie** (begründet von Alain Connes) betrachtet man Räume, deren "Funktionen" nicht kommutieren.
#
# Die **Zyklische Kohomologie** ist das exakte nichtkommutative Analogon zur de Rham-Kohomologie. Sie wird auf abstrakten Algebren $A$ definiert, indem man Ketten aus Tensorprodukten $A^{\otimes (n+1)}$ untersucht, die invariant unter zyklischen Permutationen der Elemente sind.
#
# ---
#
# **Verbindung zu Deinen Themen**
#
# * **Exterior Algebra (Äußere Algebra):** Sie ist das algebraische Fundament der de Rham-Kohomologie. Das Dachprodukt ($\wedge$) überträgt sich direkt auf die Kohomologieklassen und macht $H^*(M)$ zu einem graduierten Ring.
# * **Heisenberg-Weyl-Algebra:** Quantenmechanische Operatoren kommutieren nicht ($[x, p] = i\hbar$). Um auf der Heisenberg-Algebra Differentialgeometrie und Index-Theorie zu betreiben, nutzt man die **Zyklische Kohomologie**.
# * **Tensor Algebra:** Zyklische Kohomologie sowie die verwandte Hochschild-Kohomologie sind direkt auf der Tensoralgebra $T(A)$ bzw. auf Tensorpotenzen $A^{\otimes n}$ einer Algebra aufgebaut.
# * **Geometric Algebra (Clifford-Algebren):** Der Dirac-Operator auf Clifford-Algebren verbindet Geometrie und Kohomologie. Über den Atiyah-Singer-Indexsatz führt dieser Weg direkt von der Clifford-Algebra zur de Rham- und zyklischen Kohomologie.
