# %% [markdown]
# <a href="https://colab.research.google.com/github/deltorobarba/science/blob/main/maths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="blue">**Quantum Mathematics**

# %% [markdown]
# ![science](https://raw.githubusercontent.com/deltorobarba/science/main/science.JPG)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <font color="blue">**Tensor Algebra $v \otimes v$ as basis for Exterior-, Symmetric-, Clifford- und Weyl Algebra (Quotients by Ideal)**</font>
#
#
# | Parity of Fundamental Form (Two sides <br>are **dual** to each other. In supersymmetry <br>they are unified into a single construction <br>on $\mathbb{Z}_2$-graded vector spaces) | **Symmetric** (Metric) | **Antisymmetric** (Symplectic Form) |
# | :--- | :--- | :--- |
# | **Classical Algebra** ($\hbar \to 0$) <br>(undeformed, i.e. $Q=0$ resp. $\omega=0$)| **Exterior Algebra** $\Lambda(V)$ <br>(differential forms with $Q=0$) | **Symmetric Algebra** $\mathrm{Sym}(V)$<br>(polynomials / classical phase space with $\omega=0$) |
# | **Quotients by an Ideal of Tensor Algebra** <br>$T(V) = \bigoplus_{k=0}^{\infty} V^{\otimes k}$ <br>(associative, non-commutative) | **$\Lambda(V) = T(V)\,/\,\langle v \otimes v \rangle$**<br>**$\;\Rightarrow\; v \wedge w = -\,w \wedge v$**<br>One wants squares to vanish: ideal $v\otimes v = 0$ <br>Quotient by the two-sided ideal of all squares. <br>The product in the quotient is the wedge product: <br>$v \wedge w = [v \otimes w] \bmod I$.<br>Polarization then forces antisymmetry (hence orientation): <br>$0 = (v+w)\wedge(v+w) = v\wedge w + w\wedge v \;\Rightarrow\;$<br>$v\wedge w = -\,w\wedge v$. <br>Special case of the Clifford algebra with $Q = 0$ (limit)<br>Basis for **differential forms** and **cohomology** | **$\mathrm{Sym}(V) = T(V)\,/\,\langle v \otimes w - w \otimes v \rangle$**<br>**$\;\Rightarrow\; vw = wv$**<br>One wants the order to be irrelevant: the ideal is $v \otimes w - w \otimes v$. <br>In the quotient one then has $v \cdot w = w \cdot v$.<br><br>Classical observables, functions on classical phase space <br><br> Special case of the Weyl algebra with $\omega = 0$ (limit)<br><br>Foundation of **algebraic geometry**: coordinate ring of affine space |
# | **Fundamental Bilinear Form (Ideal) <br>on the Vector Space $V$** <br>(passage to quantization <br>= switch the bilinear form on)| **Metric** $g$ resp. $Q$ <br>(bilinear form, symmetric) | **Symplectic Form** $\omega$<br>(bilinear form, alternating / antisymmetric — as a <br>closed field on $M$ additionally a differential 2-form)|
# | **Geometry on the Manifold (Field Level)**: <br>the form on $V$ becomes a field. Geometry is  <br>the invariant theory of a form and its group | **Riemannian — local curvature exists = information is local**.<br>The $g$ on $V$ becomes a metric field $g_{\mu\nu}(x)$ <br>$\to$ How does one compare tangent spaces at different points? <br>Answer: a connection and curvature as its non-commutativity. <br>This is why Riemann needs **tensor analysis** for globalization <br>onto manifolds (Christoffel, covariant derivative, Levi-Civita, <br>Bianchi, parallel transport, Riemann/Ricci, Einstein equations) | **Symplectic — no local curvature = information is global**<br> For globalization (field instead of pointwise) symplectic geometry therefore runs <br>straight into **topology and quantization**<br>(the $\omega$ on $V$ becomes a closed 2-form on the manifold;<br> by Darboux there are no local curvature / invariants here)<br><br><br>|
# | **Quantized Algebra (Deformation)**. <br>Quantization = parity of the form × <br>deformation parameter switched on ($Q$, $\omega$) <br> (PBW deformation by a bilinear form) <br><br>  ⚠️ The deformation changes the product, <br>not the space. The quotient first fixes space<br>, and bilinear form $Q$ or $\omega$ then tunes product. | **Clifford Algebra** $\mathrm{Cl}(V,Q)$ with $Q \neq 0$<br>Differential forms become spinors/CAR<br>**Clifford (Riemann):**<br> $\underbrace{g \in \mathrm{Sym}^2 V^*}_{\text{symmetric input}} \to \mathrm{Cl}(V,g) \supset \underbrace{\mathfrak{so} \cong \Lambda^2 V}_{\text{degree 2: } \tfrac14[e_i,e_j]} \to \mathrm{Spin}\text{-repr.} \to \text{fermions, } \Lambda\text{-Fock}$<br>* Symmetric input → anticommuting output, and <br>the preserving algebra is the *exterior* square ($\mathfrak{so} \cong \Lambda^2 V$).| **Weyl Algebra** $A_n = W(V,\omega)$ with $\omega \neq 0$ <br>Phase-space polynomials become operators/CCR<br>Polynomials in $\hat q, \hat p$ = polynomial differential operators<br>* **Weyl (symplectic):** <br>$\underbrace{\omega \in \Lambda^2 V^*}_{\text{antisymmetric input}} \to W(V,\omega) \supset \underbrace{\mathfrak{sp} \cong \mathrm{Sym}^2 V}_{\text{degree 2: } \tfrac12\{\hat r_i,\hat r_j\}} \to \text{metaplectic} \to \text{bosons, } \mathrm{Sym}\text{-Fock}$<br>* Antisymmetric input → commuting output, and <br>the preserving algebra is the *symmetric* square ($\mathfrak{sp} \cong \mathrm{Sym}^2 V$). |
# | **Quotients by an Ideal of Tensor Algebra** <br>$T(V) = \bigoplus_{k=0}^{\infty} V^{\otimes k}$ <br>(associative, non-commutative) | **Clifford Algebra = Deformed $\Lambda$ with the *symmetric* form $Q$:** <br><br>**$\mathrm{Cl}(V,Q) = T(V)\,/\,\langle v \otimes v - Q(v)\mathbf{1}\rangle$**<br>**$\;\Rightarrow\; vw + wv = 2Q(v,w)$**<br><br>— the home of fermions and spinors (CAR)<br><br>* One wants the square of a vector to be <br>its length (or quadratic form $Q$)<br>* Hence one defines the ideal $I = \langle v \otimes v - Q(v) \cdot 1 \rangle$. <br>In the quotient one then automatically has $v^2 = \lVert v\rVert^2$.<br><br>* $\langle v\otimes v\rangle$ is **homogeneous** (pure degree 2) → the quotient inherits <br>the $\mathbb{Z}$-grading. $\langle v\otimes v - Q(v)\mathbf{1}\rangle$ is **inhomogeneous** <br>(mixes degree 2 and 0) → filtration (plus $\mathbb{Z}_2$-grading).<br><br>* In analysis: the Dirac operator $\nabla = d + \delta$ unites the exterior <br>derivative and its adjoint; $\nabla^2 = \Delta$ (Laplace–Beltrami). <br>* Notational economy for the Maxwell & Dirac equations. | **Weyl Algebra = Deforms $\mathrm{Sym}$ with the *antisymmetric* form $\omega$:** <br><br>**$W(V,\omega) = T(V)\,/\,\langle v \otimes w - w \otimes v - \omega(v,w)\mathbf{1}\rangle$**<br>**$\Rightarrow\; [v,w] = \omega(v,w)$**<br><br>— phase-space quantization, bosons (CCR)<br><br>* One wants the commutator of two vectors to be no longer zero, <br>but the number $\omega(v,w)$ — i.e. the Poisson bracket of the linear functions<br>* Hence one defines the ideal $I = \langle v \otimes w - w \otimes v - \omega(v,w)\cdot 1\rangle$. <br>In the quotient one then automatically has $[\hat q,\hat p] = i\hbar\mathbf{1}$.<br><br>* $\langle v\otimes w - w\otimes v\rangle$ is **homogeneous** (pure degree 2) → the quotient inherits <br>the $\mathbb{Z}$-grading. $\langle v\otimes w - w\otimes v - \omega(v,w)\mathbf{1}\rangle$ is **inhomogeneous** <br>(mixes degree 2 and 0) → filtration (Bernstein filtration; both generators are even, <br>so a $\mathbb{Z}_2$-grading survives) — structurally the very same step as on the left.<br><br>* **PBW basis:** the normal-ordered monomials $\hat q^{\,a}\hat p^{\,b}$ <br>form a vector-space basis — counterpart of $e_{i_1}\cdots e_{i_k}$ <br>in $\mathrm{Cl}$. But no relation truncates powers: <br>$\dim W = \infty$, whereas $\dim \mathrm{Cl} = 2^n$.<br>* **Dimension test:** $W$ has *no* finite-dimensional <br>representation, since $\mathrm{tr}[A,B] = 0$ but $\mathrm{tr}(i\hbar\mathbf{1}) \neq 0$ — <br>hence unbounded operators on an infinite-dimensional <br>Hilbert space, while $\mathrm{Cl}$ acts on a finite-dimensional spinor space.<br>* **Uniqueness (Stone–von Neumann):** for $\hbar \neq 0$ the exponentiated relations <br>admit exactly one irreducible representation up to unitary equivalence <br>— counterpart of the uniqueness of the spinor module of $\mathrm{Cl}$.<br><br>* In analysis: $W$ = algebra of polynomial differential operators $\mathcal{D}(\mathbb{A}^n)$; <br>Schrödinger realization $\hat q = x\,\cdot$, $\hat p = -i\hbar\,\partial_x$; basis of $D$-module theory. <br>The counterpart of the Dirac operator is the oscillator <br>$H = \tfrac12(\hat p^2 + \hat q^2) = \hbar(a^\dagger a + \tfrac12)$ — <br>a degree-2 square that generates $\mathfrak{sp}$. <br>* Notational economy: the uncertainty relation becomes a purely algebraic identity; <br>Moyal star product = the same deformation written on $\mathrm{Sym}$-functions. |
# | **Quantization as an Algebraic Act**<br>And the way back ('dequantization') is in both <br>cases $\mathrm{gr}$ = the classical limit ($\hbar \to 0$)<br>**$\mathrm{gr}$ = switching the deformation off again:** <br>keep only the top-degree part of each relation | **Fermionic quantization:** $\Lambda(V) \xrightarrow{\;Q\;} \mathrm{Cl}(V,Q)$<br> i.e.: $\Lambda(V)$ is the Clifford algebra with $Q=0$, <br>the reverse direction gives Chevalley: $\mathrm{gr}\,\mathrm{Cl}\cong\Lambda$ <br>$\mathrm{gr}\,\mathrm{Cl}(V,Q) \cong \Lambda(V)$ (Chevalley)<br>* **The way back ('dequantization') via $\mathrm{gr}$**: sanity check (dimension): <br>For $\dim V = 2$ both $\Lambda(\mathbb{R}^2)$ and $\mathrm{Cl}(\mathbb{R}^2,Q)$ have dimension 4 <br>with basis $\{1, e_1, e_2, e_1 e_2\}$ — a subset relation is ruled out. <br>Same vector-space skeleton, different multiplication table: <br>$e_1 \wedge e_1 = 0$ there, $e_1 e_1 = Q(e_1)$ here. | **Bosonic quantization:** $\mathrm{Sym}(V) \xrightarrow{\;\omega\;} W(V,\omega)$<br>i.e.: $\mathrm{Sym}(V)$ is the Weyl algebra with $\omega=0$, <br>the reverse direction is Poincaré–Birkhoff–Witt (PBW): $\mathrm{gr}\,W\cong\mathrm{Sym}$<br>$\mathrm{gr}\,W(V,\omega) \cong \mathrm{Sym}(V)$ (PBW) |
# | **Lie-Theoretic Construction Route** <br>(a second road to the same object): <br>Lie (super)algebra → universal enveloping <br>algebra $U(\cdot)$ → fix the centre $(Z=1)$<br>⚠️ Lie route is tensor-algebra quotient too: <br>$U(\mathfrak{g}) = T(\mathfrak{g})/\langle x\otimes y - y\otimes x - [x,y]\rangle$<br>both routes meet in the same ideal | **Heisenberg Lie superalgebra** $\mathfrak{h}^{\mathrm{super}}$: odd part $V$, <br>even centre $Z$; bracket = **anti**commutator <br>$\{v,w\} = 2Q(v,w)\,Z$<br>$\mathrm{Cl}(V,Q) = U(\mathfrak{h}^{\mathrm{super}})/(Z-1)$<br>**Super-PBW = Chevalley**: PBW on $\mathbb{Z}_2$-graded <br>spaces yields $\mathrm{gr}\,\mathrm{Cl} \cong \Lambda(V)$ — the table's two <br>gr-theorems are *one* theorem (the SUSY unification <br>from the header row) | **Bosonic ladder (three objects):**<br>· **Heisenberg Lie algebra** $\mathfrak{h}_n$: only addition + bracket (Jacobi); <br>basis $Q_i, P_i, Z$; $[Q_i, P_j] = \delta_{ij} Z$, $Z$ central ($Z \mapsto i\hbar\,\mathbf{1}$); $\dim = 2n+1$. <br>In $\mathfrak{h}_n$ one may *not yet* multiply $\hat Q \cdot \hat P$!<br>· **Universal enveloping algebra** $U(\mathfrak{h}_n)$: turns brackets into polynomials — <br>the Lie bracket is realized as the commutator $ab-ba$ (universal extension)<br>· **Weyl algebra** $A_n = U(\mathfrak{h}_n)/(Z-1)$: $Z=1$ turns $[Q,P]=Z$ into exactly <br>the $\omega$-relation — the same ideal as in the deformation route; $\dim = \infty$<br>**PBW in the original** is the theorem on enveloping algebras: $\mathrm{gr}\,U(\mathfrak{g}) \cong \mathrm{Sym}(\mathfrak{g})$ — <br>hence the name "PBW deformation". $\mathfrak{h}_n$ reappears inside the finished $W$: <br>as its degree-$\leq 1$ part.<br>➡️ Exponentiated & discrete objects (HW group, HW algebra, <br>CCR C*-algebra, 2×2 grid, degree ladder): **Table 2** |
# | Classical limit  | $Q\to 0 \Rightarrow \Lambda(V)$ | $\hbar\to 0 \Rightarrow \mathrm{Sym}(V)$ |
# | Defining relation | $vw + wv = 2Q(v,w)$ | $[v,w] = \omega(v,w)$ |
# | **Quantum Relation** <br>(statistics) | **Anticommutators (fermions)**<br>CAR: $\{a_i, a_j^\dagger\} = \delta_{ij}$ resp. CAR $\{\gamma_\mu,\gamma_\nu\}=2g_{\mu\nu}$ | **Commutators (bosons)** <br>CCR: $[a_i, a_j^\dagger] = \delta_{ij}$ resp. CCR $[\hat x,\hat p]=i\hbar$ |
# | **Particles**<br><br>**Role in physics** QFT needs both:<br> (Clifford/geometric + Heisenberg–Weyl)<br><br>**Representation / Fock space**  | **Fermions** ($\sigma_i$, $\gamma^\mu$ = basis vectors of $\mathrm{Cl}_{3,0}$, $\mathrm{Cl}_{1,3}$) <br><br>Internal structure: spin, spinors. <br>Spacetime, relativistic/Dirac. Fermions. <br><br>Spinor representation; fermionic Fock space $= \Lambda(\mathbb{C}^n)$ | **Bosons** ($a, a^\dagger$)<br><br>Kinematics: position/momentum $[\hat q,\hat p]=i\hbar$, phase-space quantization, <br>Schrödinger quantum mechanics. Bosons. <br><br>Oscillator representation; bosonic Fock space $= \mathrm{Sym}$ |
# | Degree-2 elements (Lie algebra) | $\mathfrak{so} \cong \Lambda^2 V$ | $\mathfrak{sp} \cong \mathrm{Sym}^2 V$ |
# | **Symmetry Tower: Group / Lie Algebra / <br>Double Cover → Group (2:1)**<br>The group preserves the form; the Lie algebra <br>consists of its infinitesimal generators <br>(= the degree-2 elements, row above); <br>the cover acts on the Fock space | **Group:** $\mathrm{O}(V,g) = \{S \in \mathrm{GL} : S^T g S = g\}$ — preserves <br>lengths and angles<br>$\mathrm{O}(V,g)$=orthogonal group of a vector space $V$ <br>equipped with a bilinear or quadratic form g<br>**Lie algebra:** $\mathfrak{so}(n) = \{A : A^T g + gA = 0\}$ (for $g = \mathbf{1}$: <br>antisymmetric matrices); $\dim = \tfrac{n(n-1)}{2}$; series $B_n$/$D_n$; <br>geometrically: infinitesimal rotations<br>**Double cover:** $\mathrm{Spin}(n) \to SO(n)$ — the spinor <br>representation on the $\Lambda$-Fock space yields the matchgate/<br>free-fermion unitaries | **Group:** symplectic group $\mathrm{Sp}(2n,\mathbb{K}) = \{S \in \mathrm{GL} : S^T J S = J\}$ <br>— stands to $\omega$ exactly as $\mathrm{O}(V,g)$ does to the symmetric form $g$.<br>**Lie algebra:** $\mathfrak{sp}(2n) = \{A : A^T J + JA = 0\}$, block form $\begin{pmatrix} B & C \\\\ D & -B^T \end{pmatrix}$ <br>with $C, D$ symmetric; $\dim = n(2n+1)$; in the classification of simple <br>Lie algebras the series $C_n$. Geometrically: **linear Hamiltonian vector fields**.<br>**Double cover:** $\mathrm{Mp}(2n,\mathbb{R})$ (metaplectic) — its representation on the <br>Fock space (oscillator representation) yields the Gaussian unitaries. <br>Exact counterpart of $\mathrm{Spin}(n) \to SO(n)$. |
# | **Bridge to Quantum Computing** (Table 2)<br>Both simulability theorems are structurally <br>**the same theorem**: degree 2 in the respective <br>branch, once for $SO(2n)$/Spin, <br>once for $Sp(2n)$/Mp (symplectic)| **Matchgates / free fermions (Valiant)**: <br>degree 2 in $\mathrm{Cl}$, time evolution = rotor in $\mathrm{Spin}(2n)$; <br>non-free only from degree 4 on (parity superselection <br>allows only even degrees) | **Clifford circuits / Gaussian (Gottesman–Knill)**: <br>degree 2 in $W$, symplectic action; <br>magic/non-Gaussian from degree 3 on <br>→ objects, degree ladder, Clifford hierarchy: **Table 2** |

# %% [markdown]
# <font color="blue">**Groups: From Heisenberg–Weyl Algebra to Quantum Gates (Degree of Generator $\hat{H}$)**</font>
#
# > Every quantum gate is a time evolution $U = e^{-i\hat{H}t}$. The physical and information-theoretic complexity of the gate is completely determined by the **polynomial degree of the generator $\hat{H}$ in the phase-space operators**.
#
# <br>
#
# |  | **Degree $\leq 1$** (linear) | **Degree $= 2$** (quadratic)| **Degree $\geq 3$** (cubic & higher) |
# | :--- | :--- | :--- | :--- |
# | **Generator** | $\hat{H} = q\hat{P} - p\hat{Q}$ | $\hat{H} \propto \hat{Q}^2 + \hat{P}^2$**<br>**$\hat{Q}^2 - \hat{P}^2,\; \hat{Q}_1 \hat{P}_2$* (mixed terms) | $\hat{H} \propto \hat{Q}^3$**<br>**$\hat{n}^2 \sim (\hat{Q}^2 + \hat{P}^2)^2$ <br>or many-body interactions |
# | **Action** | **Base lattice of pure displacements** $X, Z, D_{q,p}$<br> <br>Simply moves states to a different <br>location in phase space. This is the <br>Heisenberg–Weyl group| **Symmetry transformations** (rotations/shears such as <br>Hadamard, CNOT) that **map the lattice onto itself**. <br>Clifford: QFT/Hadamard, S, CNOT (quadratic in $\hat q,\hat p$, <br>**symplectic action)**. **Rotations, shears & entanglement**<br><br>Linear transformation of the coordinates ($U^\dagger \hat{r} U = S\hat{r}$). <br>They form the **Clifford group** (or Gaussian gates). <br>By Gottesman–Knill they are **classically efficiently simulable**, <br>because they do not bend the structure of phase space. | **Nonlinear distortion & quantum advantage**<br>They curve phase space nonlinearly<br>**Magic / non-Clifford which do not lie in the Clifford group, <br>but are contained as matrices in $M_d(\mathbb{C})$ → T, CS, Toffoli, cubic phase <br>Heisenberg evolution becomes $\hat{p} \to \hat{p} - 3\gamma t \hat{q}^2$). <br>From degree ≥ 3 on, construction is **no longer structure-preserving**.<br>One falls out of the symplectic group $\mathrm{Sp}(2n)$. <br>The HW language stays formally valid but loses its usefulness: <br>one *can* write $T$ gates as a Pauli sum, but the number of terms grows <br>under nesting, and that is precisely where classical simulation breaks down.<br>This is where genuine, non-simulable quantum computing begins. |
# | **Lie algebra**<br>(of the generators) | ✅ **$\mathfrak{h}_n$ closes trivially:**<br><br>Forms the $(2n+1)$-dimensional<br>**Heisenberg Lie algebra $\mathfrak{h}_n$**.<br><br>$[\hat{Q}, \hat{P}] = i\hbar\mathbf{1}$ is central<br>(commutes with everything). | ✅ **Closes as a Lie algebra:**<br><br>The commutator of two quadratic terms <br>stays quadratic ($[\hat{Q}^2, \hat{P}^2] \propto \hat{Q}\hat{P} + \hat{P}\hat{Q}$).<br><br>Closes to the **symplectic Lie algebra <br>v$\mathfrak{sp}(2n, \mathbb{R})$**.<br><br>Together with degree $\le 1$: semidirect product <br>$\mathfrak{sp}(2n) \ltimes \mathfrak{h}_n$ (Gaussian operations). | ❌ **Does NOT close as a Lie algebra:**<br><br>No longer forms a **finite-dimensional Lie algebra** <br>— commutators climb indefinitely into higher degrees:<br> $[\text{cubic}, \text{cubic}]$ generates degree 4, that generates degree 5, etc.<br><br>The generated group is infinite-dimensional. |
# | **Continuous<br>variables (CV)** | **Displacement operators:**<br><br>$\hat{D}(\alpha) = e^{\alpha \hat{a}^\dagger - \alpha^\ast \hat{a}}$<br><br>Shifts the state in phase space <br>to the position $(q, p)$ (position/momentum kick), <br>without changing its shape. | **Metaplectic group $\mathrm{Mp}(2n)$:**<br><br>• Phase rotator / QFT ($\hat{Q}^2 + \hat{P}^2$)<br>• Squeezer ($\hat{Q}\hat{P} + \hat{P}\hat{Q}$)<br>• Beamsplitter ($\hat{Q}_1\hat{P}_2 - \hat{Q}_2\hat{P}_1$)<br><br>**Gaussian unitaries:** transform the quadratures <br>strictly linearly: $U^\dagger \hat{r} U = S\hat{r}$ with $S \in \mathrm{Sp}(2n)$. | **Non-Gaussian unitaries:**<br><br>• Cubic-phase gate $V(\gamma) = e^{i\gamma \hat{Q}^3}$<br>• Kerr nonlinearity $e^{i\chi \hat{n}^2}$ (quartic)<br><br>The Heisenberg evolution becomes nonlinear: <br>$\hat{p} \to \hat{p} - 3\gamma t \hat{q}^2$. Phase-space states get distorted <br>(the Wigner function goes negative). One falls out of $\mathrm{Sp}(2n)$. |
# | **Discrete qudits /<br>qubits ($\mathbb{Z}_d$)** | **Heisenberg–Weyl group:**<br><br>• Shift gate $X$ (bit flip, position)<br>• Clock gate $Z$ (phase flip, momentum)<br>• Displacements $D_{q,p} = \tau^{qp} X^q Z^p$<br><br>(for $d=2$: the Pauli group $\mathcal{P}$). | **Clifford group $\mathcal{C}$:**<br><br>Defined as the normalizer of the Pauli group:<br>$\mathcal{C} = \{U : U \mathcal{P} U^\dagger = \mathcal{P}\}$<br><br>Modulo phases one has $\mathcal{C}/\mathcal{P} \cong \mathrm{Sp}(2n, \mathbb{Z}_d)$.<br><br>• Hadamard $H$ (90° rotation, swaps $X \leftrightarrow Z$)<br>• Phase gate $S$ (shear $P \to P+Q$)<br>• CNOT / C-SUM (Gaussian entanglement). | **Non-Clifford gates:**<br><br>• $T$ gate ($\pi/8$ phase gate, discrete cubic phase $e^{i\frac{\pi}{8}Z}$)<br>• Toffoli gate (CCNOT)<br>• CS gate ($C\text{-}S$)<br><br>⚠️ They lie in $M_d(\mathbb{C})$ as matrices, but do **not** belong <br>to the discrete HW group or the Clifford group. |
# | **Clifford hierarchy<br>& simulability** | **Level $\mathcal{C}_1$ of the hierarchy**<br><br>Pure lattice displacements. <br>Serve as an orthogonal basis <br>for the entire operator space. | **Level $\mathcal{C}_2$ of the hierarchy**<br><br>**Gottesman–Knill theorem <br>/ Gaussian simulation:**<br><br>Classically simulable efficiently in polynomial time, <br>since one only has to track the $2n \times 2n$ <br>symplectic matrix $S$ <br>instead of $2^n$ complex amplitudes. | **Level $\mathcal{C}_3$ and higher ($\mathcal{C}_k$):**<br><br>$\mathcal{C}_k = \{U : U \mathcal{P} U^\dagger \subset \mathcal{C}_{k-1}\}$<br><br>⚠️ For $k \ge 3$ no longer groups under multiplication.<br><br>**Magic states & quantum advantage:**<br><br>Clifford + $T$ gate generates a dense subgroup of $U(2^n)$ <br>(**universal quantum computing**). <br>No longer efficiently classically simulable. |
# | **Fermionic mirror image**<br><br>(Clifford algebra $\mathrm{Cl}(V, Q)$, CAR) <br>(contrast with Bosonic Heisenberg–<br>Weyl)mirrors structure, but has <br>fundamental physical differences | **Degree 1: Majorana operators $\gamma_i$):** There is **no <br>fermionic analogue of displacement gates**.<br><br>* Algebraically: degree $\leq 1$ does not close under the <br>commutator ($[\gamma_i, \gamma_j] = 2\gamma_i\gamma_j$ lands in degree 2). <br>Only the anticommutator closes ($\{\gamma_i, \gamma_j\} = 2\delta_{ij}\mathbf{1}$, <br>Lie superalgebra).<br><br>* Physically, the parity superselection rule forbids <br>odd Hamiltonians; fermionic coherent states exist only <br>formally, with anticommuting Grassmann numbers. | **Degree 2 (free fermions & matchgates):** Quadratic <br>fermionic Hamiltonians close under the commutator <br>onto $\mathfrak{so}(2n) \cong \Lambda^2 V$. >Their exponentiation yields <br>the group $\mathrm{Spin}(2n)$.<br><br>* **Matchgates / free fermions (Valiant):** are classically <br>efficiently simulable. **Mathematically this is the exact <br>fermionic counterpart of Gottesman–Knill** ($SO(2n)$/$\mathrm{Spin}$ <br>instead of $\mathrm{Sp}(2n)$/$\mathrm{Mp}$).<br><br>Free fermions (matchgates) are likewise classically simulable <br>(free fermions can be represented as Pauli matrices via <br>Jordan–Wigner), but for a different mathematical reason <br>(degree-2 elements in the Clifford algebra / $\mathrm{Spin}(2n)$) than <br>Clifford gates (degree-2 elements in Weyl algebra / $\mathrm{Sp}(2n)$). <br>(Orthogonal rotors instead of symplectic shears.) | **Degree 3 is missing:** Because of the parity superselection rule, <br>cubic fermionic interactions are forbidden. <br><br>Genuine, non-simulable interactions begin on the fermionic side <br>only at **degree 4** (quartic, e.g. the Hubbard $U$ term $n_\uparrow n_\downarrow$).<br><br>* **No 2×2 grid needed:** For $n$ fermionic modes the Clifford algebra $\mathrm{Cl}$ <br>is, via the Jordan–Wigner transformation, already finite-dimensional <br>by nature ($\cong M_{2^n}(\mathbb{C})$). No trace problem for anticommutators. |

# %% [markdown]
# <font color="blue">**Algebra: From Weyl Algebra (additive, continuous) to Heisenberg–Weyl Algebra (multiplicative, discrete)**</font>
#
# <br>
#
# |  | **Additive - Lie Algebra Level - Polynomials**<br>(generators & observables / $\hat{q}, \hat{p}$, Hamiltonians)<br>Here we work with $\hat{Q}, \hat{P}$ and their polynomials. <br>The composition law is addition together with the <br>Lie bracket (the commutator $[\cdot, \cdot]$) | **Multiplicative - Group Level - Exponentials**<br>(gates & unitaries / transformations, $e^{i\hat{q}}$, unitary operators)<br>Here we work with unitary operators $U = e^{-i\hat{H}t}$ at group level. |
# | --- | --- | --- |
# | **Continuous $L^2(\mathbb{R})$** ($\mathbb{R}^{2n}$) | <br><br>**Weyl algebra** $A_n = U(\mathfrak{h}_n)/(Z - \mathbf{1})$<br><br>Associative algebra of all polynomials in $\hat{q}, \hat{p}$; $\dim = \infty$; <br>space of all unbounded observables ($\hat{q}, \hat{p}, \hat{H}$)<br><br>Weyl from the **Heisenberg Lie algebra** $\mathfrak{h}_n$ ($\dim = 2n+1$)<br>Forward map: exponential map $\exp(-i\hat{H}t)$. Concretely:<br> Exponentiate at the Lie level: $\mathfrak{h}_n \xrightarrow{\exp} H_n$ (Heisenberg group)<br><br><br><br> | **CCR algebra / Weyl $C^\ast$-algebra** <br>(spanned by the continuous displacements D(α)).<br><br>Twisted group algebra on $(\mathbb{R}^{2n}, \omega)$ with $W(z)W(z') = e^{-\frac{i}{2}\omega(z,z')} W(z+z')$. <br>Acts irreducibly on $L^2(\mathbb{R}^n)$ and generates in its weak closure all bounded <br>operators $\mathcal{B}(L^2)$. This is the **Fourier–Weyl / Wigner expansion**: <br>every operator as a linear combination of displacements.<br><br>**Heisenberg group** $H_n$ (displacements $D(\alpha)$)<br>Way back is differentiating at the identity ($t=0$): $\hat{Q} = -i \frac{d}{dt}\big\vert{}_{t=0} W(t, 0)$ <br><br>$A_n$ and the CCR algebra are connected by Stone–von Neumann (representation theory)<br><br>* **Algebras are not exponentiated:** exponential map $\exp$ exists only from **Lie algebra <br>to the Lie (HW) group** ($\mathfrak{h}_n \xrightarrow{\exp} H_n$). Because commutator $[\hat{Q}, \hat{P}] = i\hbar \mathbf{1}$ is central <br>(it commutes with everything), the Baker–Campbell–Hausdorff formula (BCH) terminates <br>exactly after the first step: $e^{\hat{A}} e^{\hat{B}} = e^{\hat{A} + \hat{B} + \frac{1}{2}[\hat{A}, \hat{B}]}$. This turns additive Lie bracket directly <br>into multiplicative phase shift of HW group: $D(q, 0) D(0, p) = e^{i q p / \hbar} D(0, p) D(q, 0)$ <br><br>* Getting to the **Heisenberg–Weyl algebra**: Via **group algebra** (linear combinations): <br>One takes all group elements $D_{q,p} = X^q Z^p$ (the $d^2$ Pauli / shift–clock matrices). <br>One allows these to be multiplied by arbitrary complex numbers and added: <br>$\hat{A} = \sum_{q,p} c_{q,p} X^q Z^p$. Because the $d^2$ matrices form an orthogonal basis (Hilbert–<br>Schmidt basis), the resulting group algebra is **entire space of all matrices $M_d(\mathbb{C})$** <br><br>* **How one gets to the matrix algebra ($\mathrm{span}$ instead of $\exp$):** One passes from the <br>group to the algebra via the linear span (**group algebra**). The $d^2$ group elements <br>$D_{q,p} = X^q Z^p$ form an orthogonal Hilbert–Schmidt basis. Any matrix whatsoever <br>can be represented as a linear combination: $\hat{A} = \sum_{q,p} c_{q,p} X^q Z^p$. <br>**This is the discrete Fourier–Weyl resp. Wigner expansion**. |
# | **Discrete $\mathbb{Z}_d$** ($\mathbb{Z}_d * \mathbb{Z}_d$) | ❌ **Does not exist mathematically!**<br><br>*(Trace argument)*: On finite matrices one has <br>$\mathrm{Tr}([\hat{q}, \hat{p}]) = \mathrm{Tr}(\hat{q}\hat{p} - \hat{p}\hat{q}) = 0$, but $\mathrm{Tr}(i\hbar \mathbf{1}) = i\hbar \cdot d \neq 0$. <br>The additive relation $[\hat{q}, \hat{p}] = i\hbar$ cannot be discretized.<br>One cannot discretize the continuous additive relation $[\hat{q}, \hat{p}] = i\hbar$ <br>without keeping infinitely many dimensions. Solution: exponentiate to <br>the multiplicative Weyl relation $ZX = \omega XZ$ where <br>exact, $d$-dimensional matrices exist. ⚠️ That is why for discrete qubits +<br>qudits only the group / algebra world of exponentials ($M_d(\mathbb{C})$) exists. | **Discrete HW algebra** $M_d(\mathbb{C})$ (= all $d\times d$ matrices: T gate, Clifford gates, arbitrary <br>non-unitary operators, density matrices). $M_d(\mathbb{C})$ spanned by the <br>$d^2$ shift–clock matrices $X^q Z^p$. $M_d(\mathbb{C}) \cong \mathbb{C}_\omega[\mathbb{Z}_d \times \mathbb{Z}_d] $.<br>In the discrete case the $D_{q,p}$ span all of $M_d(\mathbb{C})$ = this is the **Fourier–Weyl / <br>Wigner expansion**: every operator as a linear combination of displacements.<br><br>Transition = in limit $d\to\infty$ discrete Weyl relations $ZX = \omega XZ$ <br>turn back into continuous commutation relations $[\hat{Q}, \hat{P}] = i\hbar \mathbf{1}$<br><br>* ⚠️ **Heisenberg–Weyl <u>algebra</u> ($M_d(\mathbb{C})$)** is space of all operators (= matrices): <br>On $n$ qubits the HW algebra is $M_{2^n}(\mathbb{C})$, i.e. *all* matrices. QFT, X, T, Toffoli, every future gate, <br>every density matrix, every non-unitary Kraus operator — everything lies inside, via the <br>Pauli expansion $U = \sum_{q,p} c_{q,p} D_{q,p}$. But this is not a substantive statement, just an observation <br>that **the Paulis form a basis**. Every qubit gate can be expressed via Pauli matrices and located <br>inside the Heisenberg–Weyl algebra (Heisenberg–Weyl basis is the **universal coordinate <br>system** in which every matrix can be expressed). - The algebra is simply space of all <br>matrices for $n$ qubits Heisenberg–Weyl algebra is just space of all complex $2^n \times 2^n$ <br>matrices ($M_{2^n}(\mathbb{C})$). Since the Pauli matrices ($I, X, Y, Z$ and their products) form <br>a complete basis of this space, every matrix can be written as a linear combination of <br>Pauli strings (but it rules nothing out).<br><br>**Discrete HW group** (order $d^3$, central phase extension of $\mathbb{Z}_d \times \mathbb{Z}_d$)<br><br>⚠️ **Group / construction is the actual physics:** Degree (Clifford hierarchy) filters <br>the generators (Hamiltonians) and unitary group. Algebra = space of all operators; <br>degree filter = an ordering on the generators.<br><br>The **polynomial degree of the generator** determines whether it is a simple displacement, <br>a Clifford operation (classically easy, HW/Clifford, degree $\le 2$), or a genuine quantum gate <br>(universally quantum, $T$/Toffoli, degree $\ge 3$). * Every unitary gate arises physically by <br>exponentiating a Hamiltonian operator: $U = e^{-i \hat{H} t}$. This generator $\hat{H}$ can always be built <br>out of position $\hat{Q}$ and momentum $\hat{P}$ (resp. creation operators $\hat{a}^\dagger$ and annihilation operators $\hat{a}$). <br>The decisive difference lies in the **degree of this polynomial** (the degree filter).<br><br>-> **The degree filter comes from the continuous Weyl algebra $A_n$, <br>but QC gates live in the discrete Heisenberg–Weyl algebra:** <br>gates are unitary and therefore naturally live in the group / C\*-world. <br>Hamiltonian physics and degree filter live in polynomial world $A_n$. <br>This is why the combination "degree filter on $A_n$ + gates in the HW/Clifford group" <br>is not a contradiction, but switching back and forth via $\exp$. |
#
# <br>

# %% [markdown]
# <font color="blue">**Physics: Quantum Operators from Quantum Harmonic Oscillator (via Exponentiation of Generators $\hat{Q}$, $\hat{P}$ and its Degree)**</font>
#
# ![Quantum Harmonic Oscillator](https://upload.wikimedia.org/wikipedia/commons/thumb/9/9e/HarmOsziFunktionen.png/330px-HarmOsziFunktionen.png)
#
# <font color="blue">***Quantum Harmonic Oscillator*** *and the Hamiltonian $\hat{H}$*</font>
#
# * $\hat{H} \propto \hat{P}^2 + \hat{Q}^2 = \hbar \omega \left(\hat{a}^\dagger \hat{a} + \frac{1}{2}\right) = \hbar \omega (\hat{n} + \frac{1}{2})$
# * $\hat{H}$ generator of basis state rotations in phase space ($Q / P$)
# * Ladder Operator Form: $\hat{H}=\hbar \omega\left(a^{\dagger} a+\frac{1}{2}\right)$. $\hat{a}$ and $\hat{a}^\dagger$ (Ladder Operators):  jump Up and Down the energy ladder.  Operators $\hat{Q}$ and $\hat{P}$ linear combinations of $\hat{a}, \hat{a}^\dagger$. Their sum of squares ($\hat{Q}^2 + \hat{P}^2$) gives Number Operator $\hat{n}$ for total energy.
# * Position/Momentum Form $\hat{H}=\frac{p^2}{2 m}+\frac{1}{2} m \omega^2 x^2$. [Quantum Harmonic Oscillation](https://en.wikipedia.org/wiki/Quantum_harmonic_oscillator) describes physical swap Kinetic $\leftrightarrow$ Potential = Time Evolution. Eg $t=0$: state in Position $Q$. Time evolution by $t=\frac{\pi}{2\omega}$ rotated $90^\circ$ to Momentum $P$ $\rightarrow$ is QFT!
# * Everything in quantum physics can be mapped onto a ['Phase Space'](https://en.wikipedia.org/wiki/Phase_space) of position $Q$ and momentum $P$ ([Formulation](https://en.wikipedia.org/wiki/Phase-space_formulation))
# * Mathematically, in QM Time is an Angle. In the expression $e^{-i\theta}$, $\theta$ must be a dimensionless number (an angle in radians). When we write the time-evolution operator as $\hat{U}(t) = e^{-i \hat{H} t / \hbar}$, the quantity $(\hat{H} t / \hbar)$ plays the role of that angle. In QM, states don't move along a trajectory like a baseball but its complex phase rotates. **If a system is in an energy eigenstate (Stationary State) with energy $E$, it stays in that state, but its phase "spins" at a frequency of $\omega = E/\hbar$.**
#
# <font color="blue">***Unit Circle*** *(Why Complex Numbers?)*</font>
#   * [Harmonic oscillator](https://en.wikipedia.org/wiki/Simple_harmonic_motion) moves back and forth: $x(t) = \cos(\omega t)$, described by real numbers: Position ($x$) and Velocity ($v$). Can combined to complex amplitude: $\alpha = x + i p$. Rotation keeps structure (unitary), rotates without changing magnitude (length).
#   * Annihilation operator $\hat{a}$ combines Position and Momentum into single complex number: $\hat{a} \propto \hat{Q} + i\hat{P}$. This is $x + iy$ (Euler) $\rightarrow$ Real Axis (Position) $\cos(\omega t)$. Imaginary Axis (Momentum) $i\sin(\omega t)$. Rotation (Time) $e^{i\omega t}$ = Oscillation between $Q$ and $P$
#   * Multiplying $\hat{a}$ by $e^{-i\omega t}$ rotates the vector in the complex plane. When the vector is horizontal (Real), the particle has maximum Position $Q$. When the vector is vertical (Imaginary), the particle has maximum Momentum $P$. **90° switch from X to Z = QFT.**
#
# <font color="blue">***Exponentiation:*** *Raise $e$ to power of position and momentum with $e^{-i \hat{G} \theta}$ to get from QHO to Quantum Operators*</font>
#   * $\hat{U} = e^{-i \hat{G} \theta}$ unitary is general form that describes movement of state in terms of fundamental operators $\hat{Q}$ and $\hat{P}$.
#     * $e^{i \theta}$ represents point on unit circle and keeps it unitary ($U^{\dagger}U=I$).
#     * $-i$ ensures transformation is rotation in Hilbert space that preserves length (norm) of state vector.
#     * $\hat{G}$ is a transformation. Parameter $\theta$ scales transformation.
#   * **Exponentiation** allows us to describe different transformations (gates). We just construct generator $\hat{G}$ with linear or non-linear combinations of fundamental operators $\hat{Q}$ + $\hat{P}$ (or $\hat{a}$ and $\hat{a}^\dagger$) or $\hat{X}$ and $\hat{Z}$ (modulo 𝑑) for qudit/qubit from Heisenberg-Weyl group. Exponentiation of unitary $\hat{U} = e^{-i \hat{H} t / \hbar}$ is defined and computed upon $[\hat{x}, \hat{p}] = i\hbar$ (CCR).
#     * If $\hat{G}$ is energy $\hat{H}$ (Hamiltonian), then $\hat{U} = e^{-i \hat{H} t / \hbar}$ where $\theta$ is duration of time $\frac{t}{\hbar}$ because because $\hat{H}$ is Time Evolution
#   * **Linear Transformations**: Generated by linear or quadratic functions ($\le 2^{\text{nd}}$ degree) of fundamental operators $\hat{Q}, \hat{P}$, or $\hat{X}$ and $\hat{Z}$ (modulo 𝑑). Not orthogonal and form overcomplete basis. Eigenstates of annihilation operator $\hat{a}$.
#   * **Non-Linear Transformations**: Generated by cubic or higher functions ($\ge 3^{\text{rd}}$ degree) of fundamental operators $\hat{Q}, \hat{P}$, or $\hat{X}$ and $\hat{Z}$ (modulo 𝑑). Break symmetry. Form orthonormal basis. Eigenstates of number operator $\hat{n} = \hat{a}^\dagger \hat{a}$.
#
# <font color="blue">***Conjugate relation:*** *An operator is a Generator of its conjugate variable's translation: This allows basis change $X$ <> $P$*</font>
#   * **Clock Z** *represents* Position (Potential) but *generates* Momentum Translation (Kick) - $D_{0,p} \sim Z^p$ applied (moves faster)
#   * **Shift X** *represents* Momentum (Kinetic) but *generates* Position Translation (Slide) - $D_{q,0} \sim X^q$ applied (new position)
#   * Connected via **Fourier Transform**. Used in $D_{q,p} = \tau^{qp} X^q Z^p$.  Based on commutation relation: $[x̂, p̂] = i ħ$ (for continuous), $ZX = \omega XZ$ (Weyl relation). For example in: Characteristic ($\chi(\xi)$) <> Wigner function.
#
# <font color="blue">***Kinetic Energy:*** *$\hat{P}^2$ $\rightarrow$ Momentum $\hat{P} = \frac{i}{\sqrt{2}}(\hat{a}^\dagger - \hat{a})$ $\rightarrow$ Shift operator $X = e^{-i \hat{P} \delta}$ $\rightarrow$ Bit Flip/Pauli $X$. Generator linear in $\hat{P}$*</font>
#   * **Kinetic Energy $\hat{P}^2$** corresponds to hopping term/Laplacian $\approx (X + X^\dagger)$. (Real/Symmetric) > used in Google's OTOC.
#   * **Gaussian: Momentum** $\hat{P} = \frac{i}{\sqrt{2}}(\hat{a}^\dagger - \hat{a})$ $\rightarrow$ corresponds to derivative $\approx i(X^\dagger - X)$. (Complex/Imaginary, anti-symmetric)
#   * **Clifford (Qudit): Shift**  $\hat{X}^a |j\rangle = |j+1\rangle \pmod d\rangle$. |0⟩→|1⟩→|2⟩→|d−1⟩→|0⟩. Eigenvalues of $X$ are powers of $\omega$ (via Fourier). Because:  In "Momentum Basis", Shift operator is diagonal! Looks like Clock matrix. Because $X = \text{DFT}^\dagger \cdot Z \cdot \text{DFT}$.
#   * **Clifford (Qubit): Pauli X**: $\sigma_x |j\rangle = |j+1 \pmod 2\rangle$. Swaps 0<>1. $ZX = -XZ$. Phase is ω = $e^{i 2\pi/2}$ = -1, Eigenvalues 1, -1.
#   * **Conjugation relation: Shift $X$ *represents* Momentum (Kinetic) but *generates* Position Shift** - $D_{q,0} \sim X^q$ applied (new position). Matrix $X$ is Real and Off-Diagonal (Permutation matrix of 0s and 1s). Shift is exponentiated momentum $X \approx e^{-i \hat{P} \delta_x}$
#
# <font color="blue">***Potential Energy**** *$\hat{Q}^2$ $\rightarrow$ Position $\hat{Q} = \frac{1}{\sqrt{2}}(\hat{a} + \hat{a}^\dagger)$ $\rightarrow$ Clock operator $Z = e^{i \hat{Q} \delta}$ $\rightarrow$ Phase Flip/Pauli-$Z$. Generator linear in $\hat{Q}$*</font>
#   * **Gaussian: Position** $\hat{Q} = \frac{1}{\sqrt{2}}(\hat{a} + \hat{a}^\dagger)$ is observable. Position ($\hat{Q}$) observable has Real eigenvalues (location index $k$).
#   * **Clifford (Qudit): Clock** $\hat{Z}^b$ acts as $|k\rangle \rightarrow \omega^k |k\rangle$ where $\omega=e^{2\pi i/d}$ phase gradient + primitive $d$-th root unity (=Eigenvalues). $e^{ix}$ is clock phase gate $Z$ with complex eigenvalues on unit circle (phases $\omega^k$ on unit circle). Raised to $d$-th power ($\omega^0, \omega^1, \dots, \omega^{d-1}$) to generate $d$ solutions to tag each basis state k. For $d=3$, $\omega = e^{i 2\pi/3}$  (unitary but not Hermitian).
#   * **Clifford (Qubit): Phase Flip/Pauli $Z$**. $d=2$ primitive root of unity: $\omega_2 = e^{2\pi i / 2} = e^{i\pi} = -1$ $→$  $\sigma_z |j\rangle = (-1)^j |j\rangle = \omega^j |j\rangle$. This is mod 2 version: $ZX = -XZ (ω = -1)$. Adds a $-1$ phase to $\sigma_z |1\rangle = -|1\rangle$, but leaves $\sigma_z |0\rangle = |0\rangle$. = Pauli $Z$ matrix is both Unitary (preserves probabilities) and Hermitian (is its own conjugate). We can observe it directly.
#   * **Conjugation relation: Clock $Z$ *represents* Position (Potential) but *generates* Momentum (Kick)** - $D_{0,p} \sim Z^p$ applied (move faster). Matrix $Z$ complex Eigenvalues (phases on unit circle) and diagonal. Operator $\hat{Q}$ has real eigenvalues (location)
#
# <font color="blue">***Quantum Operators***</font>
#
# * <font color="blue">*[Hamiltonian Operator](https://en.wikipedia.org/wiki/Hamiltonian_(quantum_mechanics)#Schr%C3%B6dinger_equation) generates [Time Evolution](https://en.wikipedia.org/wiki/Time_evolution) / Rotation / Basis Change. Generator is Quadratic $H = \hat{P}^2 + \hat{Q}^2$*</font>
#   * **Gaussian: Phase Shifter** $R(θ)=e^{-i \theta \hat{n}}$ rotates state by angle $θ$. For $θ=π/2$ (quarter turn), 90° = Fourier Transform. Generating operator is number operator $\hat{n}$ with Hamiltonian $H \propto \hat{Q}^2 + \hat{P}^2$ with rotation operator $R(θ)=e^{-i \theta (Q^2 + P^2)}$. $\hat{Q}$-$\hat{P}$ swap represents how potential and kinetic energy switch back and forth forever = basis change (rotation)
#   * **Clifford (Qudit): Quantum Fourier Transform (QFT)** is exactly Quarter period $\theta = \pi/2$ to rotate $Z$-eigenbasis (Position) into $X$-eigenbasis (Momentum) due to conjugate relation. Basis change by action on computational states $\text{QFT}*d |j \rangle$ =  ${0}^{d-1}  \omega^{jk} |k \rangle$. Basis change: maps single, localized basis state $|j\rangle$ into uniform superposition of all basis states tagged with phase $\omega^{jk}$. $W X W^\dagger = Z$. QFT turns Shift into Clock $\rightarrow$ QFT diagonalizes Shift $X$ operator. $W Z W^\dagger = X^\dagger$. Inverse QFT turns Clock into inverse Shift $\rightarrow$ Qudit $Z$ operator applies phase $\omega^j = e^{2\pi i j / d}$ based on *single* qudit index $j$.
#   * **Clifford (Qubit): Hadamard ($\hat{H}$)**. Conjugate relation allows basis change $Z$<>$X$  via equal superposition $H|0\rangle = |+\rangle$.
#   * Quadratic Generators $\hat{Q}^2 + \hat{P}^2$ geometrically generate rotations around origin of phase space. If you let a state evolve under this generator for a specific "time" or "angle," it's Quantum Fourier Transform. And angle is time in this setting!
# * <font color="blue">*[Displacement Operator](https://en.wikipedia.org/wiki/Displacement_operator) generates displacements in Phase Space. Generator is linear $G = q\hat{P} - p\hat{Q}$*</font>
#   * **Gaussian: Displacement** $\hat{D}(q, p) = e^{( -\frac{i}{\hbar} (q\hat{P} - p\hat{Q})}$ with generator $H  \propto (q\hat{P} - p\hat{Q})$. Where $H \propto \hat{P} \rightarrow$ generates shift in $Q$. And $H \propto \hat{Q} \rightarrow$ generates shift in $P$. Here called: position / momentum.
#   * **Clifford (Qudit): Displacement** $D_{q,p} = e^{i\pi qp/d} X^q Z^p$. Via Heisenberg-Weyl with of all combinations of shifts and clock/ phases ($X^q Z^p$). Phase factor $e^{i\pi qp/d}$ required because $X$ and $Z$ do not commute (Aharonov-Bohm effect in phase space).
#   * Linear Generators $q\hat{P} - p\hat{Q}$  geometrically don't rotate state around origin but slide to new location (q,p) in phase space
# * <font color="blue">*Special: Gaussian: Pauli-Y*</font>
#   * is just a product, not independent operator! In qubit $\sigma_y = i \sigma_x \sigma_z$ is just combination of bit and phase flip. For qudits: family of Generalized Pauli Operators defined by product of shifts and clocks: $P_{q,p} = X^q Z^p$.
#   * **For $d=2$ (Qubits):** $X^1 Z^0 = X$ and $X^0 Z^1 = Z$ and $X^1 Z^1 \propto Y$ ($Y$ is just $(1,1)$ point on the grid).
#   * **For $d=3$ (Qutrits):** $X Z$, $X Z^2$, $X^2 Z$, etc. None of these is uniquely called "$Y$". "Pauli $Y$" doesn't vanish; it just becomes one of the many $D_{q,p}$ displacement operators ($q \neq 0, p \neq 0$)
# * <font color="blue">*Special: Shear/Phase Gate*</font>
#   * Gaussian: **Quadratic Phase (Shear)**: Generator $H \propto \hat{Q}^2$. Hamiltonian $H \propto \hat{Q}^2$ (a "Kerr" nonlinearity or a Shear) preserves Position $Q$ but shears Momentum $P \to P + Q$.
#   * Clifford (Qubit): **Phase Gate ($\hat{S}$ or $\hat{P}$)**. $Z \to Z$, $X \to Y \sim XZ$. Phase gate is diagonal. $S = \text{diag}(1, i, \dots)$. It adds a quadratic phase $k^2$ to the wavefunction.
# * <font color="blue">*Special: Entanglement*</font>
#   * **Gaussian: Squeezer + Beam Splitter = Entanglement** $\approx$ CNOT.  Squeeze state to ellipse, then rotate ellipse 45° via Beam Splitter $\rightarrow$ noise becomes correlated between two axes = this is Entanglement. **Squeezer** is $\hat{S}(r) = e^{\left( -\frac{i r}{2\hbar} (\hat{Q}^2 - \hat{P}^2)\right)}$ with generator $H \propto (\hat{Q}^2 - \hat{P}^2)$ $= \hat{Q}\hat{P} + \hat{P}\hat{Q}$. Scales axes: stretches $Q$ and shrinks $P$ (or vice versa). Multiplies position by $e^{-r}$ and momentum by $e^r$. **Beam Splitter** $\hat{B}(\theta) = e^{-i \theta (\hat{Q}_1 \hat{P}_2 - \hat{Q}_2 \hat{P}_1)}$ with generator $H \propto \hat{Q}_1\hat{P}_2 - \hat{Q}_2\hat{P}_1$. This is the angular momentum operator in phase space. It performs passive rotation between two modes.If $\theta = \pi/4$ (50:50 Beam Splitter), it mixes the two inputs equally:$\hat{a}_1 \to \frac{\hat{a}_1 + \hat{a}_2}{\sqrt{2}}$ and $\hat{a}_2 \to \frac{\hat{a}_1 - \hat{a}_2}{\sqrt{2}}$.
#   * **Clifford (Qudit): C-SUM ($CX$)** $|c\rangle|t\rangle \to |c\rangle|t \oplus c\rangle  \pmod d\rangle$.  Adds control bit to target bit modulo d. $\hat{C}_{\text{SUM}} = e^{-i \hat{Q}_1 \hat{P}_2}$ with generator $\hat{Q}_1 \hat{P}_2$. Couples Position particle 1 to Momentum (shift) particle 2. C-SUM gate built via: Beam Splitter + Squeezing + Inverse Beam Splitter
#   * **Clifford (Qubit): CNOT**. $|c\rangle|t\rangle \to |c\rangle|t \oplus c\rangle  \pmod 2\rangle$. Adds control bit to target bit modulo 2.
# * <font color="blue">*Special: Cubic Phase $\rightarrow$ here begins non-simulatable magic states*</font>
#   * **Non-Gaussian: Cubic Phase** $\hat{U} = e^{i\gamma \hat{Q}^3}$ with generator $H \propto \hat{Q}^3$.  Cubic Phase gate $V(\gamma) = e^{i \gamma \hat{Q}^3}$ distorts phase space. A circle (coherent state) becomes a "banana" shape with negative Wigner function regions—the signature of non-classicality.
#   * **Non-Clifford (Qudit): Discrete Cubic Phase ($\hat{T}_d$)** (mod d). Generalized Magic Gates, often diagonal phases like $e^{i \frac{2\pi}{d^3} k^3}$. Corresponds to degree-3 polynomial phases: $T_d |k\rangle = \omega^{k^3} |k\rangle$. Exactly analogous to the cubic phase gate: $V(\gamma) = e^{i\gamma \hat{x}^3}$.
#   * **Non-Clifford (QUBIT): $\hat{T}$-gate** (magic gate) degree-3 (or $\pi/8$ gate): $\hat{T} = e^{-i \pi/8 \hat{Z}}$ - is cubic phase in discrete phase space (mod 2) : $\pi/8$ phase. The Clifford group maps Pauli operators to Pauli operators (Level 2).
# * <font color="blue">*Special: Other Operators*</font>
#   * **Non-Gaussian: Kerr** $\hat{U} = e^{i\chi \hat{n}^2}$ where $\hat{n} = \hat{a}^\dagger \hat{a}$. Generator $\propto (\hat{Q}^2 + \hat{P}^2)^2$ (quartic). Since $\hat{n} \sim Q^2 + P^2$, then $\hat{n}^2 \sim (Q^2 + P^2)^2 \sim Q^4 + \dots$This is a Quartic (4th order) potential. This represents a medium where the refractive index changes based on intensity. In computation, it is often used to build "Cat States" (macroscopic superpositions), which are excellent candidates for error-corrected logical qubits (Bosonic Codes).
#   * **Non-Clifford (Qudit): General high-order phase gates**
#   * **Non-Clifford (QUBIT): Toffoli Gate** (also Non-Clifford and Universal with $\hat{H}$ and $\hat{T}$)

# %% [markdown]
# <font color="blue">**Quantum Dynamics: Schrödinger Equation  $|\psi(t)\rangle = e^{-iHt} |\psi(0)\rangle$**
#
# Quantum systems in chemistry and physics can be described and computed with either classical and quantum methods:
#
# * **Model**: Classical (Newton Mechanics) vs Quantum (Schrödinger equation)
# * **Type**: Static (State) vs Dynamical (Evolution)
# * **Computing**: Classical Computing vs Quantum Computing
#
# <font color="blue">*1. Classical (Newtonian) Mechanics (**Static and Dynamic**): $F = m \cdot a$*
# * Ignores electrons and consider atoms as spheres connected by springs (force fields)
# * **Classical - Dynamic**: Molecular dynamics (MD). How proteins enfold and move? GROMACS, NAMD, AMBER.
# * **Classical - Static**: Molecular Docking / Energy Minimization. Geometrically: Does medication fit to enzyme? AutoDock, Rosetta.
# * **Quantum computing methods:** Future: Navier Stokes (fluid dynamics) with HHL to solve linear systems and differential equations exponentially faster than classical computers. For weather and climate: simulate weather with a much finer grid (e.g. 100m)
#
# <font color="blue">*2. Quantum Mechanics (**Static**): Time-independent Schrödinger Equation $\hat{H}|\psi\rangle = E|\psi\rangle$*
# * Includes electrons. **Approximates Ground State via optimization** with variation $\delta \langle H \rangle = 0$ to find global optimum in energy landscape. Stationary state important for calculating binding energies: If $\psi$ is an eigenstate of $\hat{H}$, then time evolution is trivial: $\Psi(t) = \psi e^{-iEt/\hbar}$. Probability density $|\Psi(t)|^2$ remains constant over time = states are stationary.
# * **Classical computing:** Hartree-Fock (mean field of $\psi$) but ignore correlation energies, DFT (electron density $\rho$) approximates correlation energies with functionals (but require correct functional assumed), Post-HF (Coupled cluster, configuration interaction) calculate correlation energies but only small systems since their complexity grows exponentially
# * **Quantum computing** (**NISQ**): Variational Quantum Eigensolver. Quantum Advantage: finds correlation energy with entanglement.
#   * In classical quantum chemistry, correlation energies are either ignored (HF), approximated (DFT), or, while theoretically calculable exactly, are only feasible for small quantum systems (post-Hartree-Fock methods like coupled cluster or configuration interaction).
#   * For classical computers, complexity grows exponentially, this is why quantum computers will play a significant role in analyzing larger, more complex systems.
#
# <font color="blue">*3. Quantum Mechanics (**Dynamic**): Time-dependent Schrödinger Equation $i\hbar \frac{\partial}{\partial t} \Psi(\mathbf{r}, t) = \hat{H} \Psi(\mathbf{r}, t)$*
# * **Simulate Time Evolution** $e^{-i\hat{H}t}$ of Quantum State $|\Psi(t)\rangle = e^{-i\hat{H}t/\hbar} |\Psi(0)\rangle$ via Unitary Transformation. For Quantum Chaos, OTOC, Scrambling (Black Holes) reaction dynamics (observe how bonds break and reform during a collision). No forward theorem!
# * **Classical computing**: Time-Dependent DFT (TD-DFT) used to classically calculate excitations (fluorescence, spectra). However only for short times and small systems. To solve the time-dependent equation $i\hbar \frac{\partial}{\partial t} \Psi = \hat{H} \Psi$ classically at scale, you have to apply operator $e^{-i\hat{H}t/\hbar}$ to wavefunction. In system with $N$ particles, complexity grows exponentially with $N$.
# * **Quantum computing** (**Fault-Tolerant**): Central challenge in quantum dynamics (Simulating Quantum Time Evolution):
#   * Molecule evolves under all its forces (Kinetic + Potential) simultaneously, but QC can only do one. But unitary propagator $U(t) = e^{-i\hat{H}t}$ is implemented on quantum hardware that only supports a discrete set of elementary gates at once.
#   * Three approaches: LCU, Trotterization, Qubitization (with Quantum Walks and Block Encoding). And with the OTOC metric to [measure information scrambling during quantum evolution](https://research.google/blog/a-verifiable-quantum-advantage/)
#
#
# <font color="blue">*Why we can solve the Schrödinger equation analytically only for very small systems (Quantum Chemistry)*
# * **Analytical** solution for Schrödinger in Hydrogen atom. But a second electron add electron-electron repulsion = three-body problem.
# * **Approximate** Schrödinger with DFT and HF on classical computers via **optimization (variation)** for larger systems than Hydrogen
# * **Simulate** time evolution for even larger systems = Quantum computer doesn't store information anymore - **it is the Hilbert space!**
# * Weil die Schrödinger Gleichung nicht exakt lösbar für größere Systeme: Rayleigh Ritz Verfahren aus Variationsanalyse und Born-Oppenheimer Aporoximation (Nukleus fixed, Elektronen für Energy Potential). Modelle und Verfahren:
#   * Valenzbindungstheorie (Hybridisierung, lokale Bindungen)
#   * Molekülorbitaltheorie (Delokalisierung, Konjugation, Homo/Lumo, LCAO-Methode)
#   * Hartee-Fock, Post-Hartree Fock (correlation energies), DFT
#   * Quantum Numbers (Besonderheit: Spinquantenzahl. Normale“ Schrödinger-Gleichung liefert nur $n$, $l$ und $m_l$. Spin ($m_s$=± 1/2) quanten- mechanische Eigenschaft. Erscheint wenn Quantenmechanik + Speziellen RT kombiniert (1928 Dirac-Gleichung).
#
# <font color="blue">*Qubitization (Quantum Walk, Block Encoding, LCU): Quantum Dynamics on fault-Tolerants QCs*
#
# * (ps: Trotterization / Trotter-Suzuki is a less-efficient alternative for Hamiltonian Simulation suited for NISQ)
# * Qubitization is an algebraic trick. It transforms the problem of walking through time into a problem of walking through the eigenvalues of an operator.
# * **LCU Decomposition:**
#   * Approximate operator by decomposing propagator $e^{-iHt}$ via Taylor series in weightes sum of unitaries $H = \sum_{l=0}^{L-1} \alpha_l U_l$. (non-unitary, represents energy).
#   * Then **Normalization:** $\lambda = \sum |\alpha_k|$ $\rightarrow$ $H/\lambda$.
#   * If $H=$ Dirac $\mathcal{D}$ = as benchmark, its algebraic structure (sum of Paulis) efficient.
# * **LCU Oracles**:
#   1. PREPARE Oracle ($P$): encodes coefficients $\alpha_j$ into amplitudes of ancilla. Output is state where probability of measuring state $j$ is proportional to $\alpha_j$: $P|0\rangle = \frac{1}{\sqrt{\|\alpha\|_1}} \sum_{j=0}^{m-1} \sqrt{\alpha_j} |j\rangle$.
#   2. SELECT Oracle ($S$) apply unitaries $U_l$ to target register state, conditioned on state of ancilla (entangles). If ancilla is state $|j\rangle$, it applies $U_j$ to target state $|\psi\rangle$. $S = \sum_{j=0}^{m-1} |j\rangle\langle j| \otimes U_j$
#   3. Un-prepare: Apply inverse $P^\dagger$ to ancilla.
#   4. Measure: ancilla.
# * **Block Encoding $U_H$:**
#   * LCU embeds $\hat{H}/\lambda$ in top-left corner of quantum walk $U_H = \begin{pmatrix} \hat{H}/\lambda & \dots \\ \dots & \dots \end{pmatrix}$.
#   * If Ancilla is $|0\rangle$, we apply $H$. If Ancilla is $|1\rangle$, apply junk.
# * **Quantum Walk** $Q$:
#   * add reflections to $U$ turns it into walk that moves through energy spectrum.
#   * By reflecting junk back into system ($Q = R \cdot U$), a rotation is created.
#   * Eigenvalues of $Q$ are linked to eigenvalues $E$ of $H$ via $\mu = e^{\pm i \arccos(E/\lambda)}$ (energy mapping).
#   * Physics is in angle (Isomorphism): $E_k = \lambda \cos(\theta_k)$.
#   * QW transforms *energy information* (scalar magnitude) into *phase information* (how fast rotates).
#   * High Energy $\rightarrow$ Small Angle. Zero Energy $\rightarrow$ $\cos(90^\circ)=0$.
# * **Simulation: Qubitization for OTOC**
#   * Example: OTOC (scrambling of black hole or complex molecule). Time Reversal in Qubitization: invert Reflection and Oracles. **Shows that TIME in Qubitization is actually an ANGLE in Hilbert space**.
#   * Scrambling: Even with 1 system qubit, measurement changes if Forward and Backward walks don't perfectly cancel out because of the $X$ gate (butterfly). Code is gate-based with no god-mode access to $e^{-iHt}$.

# %% [markdown]
# <font color="blue">**Appendix: Connection to Lie theory: the relationship between operators and gates follows the formalism of Lie groups**</font>
#
# * **The Lie group $G$** (e.g. $\mathrm{SO}(3)$ in robotics or the unitary gates in quantum mechanics) is the curved, nonlinear manifold of all transformations / motions (e.g. rotations $\mathrm{SO}(3)$ or rigid transformations $\mathrm{SE}(3)$)].
# * **The Lie algebra $\mathfrak{g}$** is the flat tangent space at the identity $T_eG$. This is where the physical generators live (the Hamiltonian operators $\hat{H}$). Since it is a flat vector space, one can take linear combinations here, do differential equations and differentiate.
# * **The exponential map $\exp(-i\hat{H}t)$** rolls the tangent vector along the geodesics onto the manifold and yields yields the actual motion (here: the physical gate).
# * In quantum mechanics too the Lie algebra is the linear space of infinitesimal generators (Hamiltonians $\hat{H}$), and by exponentiation $\exp(-i\hat{H}t)$ one arrives at the Lie group of unitary transformations/gates. **What they share**:
#   * **Lie theory ($\mathfrak{h}_n \xrightarrow{\exp} \text{group}$)** explains how motions/gates arise from generators (the *physical picture*).
#   * **The group algebra ($\text{group} \xrightarrow{\text{span}} M_d(\mathbb{C})$)** explains why the Paulis serve as a complete coordinate system for all quantum operators (the *algebraic picture*).
# * **But the difference:**
#   * **Heisenberg–Weyl group:** exponentiation of **degree-1 generators** (pure phase-space displacements).
#   * **Clifford / metaplectic group:** exponentiation of the Lie algebra $\mathfrak{sp}(2n)$ built from **degree-2 generators** (phase-space rotations and shears).
#   * **Weyl algebra:** not merely a Lie algebra, but the **associative algebra of all polynomials** in $\hat{Q}$ and $\hat{P}$ (degree 1, 2, 3, 4, ...), in which operators may also be freely added and multiplied.
# * **In continuous quantum mechanics there is a genuine Lie group and a genuine Lie algebra (Lie algebra $\to$ Lie group as in robotics):**
#   * **The Heisenberg Lie algebra $\mathfrak{h}_n$:** this is the $(2n+1)$-dimensional vector space spanned by the basis $\{\hat{Q}_i, \hat{P}_j, \hat{Z}\}$ with the Lie bracket (commutator): $[\hat{Q}_i, \hat{P}_j] = \delta_{ij} \hat{Z}, \quad [\hat{Q}_i, \hat{Z}] = 0, \quad [\hat{P}_j, \hat{Z}] = 0$. This is the tangent space at the origin.
#   * **The Heisenberg–Weyl Lie group $\mathrm{HW}$:** one exponentiates the elements of this Lie algebra: $D(q, p, \phi) = \exp\left( -i(q\hat{P} - p\hat{Q} + \phi \hat{Z}) \right)$
#   * Setting the central phase $\hat{Z} = \hbar \mathbf{1}$, one obtains the familiar **displacement operators** $D(q, p)$.
#   * **Group multiplication (Baker–Campbell–Hausdorff):** because $[\hat{Q}, \hat{P}] = i\hbar \mathbf{1}$ is central (i.e. commutes with everything), the BCH formula terminates after the first commutator: $e^{\hat{A}} e^{\hat{B}} = e^{\hat{A} + \hat{B} + \frac{1}{2}[\hat{A}, \hat{B}]}$.  This turns the additive structure of the Lie algebra into the multiplicative group phase (Weyl relation): $D(q, 0) D(0, p) = e^{i q p / \hbar} D(0, p) D(q, 0)$.
#   * **Up to this point it is 1:1 identical to robotics:** Lie algebra $\mathfrak{h}_n$ $\xrightarrow{\exp}$ Lie group $\mathrm{HW}$.
# * **Difference: what then is the "Weyl algebra"?**
#   * In robotics one usually stays with vectors and matrices. In quantum mechanics, however, we want not only to compose operators (group) but also to **multiply and add them with each other** (polynomials such as $\hat{H} = \frac{\hat{P}^2}{2m} + \frac{1}{2}m\omega^2\hat{Q}^2$ or $\hat{Q}^3$).
#   * This is where the so-called **universal enveloping algebra ($U(\mathfrak{h})$)** comes into play:
#   * **Lie algebra $\mathfrak{h}_n$ (tangent space, dimension $2n+1$):** allows only vector addition and the Lie bracket $[\cdot, \cdot]$. Here one may *not yet* multiply $\hat{Q}$ and $\hat{P}$ with each other as $\hat{Q} \cdot \hat{P}$.
#   * **Universal enveloping algebra $U(\mathfrak{h}_n)$ / Weyl algebra $A_n$ (infinite-dimensional):** here one takes all formal products and polynomials of $\hat{Q}$ and $\hat{P}$ and quotients out the ideal that enforces $[Q, P] = i\hbar\mathbf{1}$: $W(V, \omega) = T(V) \,/\, \langle v \otimes w - w \otimes v - \omega(v, w)\mathbf{1} \rangle$
#   * *That* is the **Weyl algebra** (the algebraic structure of all polynomial differential operators).
# * **Why do degree-2 operators close into a Lie algebra of their own?**
#   * If you commute two quadratic operators (e.g. $[ \hat{Q}^2, \hat{P}^2 ]$), you get back a quadratic term ($\propto \hat{Q}\hat{P} + \hat{P}\hat{Q}$). This means:
#   * Under the commutator, the quadratic Hamiltonians form the **Lie algebra $\mathfrak{sp}(2n, \mathbb{R})$**.
#   * Exponentiating this Lie algebra, you obtain the **metaplectic group** (on discrete qubits, the **Clifford group**).
#   * If instead you commute two cubic terms (degree 3, e.g. $\hat{Q}^3$), the commutator generates terms of degree 4; those of degree 4 generate degree 5, and so on. **No finite-dimensional Lie algebra** closes any more.
#
#
# <font color="blue">**Appendix: Tensor Algebra as the Basis for the Exterior, Symmetric, Clifford and Weyl Algebras**
#
# * Bilinear forms and their geometries — from the tensor algebra to quantization
# * Choose a bilinear form on $V$ — from it follow the algebra, the geometry, the symmetry group and the physics (four switches, one blueprint)
#
# <font color="blue">**Quotients by an Ideal in the Tensor Algebra**
#
# * Starting point: the free, rule-less **tensor algebra** $T(V) = \bigoplus_{k=0}^{\infty} V^{\otimes k}$: associative, non-commutative, no relations
# * **Construction principle:**
#   * Structure arises through the **quotient by an ideal** — certain elements are declared to be zero.
#   * This imposes a computational rule (and thereby a geometry) on the space.
# * **Quotient $T(V)/I$ (setting to zero)**
#   * Tensor algebra $T(V)$ with the element $v \otimes v$. For the exterior algebra this element is to be zero, i.e. $I$ = 0 for the quotient $T(V)/I$
#   * Consequence: **equivalence classes**. If elements $A$ and $B$ differ only by an element of $I$, then their difference is zero = they count as the same element. The space $T(V)$ gets compressed. Elements we no longer wish to distinguish are "glued together".
#   * Important: **quotient ≠ subset:** a quotient cuts nothing out, it **glues together** (equivalence classes). $\Lambda(V)$ does not lie *inside* $T(V)$. (In characteristic 0 there is an embedding of the antisymmetric tensors back in — but only as vector spaces, not as algebras; the factor $\tfrac{(k+l)!}{k!\,l!}$ in the alternation operator is precisely the proof that $\wedge$ is not the restriction of $\otimes$.)
# * **The ideal $I$: the "black hole" of multiplication**
#   * The subspace has to be an 'ideal', not just a set $I$: the multiplication rule must act the same way on the left and on the right.
#   * $v \otimes v = 0$ multiplied by a tensor $A$, it must necessarily hold that: $A \otimes (v \otimes v) = A \otimes 0 = 0$.
#   * If an element $x$ lies in the ideal $I$ and $A$ is *any* element of the entire algebra, then the products $A \otimes x$ and $x \otimes A$ must lie in the ideal $I$ again as well.
#   * The set we declare to be 0 must have the absorption property, so that multiplication works in the new quotient space
# * **Example: how the ideal enforces antisymmetry in the exterior algebra**
#   * The ideal $I$ is generated by all elements of the form $v \otimes v$. So in the quotient space $\Lambda(V) = T(V)/I$ every $v \otimes v = 0$. From now on we call this $v \wedge v = 0$. How does this "squares = 0" force everything else to become antisymmetric?
#   * Take two vectors $v$ and $w$. Consider the vector $(v+w)$. Because *every* element lies in the ideal together with itself, it must also hold that: $(v+w) \otimes (v+w) \in I$. In the quotient space this is therefore zero. Let us work it out:
#     * We start with: $(v+w) \wedge (v+w) = 0$.
#     * From this follows: $v \wedge v + v \wedge w + w \wedge v + w \wedge w = 0$.
#     * These drop out: $v \wedge v = 0$ and $w \wedge w = 0$ (they come from the ideal).
#     * What remains: $v \wedge w + w \wedge v = 0$ resp. **$v \wedge w = - (w \wedge v)$**
#   * Result: by setting $v \otimes v$ to zero via the ideal, we have proved that swapping two different vectors automatically flips the sign.
#
#
# <font color="blue">**Appendix: Differential Forms and the Symplectic Form**
#
# <font color="blue">*Maps vs. forms*
#
# * **Remember: maps have a vector (or a function) as output, forms a number.**
# * **Maps:** 0-map = scalar; 1-map = linear map as a sum of vector–covector pairs $L = \sum L^i_j\,(e_i \otimes e^j)$ — matrix multiplication is "row (covector) eats column vector, result scales the basis vector"; 2-map = bilinear-form-like with vector output; $k$-map = multilinear. *Operator* = endomorphism $V \to V$ or a map between function spaces (e.g. the derivative).
# * **Forms:** 0-form = smooth function; 1-form = linear form/covector $\alpha: V \to \mathbb{K}$ (infinite-dimensional: *functional*); 2-form = bilinear form $B = \sum B_{ij}\,(e^i \otimes e^j)$, coefficients = representing matrix; $k$-form = multilinear form.
#
# <font color="blue">*Differential form = field of alternating forms*
#
# * $\Omega^k(M) = \Gamma(\Lambda^k T^*M)$: to each point of the manifold an **alternating** $k$-multilinear form on the tangent space is assigned. An algebraic form lives rigidly in a vector space; a differential form is a **field** of forms, varying from point to point.
# * The antisymmetry comes from the wedge product: $\alpha \wedge \beta = -\beta \wedge \alpha$, in general a sign change on every swap of arguments, $\omega(v,v,\dots) = 0$. **Degree ladder (= what is integrated over what):**
#   * 0-form: function — "integration" = evaluation at points.
#   * 1-form ($dx$): line integrals (work along a path); smooth covector field.
#   * 2-form ($dx \wedge dy$): surface integrals (magnetic flux); measures oriented area à la determinant — swapping vectors flips the sign.
#   * 3-form ($dx \wedge dy \wedge dz$): volume integrals (density).
#   * $k$-form: completely antisymmetric covariant tensor of rank $k$.
# * Coordinate-free measuring and integrating of lengths, areas, volumes — adapts to stretching/compression of the space.
#
# <font color="blue">*The symplectic form $\omega$ (the single most important 2-differential form)*
#
# * Symplectic form $\omega$ = **alternating** (= 2-form) + **closed** ($d\omega = 0$) + **non-degenerate**, $\omega = \sum_{i=1}^n dp_i \wedge dq_i$
# * Darboux (no local invariants) and Liouville ($\omega$-conservation) turn it into phase space
# * **The symplectic form $\omega $ is both things at once, depending on which branch of mathematics one views it from:**
#   * It is a special (and smooth and closed) differential form,
#   * which acts pointwise on each tangent space as a special bilinear form (a non-degenerate, alternating 2-form)
# * **Non-degenerate:** from $\omega(v,w) = 0\ \forall w$ it follows that $v = 0$ — only the zero vector is "symplectically orthogonal". Matrix: invertible, $\det \neq 0$. Consequence: symplectic manifolds have **even dimension** $2n$ (one momentum degree of freedom for every position one).
# * $\omega^n = \omega \wedge \dots \wedge \omega$ vanishes nowhere → **Liouville volume form**.
# * **Darboux:** every symplectic vector space has a basis in the standard form $J = \begin{pmatrix} 0 & I_n \\ -I_n & 0 \end{pmatrix}$ — there is **only one symplectic vector space per dimension**, no local invariants (contrast with Riemann: there the curvature distinguishes locally).
# * **Liouville:** Hamiltonian flows preserve $\omega$ → phase-space volume is exactly conserved under time evolution.
#
# <font color="blue">*The uncertainty relation is the non-degeneracy of the symplectic form $\omega$, translated into operators*
# * Geometric core (Cauchy–Schwarz for forms): $|\omega(X,Y)|^2 \leq g(X,X)\cdot g(Y,Y)$ — the symplectic area of a parallelogram can never exceed the product of the metric lengths.
# * Translation into physics: $X = A - \langle A\rangle$, $Y = B - \langle B\rangle$; then $g(X,X) = (\Delta A)^2$, and the symplectic structure is the commutator: $\omega(X,Y) = \tfrac{1}{2i}\langle[A,B]\rangle$. Substituting: $\Delta A \cdot \Delta B \;\geq\; \tfrac12\,\bigl|\langle [A,B]\rangle\bigr| \quad\Rightarrow\quad \Delta q \cdot \Delta p \geq \tfrac{\hbar}{2}$
# * Interpretation: the uncertainty is the **non-degeneracy of $\omega$ in operator language** — every state carries a minimal, indivisible phase-space area (action element) that cannot collapse to a point.
